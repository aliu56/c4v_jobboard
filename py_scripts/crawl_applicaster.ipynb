# %% [markdown]
# EVERLI

# %% [markdown]
# # SCRAPING

# %%
import requests


from requests import get

# Lien de la page à scraper
url = "https://www.applicaster.com/careers"

response = get(url)
source = None # Le code source de la page 

if response.status_code == 200 :
    # Si la requete s'est bien passee
    source = response.text
    
print(source)
# Out:
# <!doctype html><!--[if lt IE 7]> <html class="no-js lt-ie9 lt-ie8 lt-ie7" lang="en" > <![endif]--><!--[if IE 7]>    <html class="no-js lt-ie9 lt-ie8" lang="en" >        <![endif]--><!--[if IE 8]>    <html class="no-js lt-ie9" lang="en" >               <![endif]--><!--[if gt IE 8]><!--><html class="no-js" lang="en"><!--<![endif]--><head>
#     <meta charset="utf-8">
#     <meta http-equiv="X-UA-Compatible" content="IE=edge,chrome=1">
#     <meta name="author" content="Applicaster">
#     <meta name="description" content="We’re hiring. Tech jobs. Developer jobs. Sales jobs. We want to talk to excellent techies and highly successful salespeople.">
#     <meta name="generator" content="HubSpot">
#     <title>Careers | Applicaster</title>
#     <link rel="shortcut icon" href="https://www.applicaster.com/hubfs/Applicaster_Nov_2016/Image/favicon.png">
#
#
#     <script src="/hs/hsstatic/jquery-libs/static-1.1/jquery/jquery-1.7.1.js"></script>
# <script>hsjQuery = window['jQuery'];</script>
#     <meta property="og:description" content="We’re hiring. Tech jobs. Developer jobs. Sales jobs. We want to talk to excellent techies and highly successful salespeople.">
#     <meta property="og:title" content="Careers | Applicaster">
#     <meta name="twitter:description" content="We’re hiring. Tech jobs. Developer jobs. Sales jobs. We want to talk to excellent techies and highly successful salespeople.">
#     <meta name="twitter:title" content="Careers | Applicaster">
#
#
#
#
#     <style>
# a.cta_button{-moz-box-sizing:content-box !important;-webkit-box-sizing:content-box !important;box-sizing:content-box !important;vertical-align:middle}.hs-breadcrumb-menu{list-style-type:none;margin:0px 0px 0px 0px;padding:0px 0px 0px 0px}.hs-breadcrumb-menu-item{float:left;padding:10px 0px 10px 10px}.hs-breadcrumb-menu-divider:before{content:'›';padding-left:10px}.hs-featured-image-link{border:0}.hs-featured-image{float:right;margin:0 0 20px 20px;max-width:50%}@media (max-width: 568px){.hs-featured-image{float:none;margin:0;width:100%;max-width:100%}}.hs-screen-reader-text{clip:rect(1px, 1px, 1px, 1px);height:1px;overflow:hidden;position:absolute !important;width:1px}
# </style>
#
# <link rel="stylesheet" href="https://www.applicaster.com/hs-fs/hub/1919336/hub_generated/module_assets/34711567328/1600899404625/module_34711567328_Banner_-_v2.min.css">
# <link rel="stylesheet" href="https://www.applicaster.com/hs-fs/hub/1919336/hub_generated/module_assets/35233170497/1600901582584/module_35233170497_Platform_App_Mgmt_Slider_-_v2.min.css">
# <link rel="stylesheet" href="https://www.applicaster.com/hs-fs/hub/1919336/hub_generated/module_assets/12251805651/1600699635315/module_12251805651_2_Col_-_Slider_Copy_and_Image.min.css">
# <link rel="stylesheet" href="https://www.applicaster.com/hs-fs/hub/1919336/hub_generated/module_assets/1570820954480/module_12280678332_Custom_modules_Applicaster_2019_S2_Career_Positions.min.css">
#
#
#
#     <link rel="canonical" href="https://www.applicaster.com/careers">
#
# <meta name="viewport" content="width=device-width, initial-scale=1">
# <!-- Google Tag Manager -->
# <script>(function(w,d,s,l,i){w[l]=w[l]||[];w[l].push({'gtm.start':
# new Date().getTime(),event:'gtm.js'});var f=d.getElementsByTagName(s)[0],
# j=d.createElement(s),dl=l!='dataLayer'?'&l='+l:'';j.async=true;j.src=
# 'https://www.googletagmanager.com/gtm.js?id='+i+dl;f.parentNode.insertBefore(j,f);
# })(window,document,'script','dataLayer','GTM-MSFHXLL');</script>
# <!-- End Google Tag Manager -->
#
#
# <script type="text/javascript" language="javascript">;
#   var sf14gv = 18462;
#   (function() {
#     var sf14g = document.createElement('script'); sf14g.type = 'text/javascript'; sf14g.async = true;
#     sf14g.src = ('https:' == document.location.protocol ? 'https://' : 'http://') + 't.sf14g.com/sf14g.js';
#     var s = document.getElementsByTagName('script')[0]; s.parentNode.insertBefore(sf14g, s);
#   })();
# </script>
#
# <meta name="google-site-verification" content="Rq7kzoNa2rgFVGTFyNDdTs4gk5SazE-Orl7O1-zuILo">
# <meta property="og:url" content="https://www.applicaster.com/careers">
# <meta name="twitter:card" content="summary">
# <link rel="stylesheet" href="//cdn2.hubspot.net/hub/7052064/hub_generated/template_assets/1623444889189/hubspot/hubspot_default/shared/responsive/layout.min.css">
#
#
# <link rel="stylesheet" href="https://www.applicaster.com/hs-fs/hub/1919336/hub_generated/template_assets/34705417867/1620334362291/Templates/Custom/Page/Applicaster_2020_-_s2/s2-style-v2.min.css">
#
#
#     <script src="https://unpkg.com/scrollreveal"></script>
# <script src="https://cdnjs.cloudflare.com/ajax/libs/slick-carousel/1.9.0/slick.min.js"></script>
# <link rel="stylesheet" type="text/css" href="https://cdnjs.cloudflare.com/ajax/libs/slick-carousel/1.9.0/slick.min.css">
# <!--[if lte IE 9]>
# <link rel="stylesheet" type="text/css" href="https://cdn2.hubspot.net/hubfs/1919336/Applicaster%20Aug%202019%20Assets/css/animations-ie-fix.css">
# <![endif]-->
# <link rel="stylesheet" type="text/css" href="https://www.applicaster.com/hubfs/Applicaster%20Aug%202019%20Assets/css/animations.css">
#
#
# </head>
# <body class="general   hs-content-id-34961382829 hs-site-page page " style="">
#     <div class="header-container-wrapper">
#     <div class="header-container container-fluid">
#
# <div class="row-fluid-wrapper row-depth-1 row-number-1 ">
# <div class="row-fluid ">
# <div class="span12 widget-span widget-type-global_group " style="" data-widget-type="global_group" data-x="0" data-w="12">
# <div class="" data-global-widget-path="generated_global_groups/35293518671.html"><div class="row-fluid-wrapper row-depth-1 row-number-1 ">
# <div class="row-fluid ">
# <div class="span12 widget-span widget-type-cell header bg-white" style="" data-widget-type="cell" data-x="0" data-w="12">
#
# <div class="row-fluid-wrapper row-depth-1 row-number-2 ">
# <div class="row-fluid ">
# <div class="span12 widget-span widget-type-cell header-wrapper" style="" data-widget-type="cell" data-x="0" data-w="12">
#
# <div class="row-fluid-wrapper row-depth-1 row-number-3 ">
# <div class="row-fluid ">
# <div class="span4 widget-span widget-type-custom_widget " style="" data-widget-type="custom_widget" data-x="0" data-w="4">
# <div id="hs_cos_wrapper_module_15646223506968" class="hs_cos_wrapper hs_cos_wrapper_widget hs_cos_wrapper_type_module widget-type-logo" style="" data-hs-cos-general-type="widget" data-hs-cos-type="module">
#
#
#
#
#   <span id="hs_cos_wrapper_module_15646223506968_hs_logo_widget" class="hs_cos_wrapper hs_cos_wrapper_widget hs_cos_wrapper_type_logo" style="" data-hs-cos-general-type="widget" data-hs-cos-type="logo"><a href="http://applicaster.com" id="hs-link-module_15646223506968_hs_logo_widget" style="border-width:0px;border:0px;"><img src="https://www.applicaster.com/hubfs/Applicaster%20Aug%202019%20Assets/applicaster%20logo%20blue.svg" class="hs-image-widget " style="width:199px;border-width:0px;border:0px;" width="199" alt="applicaster logo blue" title="applicaster logo blue"></a></span>
#
# </div>
#
# </div><!--end widget-span -->
# <div class="span8 widget-span widget-type-cell header-nav bg-blue" style="" data-widget-type="cell" data-x="4" data-w="8">
#
# <div class="row-fluid-wrapper row-depth-1 row-number-4 ">
# <div class="row-fluid ">
# <div class="span12 widget-span widget-type-custom_widget header-menu" style="" data-widget-type="custom_widget" data-x="0" data-w="12">
# <div id="hs_cos_wrapper_module_156462240271810" class="hs_cos_wrapper hs_cos_wrapper_widget hs_cos_wrapper_type_module widget-type-menu" style="" data-hs-cos-general-type="widget" data-hs-cos-type="module">
# <span id="hs_cos_wrapper_module_156462240271810_" class="hs_cos_wrapper hs_cos_wrapper_widget hs_cos_wrapper_type_menu" style="" data-hs-cos-general-type="widget" data-hs-cos-type="menu"><div id="hs_menu_wrapper_module_156462240271810_" class="hs-menu-wrapper active-branch flyouts hs-menu-flow-horizontal" role="navigation" data-sitemap-name="default" data-menu-id="45772263050" aria-label="Navigation Menu">
#  <ul role="menu">
#   <li class="hs-menu-item hs-menu-depth-1" role="none"><a href="https://www.applicaster.com/platform" role="menuitem">Platform</a></li>
#   <li class="hs-menu-item hs-menu-depth-1 hs-item-has-children" role="none"><a href="javascript:;" aria-haspopup="true" aria-expanded="false" role="menuitem">Solutions</a>
#    <ul role="menu" class="hs-menu-children-wrapper">
#     <li class="hs-menu-item hs-menu-depth-2" role="none"><a href="https://www.applicaster.com/broadcasters" role="menuitem">Broadcasters</a></li>
#     <li class="hs-menu-item hs-menu-depth-2" role="none"><a href="https://www.applicaster.com/sports" role="menuitem">Sports</a></li>
#     <li class="hs-menu-item hs-menu-depth-2" role="none"><a href="https://www.applicaster.com/kids" role="menuitem">Kids</a></li>
#     <li class="hs-menu-item hs-menu-depth-2" role="none"><a href="https://www.applicaster.com/fitness" role="menuitem">Fitness</a></li>
#    </ul></li>
#   <li class="hs-menu-item hs-menu-depth-1" role="none"><a href="https://www.applicaster.com/ui" role="menuitem">UI</a></li>
#   <li class="hs-menu-item hs-menu-depth-1" role="none"><a href="https://www.applicaster.com/apis" role="menuitem">Partner APIs</a></li>
#   <li class="hs-menu-item hs-menu-depth-1" role="none"><a href="https://www.applicaster.com/case-studies" role="menuitem">Case Studies</a></li>
#   <li class="hs-menu-item hs-menu-depth-1" role="none"><a href="https://www.applicaster.com/pricing" role="menuitem">Pricing</a></li>
#   <li class="hs-menu-item hs-menu-depth-1" role="none"><a href="https://www.applicaster.com/resources" role="menuitem">Resources</a></li>
#   <li class="hs-menu-item hs-menu-depth-1" role="none"><a href="https://www.applicaster.com/about-us" role="menuitem">About Us</a></li>
#   <li class="hs-menu-item hs-menu-depth-1" role="none"><a href="https://zapp.applicaster.com" role="menuitem">Sign In</a></li>
#  </ul>
# </div></span></div>
#
# </div><!--end widget-span -->
# </div><!--end row-->
# </div><!--end row-wrapper -->
#
# <div class="row-fluid-wrapper row-depth-1 row-number-5 ">
# <div class="row-fluid ">
# <div class="span12 widget-span widget-type-cell header-mobile-menu bg-darkblue display hide-md" style="" data-widget-type="cell" data-x="0" data-w="12">
#
# <div class="row-fluid-wrapper row-depth-2 row-number-1 ">
# <div class="row-fluid ">
# <div class="span12 widget-span widget-type-custom_widget header-social" style="" data-widget-type="custom_widget" data-x="0" data-w="12">
# <div id="hs_cos_wrapper_module_1564711284489593" class="hs_cos_wrapper hs_cos_wrapper_widget hs_cos_wrapper_type_module widget-type-rich_text" style="" data-hs-cos-general-type="widget" data-hs-cos-type="module"><span id="hs_cos_wrapper_module_1564711284489593_" class="hs_cos_wrapper hs_cos_wrapper_widget hs_cos_wrapper_type_rich_text" style="" data-hs-cos-general-type="widget" data-hs-cos-type="rich_text"><ul class="d-flex a-items-center no-list-style">
# <li><a href="https://twitter.com/Applicaster?ref_src=twsrc%5Egoogle%7Ctwcamp%5Eserp%7Ctwgr%5Eauthor" target="_blank" rel="noopener"><img src="https://www.applicaster.com/hubfs/Applicaster%20Aug%202019%20Assets/twitter-light.svg"></a></li>
# <li><a href="https://www.facebook.com/applicaster/" target="_blank" rel="noopener"><img src="https://www.applicaster.com/hubfs/Applicaster%20Aug%202019%20Assets/facebook-light.svg"></a></li>
# <li><a href="https://www.youtube.com/channel/UCcUVcIIxenqWdnW0bplNEmw" target="_blank" rel="noopener"><img src="https://www.applicaster.com/hubfs/Applicaster%20Aug%202019%20Assets/youtube-light.svg"></a></li>
# <li><a href="https://www.linkedin.com/company/applicaster-ltd/" target="_blank" rel="noopener"><img src="https://www.applicaster.com/hubfs/Applicaster%20Aug%202019%20Assets/LI-In-Bug-light.png"></a></li>
# </ul></span></div>
#
# </div><!--end widget-span -->
# </div><!--end row-->
# </div><!--end row-wrapper -->
#
# <div class="row-fluid-wrapper row-depth-2 row-number-2 ">
# <div class="row-fluid ">
# <div class="span12 widget-span widget-type-custom_widget " style="" data-widget-type="custom_widget" data-x="0" data-w="12">
# <div id="hs_cos_wrapper_module_1564711371002625" class="hs_cos_wrapper hs_cos_wrapper_widget hs_cos_wrapper_type_module widget-type-menu" style="" data-hs-cos-general-type="widget" data-hs-cos-type="module">
# <span id="hs_cos_wrapper_module_1564711371002625_" class="hs_cos_wrapper hs_cos_wrapper_widget hs_cos_wrapper_type_menu" style="" data-hs-cos-general-type="widget" data-hs-cos-type="menu"><div id="hs_menu_wrapper_module_1564711371002625_" class="hs-menu-wrapper active-branch flyouts hs-menu-flow-vertical" role="navigation" data-sitemap-name="default" data-menu-id="34735700898" aria-label="Navigation Menu">
#  <ul role="menu">
#   <li class="hs-menu-item hs-menu-depth-1" role="none"><a href="https://www.applicaster.com/platform" role="menuitem">Platform</a></li>
#   <li class="hs-menu-item hs-menu-depth-1" role="none"><a href="https://www.applicaster.com/ui" role="menuitem">UI</a></li>
#   <li class="hs-menu-item hs-menu-depth-1 hs-item-has-children" role="none"><a href="javascript:;" aria-haspopup="true" aria-expanded="false" role="menuitem">Solutions</a>
#    <ul role="menu" class="hs-menu-children-wrapper">
#     <li class="hs-menu-item hs-menu-depth-2" role="none"><a href="https://www.applicaster.com/broadcasters" role="menuitem">Broadcasters</a></li>
#     <li class="hs-menu-item hs-menu-depth-2" role="none"><a href="https://www.applicaster.com/kids" role="menuitem">Kids</a></li>
#     <li class="hs-menu-item hs-menu-depth-2" role="none"><a href="https://www.applicaster.com/sports" role="menuitem">Sports</a></li>
#     <li class="hs-menu-item hs-menu-depth-2" role="none"><a href="https://www.applicaster.com/fitness" role="menuitem">Fitness</a></li>
#    </ul></li>
#   <li class="hs-menu-item hs-menu-depth-1" role="none"><a href="https://www.applicaster.com/apis" role="menuitem">Partner APIs</a></li>
#   <li class="hs-menu-item hs-menu-depth-1" role="none"><a href="https://www.applicaster.com/case-studies" role="menuitem">Case Studies</a></li>
#   <li class="hs-menu-item hs-menu-depth-1" role="none"><a href="https://www.applicaster.com/pricing" role="menuitem">Pricing</a></li>
#   <li class="hs-menu-item hs-menu-depth-1" role="none"><a href="https://www.applicaster.com/resources" role="menuitem">Resources</a></li>
#   <li class="hs-menu-item hs-menu-depth-1" role="none"><a href="https://www.applicaster.com/about-us" role="menuitem">About Us</a></li>
#   <li class="hs-menu-item hs-menu-depth-1" role="none"><a href="https://zapp.applicaster.com" role="menuitem">Sign In</a></li>
#  </ul>
# </div></span></div>
#
# </div><!--end widget-span -->
# </div><!--end row-->
# </div><!--end row-wrapper -->
#
# </div><!--end widget-span -->
# </div><!--end row-->
# </div><!--end row-wrapper -->
#
# </div><!--end widget-span -->
# </div><!--end row-->
# </div><!--end row-wrapper -->
#
# </div><!--end widget-span -->
#
# <span class="nav-bar display hide-lg"><span></span></span>
# </div><!--end row-->
# </div><!--end row-wrapper -->
#
# </div><!--end widget-span -->
# </div><!--end row-->
# </div><!--end row-wrapper -->
# </div>
# </div><!--end widget-span -->
# </div><!--end row-->
# </div><!--end row-wrapper -->
#
#     </div><!--end header -->
# </div><!--end header wrapper -->
#
# <div class="body-container-wrapper">
#     <div class="body-container container-fluid">
#
# <div class="row-fluid-wrapper row-depth-1 row-number-1 ">
# <div class="row-fluid ">
# <div class="span12 widget-span widget-type-widget_container " style="" data-widget-type="widget_container" data-x="0" data-w="12">
# <span id="hs_cos_wrapper_module_15646222868736" class="hs_cos_wrapper hs_cos_wrapper_widget_container hs_cos_wrapper_type_widget_container" style="" data-hs-cos-general-type="widget_container" data-hs-cos-type="widget_container"><div id="hs_cos_wrapper_widget_1600955110978" class="hs_cos_wrapper hs_cos_wrapper_widget hs_cos_wrapper_type_module" style="" data-hs-cos-general-type="widget" data-hs-cos-type="module">
#
#
#
#
# <div class="home-banner banner animatedParent animateOnce top-spacing-lg bottom-spacing-md">
#   <img class="accent-right accent hide display-lg animated fadeInRight" src="https://www.applicaster.com/hubfs/Applicaster%20Aug%202019%20Assets/banner_group2.svg">
#
#   <div class="container">
#     <div class="banner__inner animated fadeIn">
#       <div class="banner__title">
#         <h1>
#           <strong>Build the <span>future</span> of media OTT distribution</strong>&nbsp;
#           <div class="banner__title-rotation">
#             <div>
#
#             </div>
#           </div>
#         </h1>
#       </div>
#       <div class="custom-row j-content-between">
#         <div class="column-lg-5 banner-text custom-column">
#           <div class="banner__copy">
#             <p class="p1"><span class="s1">Positive. Curious. Creative. Dedicated. Humble. Fun.<br>If this sounds like you, we’d love to have you on our team.</span></p>
#           </div>
#           <div class="banner__cta">
#
#             <span id="hs_cos_wrapper_widget_1600955110978_" class="hs_cos_wrapper hs_cos_wrapper_widget hs_cos_wrapper_type_cta" style="" data-hs-cos-general-type="widget" data-hs-cos-type="cta"><!--HubSpot Call-to-Action Code --><span class="hs-cta-wrapper" id="hs-cta-wrapper-b0baecfc-45a9-407e-bce5-51f4c3da6d78"><span class="hs-cta-node hs-cta-b0baecfc-45a9-407e-bce5-51f4c3da6d78" id="hs-cta-b0baecfc-45a9-407e-bce5-51f4c3da6d78"><!--[if lte IE 8]><div id="hs-cta-ie-element"></div><![endif]--><a href="https://cta-redirect.hubspot.com/cta/redirect/1919336/b0baecfc-45a9-407e-bce5-51f4c3da6d78"><img class="hs-cta-img" id="hs-cta-img-b0baecfc-45a9-407e-bce5-51f4c3da6d78" style="border-width:0px;" src="https://no-cache.hubspot.com/cta/default/1919336/b0baecfc-45a9-407e-bce5-51f4c3da6d78.png" alt="Request a Demo"></a></span><script charset="utf-8" src="/hs/cta/cta/current.js"></script><script type="text/javascript"> hbspt.cta._relativeUrls=true;hbspt.cta.load(1919336, 'b0baecfc-45a9-407e-bce5-51f4c3da6d78', {"region":"na1"}); </script></span><!-- end HubSpot Call-to-Action Code --></span>
#
#
#
#           </div>
#           <img class="accent-right accent hide-lg display animated fadeInRight" src="https://www.applicaster.com/hubfs/Applicaster%20Aug%202019%20Assets/banner_accent_mobile.svg">
#         </div>
#         <div class="banner__img-wrapper banner__img-desktop column-lg-7 custom-column">
#           <div class="banner__img imgoverlap">
#
#             <img src="https://www.applicaster.com/hubfs/Applicaster%20Aug%202019%20Assets/Rectangle.png" class="grey-rhombus grey-rhombus__right-top animated fadeIn slower hide display-md">
#             <img src="https://www.applicaster.com/hubfs/carrers.png" alt="carrers">
#
#           </div>
#         </div>
#       </div>
#     </div>
#   </div>
#   <img src="https://www.applicaster.com/hubfs/Applicaster%20Aug%202019%20Assets/banner_group1@2x.png" class="banner__img-bottomLine pos-relative animated fadeInLeft hide display-md">
# </div></div>
# <div id="hs_cos_wrapper_widget_1600955414679" class="hs_cos_wrapper hs_cos_wrapper_widget hs_cos_wrapper_type_module" style="" data-hs-cos-general-type="widget" data-hs-cos-type="module"><div class="appMgmt-platform pos-relative bg-white animatedParent animateOnce  bottom-spacing">
#   <div class="container animatedParent animateOnce">
#
#     <h2 class="">
#       Great benefits for great people
#     </h2>
#
#     <p style="font-size: 18px;"><span class="s1">At Applicaster, we believe that if you’re working hard for us then we should be working just as hard for you. We offer market-leading benefits at all of our global locations. As with any global company, benefits vary depending on your region. Benefits may include:</span></p>
#     <div class="custom-row appMgmt-platform__slider">
#
#       <div class="custom-column column-md-6 appMgmt-platform-item">
#         <div class="image">
#           <div class="appMgmt-platform__slider-icon ta-center " id="appMgmt-platform__lottie1" data-src="">
#
#
#
#
#             <img src="https://www.applicaster.com/hs-fs/hubfs/vacation-icon@2x.png?width=80&amp;height=79&amp;name=vacation-icon@2x.png" alt="vacation-icon@2x" width="80" height="79" srcset="https://www.applicaster.com/hs-fs/hubfs/vacation-icon@2x.png?width=40&amp;height=40&amp;name=vacation-icon@2x.png 40w, https://www.applicaster.com/hs-fs/hubfs/vacation-icon@2x.png?width=80&amp;height=79&amp;name=vacation-icon@2x.png 80w, https://www.applicaster.com/hs-fs/hubfs/vacation-icon@2x.png?width=120&amp;height=119&amp;name=vacation-icon@2x.png 120w, https://www.applicaster.com/hs-fs/hubfs/vacation-icon@2x.png?width=160&amp;height=158&amp;name=vacation-icon@2x.png 160w, https://www.applicaster.com/hs-fs/hubfs/vacation-icon@2x.png?width=200&amp;height=198&amp;name=vacation-icon@2x.png 200w, https://www.applicaster.com/hs-fs/hubfs/vacation-icon@2x.png?width=240&amp;height=237&amp;name=vacation-icon@2x.png 240w" sizes="(max-width: 80px) 100vw, 80px">
#
#
#           </div>
#         </div>
#         <div class="text">
#           <h4 class="fw-bold">
#
#           </h4>
#           <h3>Take what you need vacation policy</h3>
#         </div>
#       </div>
#
#       <div class="custom-column column-md-6 appMgmt-platform-item">
#         <div class="image">
#           <div class="appMgmt-platform__slider-icon ta-center " id="appMgmt-platform__lottie2" data-src="">
#
#
#
#
#             <img src="https://www.applicaster.com/hs-fs/hubfs/medical-icon@2x.png?width=80&amp;height=79&amp;name=medical-icon@2x.png" alt="medical-icon@2x" width="80" height="79" srcset="https://www.applicaster.com/hs-fs/hubfs/medical-icon@2x.png?width=40&amp;height=40&amp;name=medical-icon@2x.png 40w, https://www.applicaster.com/hs-fs/hubfs/medical-icon@2x.png?width=80&amp;height=79&amp;name=medical-icon@2x.png 80w, https://www.applicaster.com/hs-fs/hubfs/medical-icon@2x.png?width=120&amp;height=119&amp;name=medical-icon@2x.png 120w, https://www.applicaster.com/hs-fs/hubfs/medical-icon@2x.png?width=160&amp;height=158&amp;name=medical-icon@2x.png 160w, https://www.applicaster.com/hs-fs/hubfs/medical-icon@2x.png?width=200&amp;height=198&amp;name=medical-icon@2x.png 200w, https://www.applicaster.com/hs-fs/hubfs/medical-icon@2x.png?width=240&amp;height=237&amp;name=medical-icon@2x.png 240w" sizes="(max-width: 80px) 100vw, 80px">
#
#
#           </div>
#         </div>
#         <div class="text">
#           <h4 class="fw-bold">
#
#           </h4>
#           <h3>Private medical insurance</h3>
#         </div>
#       </div>
#
#       <div class="custom-column column-md-6 appMgmt-platform-item">
#         <div class="image">
#           <div class="appMgmt-platform__slider-icon ta-center " id="appMgmt-platform__lottie3" data-src="">
#
#
#
#
#             <img src="https://www.applicaster.com/hs-fs/hubfs/401-plans-icon@2x.png?width=80&amp;height=79&amp;name=401-plans-icon@2x.png" alt="401-plans-icon@2x" width="80" height="79" srcset="https://www.applicaster.com/hs-fs/hubfs/401-plans-icon@2x.png?width=40&amp;height=40&amp;name=401-plans-icon@2x.png 40w, https://www.applicaster.com/hs-fs/hubfs/401-plans-icon@2x.png?width=80&amp;height=79&amp;name=401-plans-icon@2x.png 80w, https://www.applicaster.com/hs-fs/hubfs/401-plans-icon@2x.png?width=120&amp;height=119&amp;name=401-plans-icon@2x.png 120w, https://www.applicaster.com/hs-fs/hubfs/401-plans-icon@2x.png?width=160&amp;height=158&amp;name=401-plans-icon@2x.png 160w, https://www.applicaster.com/hs-fs/hubfs/401-plans-icon@2x.png?width=200&amp;height=198&amp;name=401-plans-icon@2x.png 200w, https://www.applicaster.com/hs-fs/hubfs/401-plans-icon@2x.png?width=240&amp;height=237&amp;name=401-plans-icon@2x.png 240w" sizes="(max-width: 80px) 100vw, 80px">
#
#
#           </div>
#         </div>
#         <div class="text">
#           <h4 class="fw-bold">
#
#           </h4>
#           <h3>401k (retirement) plans</h3>
#         </div>
#       </div>
#
#       <div class="custom-column column-md-6 appMgmt-platform-item">
#         <div class="image">
#           <div class="appMgmt-platform__slider-icon ta-center " id="appMgmt-platform__lottie4" data-src="">
#
#
#
#
#             <img src="https://www.applicaster.com/hs-fs/hubfs/fsa-icon@2x.png?width=80&amp;height=79&amp;name=fsa-icon@2x.png" alt="fsa-icon@2x" width="80" height="79" srcset="https://www.applicaster.com/hs-fs/hubfs/fsa-icon@2x.png?width=40&amp;height=40&amp;name=fsa-icon@2x.png 40w, https://www.applicaster.com/hs-fs/hubfs/fsa-icon@2x.png?width=80&amp;height=79&amp;name=fsa-icon@2x.png 80w, https://www.applicaster.com/hs-fs/hubfs/fsa-icon@2x.png?width=120&amp;height=119&amp;name=fsa-icon@2x.png 120w, https://www.applicaster.com/hs-fs/hubfs/fsa-icon@2x.png?width=160&amp;height=158&amp;name=fsa-icon@2x.png 160w, https://www.applicaster.com/hs-fs/hubfs/fsa-icon@2x.png?width=200&amp;height=198&amp;name=fsa-icon@2x.png 200w, https://www.applicaster.com/hs-fs/hubfs/fsa-icon@2x.png?width=240&amp;height=237&amp;name=fsa-icon@2x.png 240w" sizes="(max-width: 80px) 100vw, 80px">
#
#
#           </div>
#         </div>
#         <div class="text">
#           <h4 class="fw-bold">
#
#           </h4>
#           <h3>FSA card</h3>
#         </div>
#       </div>
#
#       <div class="custom-column column-md-6 appMgmt-platform-item">
#         <div class="image">
#           <div class="appMgmt-platform__slider-icon ta-center " id="appMgmt-platform__lottie5" data-src="">
#
#
#
#
#             <img src="https://www.applicaster.com/hs-fs/hubfs/life-icon@2x.png?width=80&amp;height=79&amp;name=life-icon@2x.png" alt="life-icon@2x" width="80" height="79" srcset="https://www.applicaster.com/hs-fs/hubfs/life-icon@2x.png?width=40&amp;height=40&amp;name=life-icon@2x.png 40w, https://www.applicaster.com/hs-fs/hubfs/life-icon@2x.png?width=80&amp;height=79&amp;name=life-icon@2x.png 80w, https://www.applicaster.com/hs-fs/hubfs/life-icon@2x.png?width=120&amp;height=119&amp;name=life-icon@2x.png 120w, https://www.applicaster.com/hs-fs/hubfs/life-icon@2x.png?width=160&amp;height=158&amp;name=life-icon@2x.png 160w, https://www.applicaster.com/hs-fs/hubfs/life-icon@2x.png?width=200&amp;height=198&amp;name=life-icon@2x.png 200w, https://www.applicaster.com/hs-fs/hubfs/life-icon@2x.png?width=240&amp;height=237&amp;name=life-icon@2x.png 240w" sizes="(max-width: 80px) 100vw, 80px">
#
#
#           </div>
#         </div>
#         <div class="text">
#           <h4 class="fw-bold">
#
#           </h4>
#           <h3>Life and disability insurance</h3>
#         </div>
#       </div>
#
#       <div class="custom-column column-md-6 appMgmt-platform-item">
#         <div class="image">
#           <div class="appMgmt-platform__slider-icon ta-center " id="appMgmt-platform__lottie6" data-src="">
#
#
#
#
#             <img src="https://www.applicaster.com/hs-fs/hubfs/parental-icon@2x.png?width=80&amp;height=79&amp;name=parental-icon@2x.png" alt="parental-icon@2x" width="80" height="79" srcset="https://www.applicaster.com/hs-fs/hubfs/parental-icon@2x.png?width=40&amp;height=40&amp;name=parental-icon@2x.png 40w, https://www.applicaster.com/hs-fs/hubfs/parental-icon@2x.png?width=80&amp;height=79&amp;name=parental-icon@2x.png 80w, https://www.applicaster.com/hs-fs/hubfs/parental-icon@2x.png?width=120&amp;height=119&amp;name=parental-icon@2x.png 120w, https://www.applicaster.com/hs-fs/hubfs/parental-icon@2x.png?width=160&amp;height=158&amp;name=parental-icon@2x.png 160w, https://www.applicaster.com/hs-fs/hubfs/parental-icon@2x.png?width=200&amp;height=198&amp;name=parental-icon@2x.png 200w, https://www.applicaster.com/hs-fs/hubfs/parental-icon@2x.png?width=240&amp;height=237&amp;name=parental-icon@2x.png 240w" sizes="(max-width: 80px) 100vw, 80px">
#
#
#           </div>
#         </div>
#         <div class="text">
#           <h4 class="fw-bold">
#
#           </h4>
#           <h3>Parental leave</h3>
#         </div>
#       </div>
#
#     </div>
#
#
#
#
#
#   </div>
# </div></div>
# <div id="hs_cos_wrapper_widget_1566354100804" class="hs_cos_wrapper hs_cos_wrapper_widget hs_cos_wrapper_type_module" style="" data-hs-cos-general-type="widget" data-hs-cos-type="module">
# <div class="col2-copySlider-img animatedParent animateOnce padding-top padding-bottom">
#   <div class="container">
#     <div class="col2-copySlider-img__inner">
#
#       <div class="col2-copySlider-img__header ta-md-center ta-left animated fadeIn">
#         <h2>People make the difference</h2>
#       </div>
#
#       <div class="custom-row a-items-center j-content-between animated fadeIn slow">
#         <div class="custom-column column-md-6 order-2">
#           <div class="col2-copySlider-img__imgslider mx-neg-15">
#
#
#             <div class="col2-copySlider-img__image ">
#               <img src="https://www.applicaster.com/hubfs/curious.png" alt="curious">
#             </div>
#
#
#
#             <div class="col2-copySlider-img__image ">
#               <img src="https://www.applicaster.com/hubfs/humble.png" alt="humble">
#             </div>
#
#
#
#             <div class="col2-copySlider-img__image ">
#               <img src="https://www.applicaster.com/hubfs/team.png" alt="team">
#             </div>
#
#
#
#             <div class="col2-copySlider-img__image ">
#               <img src="https://www.applicaster.com/hubfs/destiny.png" alt="destiny">
#             </div>
#
#
#
#             <div class="col2-copySlider-img__image ">
#               <img src="https://www.applicaster.com/hubfs/human.png" alt="human">
#             </div>
#
#
#           </div>
#
#         </div>
#         <div class="custom-column column-md-5 order-1">
#           <div class="col2-copySlider-img__slider">
#
#             <div class="col2-copySlider-img__slider-item">
#               <h3 class="p1"><span class="s1">We’re curious.</span></h3>
# <p class="p1"><span class="s1">“Why?” and “what if?” are questions you’ll hear a lot at Applicaster. We recognize that to question is to explore, and we believe that exploration drives us forward as individuals and as a company.</span></p>
#             </div>
#
#             <div class="col2-copySlider-img__slider-item">
#               <h3 class="p1"><span class="s1">We’re humble.</span></h3>
# <p class="p1"><span class="s1">Despite our successes, we keep our feet firmly planted on the ground, because that’s the only way to keep moving forward. </span></p>
#             </div>
#
#             <div class="col2-copySlider-img__slider-item">
#               <h3 class="p1"><span class="s1">We’re a Team.</span></h3>
# <p class="p1"><span class="s1">We win and (rarely) lose as a team. Collective responsibility and collaboration are not just words at Applicaster, they’re part of our DNA. </span></p>
#             </div>
#
#             <div class="col2-copySlider-img__slider-item">
#               <h3 class="p1"><span class="s1">We own our destiny.</span></h3>
# <p class="p1"><span class="s1">Our destiny lies in our own hands and we accept full responsibility for it. We strive to raise the bar for our products, our teams, and ourselves to one end: <i>customer satisfaction</i>.</span></p>
#             </div>
#
#             <div class="col2-copySlider-img__slider-item">
#               <h3 class="p1"><span class="s1">We are human.</span></h3>
# <p class="p1"><span class="s1">We take an interest in, and embrace each other’s individuality. We stay true to who we are, stand up for what we believe in, and are always respectful of others. </span></p>
#             </div>
#
#           </div>
#         </div>
#       </div>
#     </div>
#   </div>
# </div></div>
# <div id="hs_cos_wrapper_widget_1566354229060" class="hs_cos_wrapper hs_cos_wrapper_widget hs_cos_wrapper_type_module" style="" data-hs-cos-general-type="widget" data-hs-cos-type="module"><div class="career-positions animatedParent animateOnce bg-solitude padding-top pos-relative of-hidden padding-bottom">
#   <img class="accent-bottom-left accent animated fadeIn display-md hide" src="https://www.applicaster.com/hubfs/Applicaster%20Aug%202019%20Assets/accent-4.svg" alt="accent">
#   <img class="accent-top-right accent  animated fadeIn slow display-md hide" src="https://www.applicaster.com/hubfs/Applicaster%20Aug%202019%20Assets/accent-5.svg" alt="accent">
#   <img class="accent-left accent animated fadeIn display hide-md" src="https://www.applicaster.com/hubfs/Applicaster%20Aug%202019%20Assets/accent-6.svg" alt="accent">
#   <img class="accent-right accent  animated fadeIn slow display hide-md" src="https://www.applicaster.com/hubfs/Applicaster%20Aug%202019%20Assets/accent-7.svg" alt="accent">
#   <div class="container">
#     <div class="career-positions__header ta-center ta-md-left animated fadeIn">
#
#       <h2>
#         Open positions
#       </h2>
#
#     </div>
#     <div class="career-positions__listWrapper animated fadeIn green-rectangle-md green-rectangle pos-relative">
#       <div class="career-positions__list pos-relative">
#
#       </div>
#     </div>
#   </div>
# </div>
#
# <script id="careers-template" type="text/x-handlebars-template">
#   {{#each this}}
#   <div class="career-positions__item bg-white">
#           <div class="custom-row a-items-center">
#             <div class="custom-column column-md-9 career-positions__item-header">
#               <div class="career-positions__details">
#                 <div class="career-positions__title d-flex a-items-center ff-prospectus fw-semibold">
#                   {{ name }} {{#if location.city }}<span class="ff-circular fw-bold pos-relative">{{ location.city }}, {{ location.state }}</span>{{/if}}
#                 </div>
#                 {{#if details }}
#                 <div class="career-positions__desc hide display-md">
#                   {{#if details.[2].value }}
#                   {{{ details.[2].value }}}
#                   {{else}}
#                   {{{ details.[0].value }}}
#                   {{/if }}
#                 </div>
#                 {{/if }}
#               </div>
#             </div>
#             <div class="custom-column column-md-3 career-positions__collapse">
#               {{#if details }}
#               <div class="career-positions__desc display hide-md">
#                 {{#if details.[3].value }}
#                 {{{ details.[3].value }}}
#                 {{else}}
#                 {{{ details.[0].value }}}
#                 {{/if }}
#               </div>
#               {{/if }}
#               <div class="career-positions__cta ta-center">
#                 <a class="btn" href="{{ url_active_page }}" target="_blank">
#                   Apply Now
#                 </a>
#               </div>
#             </div>
#           </div>
#         </div>
#         {{/each}}
# </script>
# </div></span>
# </div><!--end widget-span -->
# </div><!--end row-->
# </div><!--end row-wrapper -->
#
#     </div><!--end body -->
# </div><!--end body wrapper -->
#
# <div class="footer-container-wrapper">
#     <div class="footer-container container-fluid">
#
# <div class="row-fluid-wrapper row-depth-1 row-number-1 ">
# <div class="row-fluid ">
# <div class="span12 widget-span widget-type-global_group " style="" data-widget-type="global_group" data-x="0" data-w="12">
# <div class="" data-global-widget-path="generated_global_groups/35301337850.html"><div class="row-fluid-wrapper row-depth-1 row-number-1 ">
# <div class="row-fluid ">
# <div class="span12 widget-span widget-type-cell footer bg-blue" style="" data-widget-type="cell" data-x="0" data-w="12">
#
# <div class="row-fluid-wrapper row-depth-1 row-number-2 ">
# <div class="row-fluid ">
# <div class="span12 widget-span widget-type-cell container" style="" data-widget-type="cell" data-x="0" data-w="12">
#
# <div class="row-fluid-wrapper row-depth-1 row-number-3 ">
# <div class="row-fluid ">
# <div class="span12 widget-span widget-type-cell footer-menu-wrapper" style="" data-widget-type="cell" data-x="0" data-w="12">
#
# <div class="row-fluid-wrapper row-depth-1 row-number-4 ">
# <div class="row-fluid ">
# <div class="span6 widget-span widget-type-custom_widget " style="" data-widget-type="custom_widget" data-x="0" data-w="6">
# <div id="hs_cos_wrapper_module_1564623273204108" class="hs_cos_wrapper hs_cos_wrapper_widget hs_cos_wrapper_type_module widget-type-logo" style="" data-hs-cos-general-type="widget" data-hs-cos-type="module">
#
#
#
#
#   <span id="hs_cos_wrapper_module_1564623273204108_hs_logo_widget" class="hs_cos_wrapper hs_cos_wrapper_widget hs_cos_wrapper_type_logo" style="" data-hs-cos-general-type="widget" data-hs-cos-type="logo"><a href="http://applicaster.com" id="hs-link-module_1564623273204108_hs_logo_widget" style="border-width:0px;border:0px;"><img src="https://www.applicaster.com/hubfs/2017_Website/applicaster%20logo%20white.svg" class="hs-image-widget " style="width:400px;border-width:0px;border:0px;" width="400" alt="applicaster logo white.svg" title="applicaster logo white.svg"></a></span>
#
# </div>
#
# </div><!--end widget-span -->
# <div class="span6 widget-span widget-type-custom_widget footer-socials" style="" data-widget-type="custom_widget" data-x="6" data-w="6">
# <div id="hs_cos_wrapper_module_1564623350392111" class="hs_cos_wrapper hs_cos_wrapper_widget hs_cos_wrapper_type_module widget-type-rich_text" style="" data-hs-cos-general-type="widget" data-hs-cos-type="module"><span id="hs_cos_wrapper_module_1564623350392111_" class="hs_cos_wrapper hs_cos_wrapper_widget hs_cos_wrapper_type_rich_text" style="" data-hs-cos-general-type="widget" data-hs-cos-type="rich_text"><ul class="d-flex a-items-center j-content-center j-content-md-end">
# <li><a href="https://twitter.com/Applicaster?ref_src=twsrc%5Egoogle%7Ctwcamp%5Eserp%7Ctwgr%5Eauthor" rel="noopener" target="_blank"><img src="https://www.applicaster.com/hubfs/Applicaster%20Aug%202019%20Assets/twitter-light.svg"></a></li>
# <li><a href="https://www.facebook.com/applicaster/" rel="noopener" target="_blank"><img src="https://www.applicaster.com/hubfs/Applicaster%20Aug%202019%20Assets/facebook-light.svg"></a></li>
# <li><a href="https://www.youtube.com/channel/UCcUVcIIxenqWdnW0bplNEmw" rel="noopener" target="_blank"><img src="https://www.applicaster.com/hubfs/Applicaster%20Aug%202019%20Assets/youtube-light.svg"></a></li>
# <li><a href="https://www.linkedin.com/company/applicaster-ltd/" rel="noopener" target="_blank"><img src="https://www.applicaster.com/hubfs/Applicaster%20Aug%202019%20Assets/LinkedIn.svg"></a></li>
# </ul></span></div>
#
# </div><!--end widget-span -->
# </div><!--end row-->
# </div><!--end row-wrapper -->
#
# <div class="row-fluid-wrapper row-depth-1 row-number-5 ">
# <div class="row-fluid ">
# <div class="span12 widget-span widget-type-custom_widget footer-menu hide display-md" style="" data-widget-type="custom_widget" data-x="0" data-w="12">
# <div id="hs_cos_wrapper_module_1564623498522142" class="hs_cos_wrapper hs_cos_wrapper_widget hs_cos_wrapper_type_module widget-type-menu" style="" data-hs-cos-general-type="widget" data-hs-cos-type="module">
# <span id="hs_cos_wrapper_module_1564623498522142_" class="hs_cos_wrapper hs_cos_wrapper_widget hs_cos_wrapper_type_menu" style="" data-hs-cos-general-type="widget" data-hs-cos-type="menu"><div id="hs_menu_wrapper_module_1564623498522142_" class="hs-menu-wrapper active-branch flyouts hs-menu-flow-horizontal" role="navigation" data-sitemap-name="default" data-menu-id="35293407662" aria-label="Navigation Menu">
#  <ul role="menu" class="active-branch">
#   <li class="hs-menu-item hs-menu-depth-1" role="none"><a href="https://www.applicaster.com/platform" role="menuitem">Platform</a></li>
#   <li class="hs-menu-item hs-menu-depth-1" role="none"><a href="https://www.applicaster.com/case-studies" role="menuitem">Case Studies</a></li>
#   <li class="hs-menu-item hs-menu-depth-1" role="none"><a href="https://applicaster.zendesk.com/hc/en-us" role="menuitem">Support</a></li>
#   <li class="hs-menu-item hs-menu-depth-1" role="none"><a href="https://www.applicaster.com/apis" role="menuitem">API's</a></li>
#   <li class="hs-menu-item hs-menu-depth-1" role="none"><a href="https://www.applicaster.com/about-us" role="menuitem">About Us</a></li>
#   <li class="hs-menu-item hs-menu-depth-1 active active-branch" role="none"><a href="https://www.applicaster.com/careers" role="menuitem">Careers</a></li>
#   <li class="hs-menu-item hs-menu-depth-1" role="none"><a href="https://developer.applicaster.com/" role="menuitem">Developers</a></li>
#   <li class="hs-menu-item hs-menu-depth-1" role="none"><a href="https://www.applicaster.com/fast-forward-solutions" role="menuitem">Fast Forward solutions</a></li>
#   <li class="hs-menu-item hs-menu-depth-1" role="none"><a href="https://www.applicaster.com/apple-certified" role="menuitem">Apple approved</a></li>
#   <li class="hs-menu-item hs-menu-depth-1" role="none"><a href="https://www.applicaster.com/launch-on-roku" role="menuitem">Roku channels</a></li>
#  </ul>
# </div></span></div>
#
# </div><!--end widget-span -->
# </div><!--end row-->
# </div><!--end row-wrapper -->
#
# </div><!--end widget-span -->
# </div><!--end row-->
# </div><!--end row-wrapper -->
#
# <div class="row-fluid-wrapper row-depth-1 row-number-6 ">
# <div class="row-fluid ">
# <div class="span12 widget-span widget-type-custom_widget hide display-md" style="" data-widget-type="custom_widget" data-x="0" data-w="12">
# <div id="hs_cos_wrapper_module_1564624529401232" class="hs_cos_wrapper hs_cos_wrapper_widget hs_cos_wrapper_type_module" style="" data-hs-cos-general-type="widget" data-hs-cos-type="module"><div class="footer-locations">
#   <div class="custom-row">
#     <div class="custom-column column-md-3">
#       <div class="footer-locations__heading c-white footer-title">
#         SALES INQUIRIES
#       </div>
#       <div class="footer-phone c-white">
#           <p>Fill out <strong><a href="https://www.applicaster.com/request-demo" rel="noopener" target="_blank">this</a></strong> form</p>
#       </div>
#     </div>
#     <div class="custom-column column-md-9">
#       <div class="footer-locations__heading c-white footer-title">
#         OUR OFFICES
#       </div>
#       <div class="custom-row footer-location__wrap">
#
#         <div class="custom-column column-lg-4 column-md-6">
#           <div class="footer-location__item c-white">
#             <div class="footer-location__title uppercase">
#               NEW YORK
#             </div>
#             <div class="footer-location__address">
#               1410 Broadway<br>New York, NY 10018 USA
#             </div>
#           </div>
#         </div>
#
#         <div class="custom-column column-lg-4 column-md-6">
#           <div class="footer-location__item c-white">
#             <div class="footer-location__title uppercase">
#               MIAMI
#             </div>
#             <div class="footer-location__address">
#               1101 Brickell Ave<br>Miami, FL 33131 USA
#             </div>
#           </div>
#         </div>
#
#         <div class="custom-column column-lg-4 column-md-6">
#           <div class="footer-location__item c-white">
#             <div class="footer-location__title uppercase">
#               LOS ANGELES
#             </div>
#             <div class="footer-location__address">
#               10100 Santa Monica Blvd<br>Los Angeles, CA 90067 USA
#             </div>
#           </div>
#         </div>
#
#         <div class="custom-column column-lg-4 column-md-6">
#           <div class="footer-location__item c-white">
#             <div class="footer-location__title uppercase">
#               SAN JOSE
#             </div>
#             <div class="footer-location__address">
#               333 W. San Carlos St., #6140<br>San Jose, CA 95110 USA
#             </div>
#           </div>
#         </div>
#
#         <div class="custom-column column-lg-4 column-md-6">
#           <div class="footer-location__item c-white">
#             <div class="footer-location__title uppercase">
#               LONDON
#             </div>
#             <div class="footer-location__address">
#               37 Broadhurst Gardens<br>London, NW6 3QT
#             </div>
#           </div>
#         </div>
#
#         <div class="custom-column column-lg-4 column-md-6">
#           <div class="footer-location__item c-white">
#             <div class="footer-location__title uppercase">
#               TEL AVIV
#             </div>
#             <div class="footer-location__address">
#               124 Ibn Gabirol St, 9th Fl<br>Tel Aviv, 6203854 Israel
#             </div>
#           </div>
#         </div>
#
#       </div>
#     </div>
#   </div>
# </div></div>
#
# </div><!--end widget-span -->
# </div><!--end row-->
# </div><!--end row-wrapper -->
#
# <div class="row-fluid-wrapper row-depth-1 row-number-7 ">
# <div class="row-fluid ">
# <div class="span12 widget-span widget-type-cell footer-copyright" style="" data-widget-type="cell" data-x="0" data-w="12">
#
# <div class="row-fluid-wrapper row-depth-1 row-number-8 ">
# <div class="row-fluid ">
# <div class="span6 widget-span widget-type-custom_widget c-white ta-center ta-md-left" style="" data-widget-type="custom_widget" data-x="0" data-w="6">
# <div id="hs_cos_wrapper_module_1564624634164234" class="hs_cos_wrapper hs_cos_wrapper_widget hs_cos_wrapper_type_module widget-type-text" style="" data-hs-cos-general-type="widget" data-hs-cos-type="module"><span id="hs_cos_wrapper_module_1564624634164234_" class="hs_cos_wrapper hs_cos_wrapper_widget hs_cos_wrapper_type_text" style="" data-hs-cos-general-type="widget" data-hs-cos-type="text">© 2021 Applicaster, All rights reserved.</span></div>
#
# </div><!--end widget-span -->
# <div class="span6 widget-span widget-type-custom_widget ta-right hide display-md" style="" data-widget-type="custom_widget" data-x="6" data-w="6">
# <div id="hs_cos_wrapper_module_1564701978245336" class="hs_cos_wrapper hs_cos_wrapper_widget hs_cos_wrapper_type_module widget-type-rich_text" style="" data-hs-cos-general-type="widget" data-hs-cos-type="module"><span id="hs_cos_wrapper_module_1564701978245336_" class="hs_cos_wrapper hs_cos_wrapper_widget hs_cos_wrapper_type_rich_text" style="" data-hs-cos-general-type="widget" data-hs-cos-type="rich_text"><a href="/privacy-security" rel=" noopener" class="c-green"><span class="s1">Privacy and Security</span></a></span></div>
#
# </div><!--end widget-span -->
# </div><!--end row-->
# </div><!--end row-wrapper -->
#
# </div><!--end widget-span -->
# </div><!--end row-->
# </div><!--end row-wrapper -->
#
# </div><!--end widget-span -->
# </div><!--end row-->
# </div><!--end row-wrapper -->
#
# </div><!--end widget-span -->
# </div><!--end row-->
# </div><!--end row-wrapper -->
# </div>
# </div><!--end widget-span -->
# </div><!--end row-->
# </div><!--end row-wrapper -->
#
#     </div><!--end footer -->
# </div><!--end footer wrapper -->
#
#
# <script>
# (function () {
#     window.addEventListener('load', function () {
#         setTimeout(function () {
#             var xhr = new XMLHttpRequest();
#             xhr.open('POST', '/_hcms/perf', true /*async*/);
#             xhr.setRequestHeader("Content-type", "application/json");
#             xhr.onreadystatechange = function () {
#                 // do nothing.
#             };
#             var connection = navigator.connection || navigator.mozConnection || navigator.webkitConnection;
#             function populateNetworkInfo(name, connection, info) {
#                 if (name in connection) {
#                     info[name] = connection[name];
#                 }
#             }
#             var networkInfo = {};
#             if (connection) {
#                 ['type', 'effectiveType', 'downlink', 'rtt'].forEach(function(name) {
#                     populateNetworkInfo(name, connection, networkInfo);
#                 });
#             }
#             var perfData = {
#                 url: location.href,
#                 portal: 1919336,
#                 content: 34961382829,
#                 group: -1,
#                 connection: networkInfo,
#                 timing: performance.timing
#             };
#             xhr.send(JSON.stringify(perfData));
#         }, 3000);  // Execute this 3 seconds after onload.
#     });
# })();
# </script>
#
# <script src="https://www.applicaster.com/hs-fs/hub/1919336/hub_generated/template_assets/11781559782/1620319843135/Coded_files/Custom/page/Applicaster_2019_S2/s2-script.js"></script>
# <script>
# if (typeof hsVars !== 'undefined') { hsVars['language'] = 'en'; }
# </script>
#
# <script src="/hs/hsstatic/cos-i18n/static-1.27/bundles/project.js"></script>
# <script src="/hs/hsstatic/keyboard-accessible-menu-flyouts/static-1.17/bundles/project.js"></script>
# <script src="https://www.applicaster.com/hs-fs/hub/1919336/hub_generated/module_assets/34711567328/1600899404482/module_34711567328_Banner_-_v2.min.js"></script>
# <script src="https://www.applicaster.com/hs-fs/hub/1919336/hub_generated/module_assets/35233170497/1600901582512/module_35233170497_Platform_App_Mgmt_Slider_-_v2.min.js"></script>
# <script src="https://www.applicaster.com/hs-fs/hub/1919336/hub_generated/module_assets/1600699635243/module_12251805651_2_Col_-_Slider_Copy_and_Image.js"></script>
# <script src="https://www.applicaster.com/hubfs/handlebars.min.js"></script>
# <script src="https://www.applicaster.com/hs-fs/hub/1919336/hub_generated/module_assets/1570820954396/module_12280678332_Custom_modules_Applicaster_2019_S2_Career_Positions.js"></script>
#
# <!-- Start of HubSpot Analytics Code -->
# <script type="text/javascript">
# var _hsq = _hsq || [];
# _hsq.push(["setContentType", "standard-page"]);
# _hsq.push(["setCanonicalUrl", "https:\/\/www.applicaster.com\/careers"]);
# _hsq.push(["setPageId", "34961382829"]);
# _hsq.push(["setContentMetadata", {
#     "contentPageId": 34961382829,
#     "legacyPageId": "34961382829",
#     "contentFolderId": null,
#     "contentGroupId": null,
#     "abTestId": null,
#     "languageVariantId": 34961382829,
#     "languageCode": null,
#
# }]);
# </script>
#
# <script type="text/javascript" id="hs-script-loader" async defer src="/hs/scriptloader/1919336.js"></script>
# <!-- End of HubSpot Analytics Code -->
#
#
# <script type="text/javascript">
# var hsVars = {
#     ticks: 1623683093133,
#     page_id: 34961382829,
#
#     content_group_id: 0,
#     portal_id: 1919336,
#     app_hs_base_url: "https://app.hubspot.com",
#     cp_hs_base_url: "https://cp.hubspot.com",
#     language: "en",
#     analytics_page_type: "standard-page",
#     analytics_page_id: "34961382829",
#     category_id: 1,
#     folder_id: 0,
#     is_hubspot_user: false
# }
# </script>
#
#
# <script defer src="/hs/hsstatic/HubspotToolsMenu/static-1.103/js/index.js"></script>
#
# <!-- Google Tag Manager (noscript) -->
# <noscript><iframe src="https://www.googletagmanager.com/ns.html?id=GTM-MSFHXLL" height="0" width="0" style="display:none;visibility:hidden"></iframe></noscript>
# <!-- End Google Tag Manager (noscript) -->
#
# <!-- Facebook Pixel Code -->
# <script>
# !function(f,b,e,v,n,t,s){if(f.fbq)return;n=f.fbq=function(){n.callMethod?
# n.callMethod.apply(n,arguments):n.queue.push(arguments)};if(!f._fbq)f._fbq=n;
# n.push=n;n.loaded=!0;n.version='2.0';n.queue=[];t=b.createElement(e);t.async=!0;
# t.src=v;s=b.getElementsByTagName(e)[0];s.parentNode.insertBefore(t,s)}(window,
# document,'script','https://connect.facebook.net/en_US/fbevents.js');
# fbq('init', '1998947433673474'); // Insert your pixel ID here.
# fbq('track', 'PageView');
# </script>
# <noscript><img height="1" width="1" style="display:none" src="https://www.facebook.com/tr?id=1998947433673474&amp;ev=PageView&amp;noscript=1"></noscript>
# <!-- DO NOT MODIFY -->
# <!-- End Facebook Pixel Code -->
#
#
#
# <script type="text/javascript"> _linkedin_partner_id = "958689"; window._linkedin_data_partner_ids = window._linkedin_data_partner_ids || []; window._linkedin_data_partner_ids.push(_linkedin_partner_id); </script><script type="text/javascript"> (function(){var s = document.getElementsByTagName("script")[0]; var b = document.createElement("script"); b.type = "text/javascript";b.async = true; b.src = "https://snap.licdn.com/li.lms-analytics/insight.min.js"; s.parentNode.insertBefore(b, s);})(); </script> <noscript> <img height="1" width="1" style="display:none;" alt="" src="https://dc.ads.linkedin.com/collect/?pid=958689&amp;fmt=gif"> </noscript>
# <script type="text/javascript"> _linkedin_data_partner_id = "68246"; </script><script type="text/javascript"> (function(){var s = document.getElementsByTagName("script")[0]; var b = document.createElement("script"); b.type = "text/javascript";b.async = true; b.src = "https://snap.licdn.com/li.lms-analytics/insight.min.js"; s.parentNode.insertBefore(b, s);})(); </script> <noscript> <img height="1" width="1" style="display:none;" alt="" src="https://dc.ads.linkedin.com/collect/?pid=68246&amp;fmt=gif"> </noscript>
# <link rel="stylesheet" type="text/css" href="/_hcms/raw-resource?path=Coded%20files/Custom/page/css/domain_fonts.css&amp;portalId=1919336&amp;t=1568132048655">
#
#
#     <script src="https://www.applicaster.com/hubfs/Applicaster%20Aug%202019%20Assets/js/lottie.min.js"></script>
# <script src="https://www.applicaster.com/hubfs/Applicaster%20Aug%202019%20Assets/js/css3-animate-it.js"></script>
#     <!-- Generated by the HubSpot Template Builder - template version 1.03 -->
#
# </body></html>

# %% [markdown]
# # PARSING

# %%
import bs4

from bs4 import BeautifulSoup

# %% [markdown]
# ADDITIONAL FUNCTIONS

# %% [markdown]
# # get_country
# get_country returns the country of a city or the country itself if it is a country
# Whatever the input language, answer is returned in english

# %%
from geopy.geocoders import Nominatim
 
geolocator = Nominatim(user_agent = "geoapiExercises")

def get_country(place):
    res = str(geolocator.geocode(place, language = "en"))
    country = res.split(',')[-1]
    return country

# %%
soup = BeautifulSoup(source, 'html.parser')

print(soup.prettify())
# Out:
# <!DOCTYPE html>
# <!--[if lt IE 7]> <html class="no-js lt-ie9 lt-ie8 lt-ie7" lang="en" > <![endif]-->
# <!--[if IE 7]>    <html class="no-js lt-ie9 lt-ie8" lang="en" >        <![endif]-->
# <!--[if IE 8]>    <html class="no-js lt-ie9" lang="en" >               <![endif]-->
# <!--[if gt IE 8]><!-->
# <html class="no-js" lang="en">
#  <!--<![endif]-->
#  <head>
#   <meta charset="utf-8"/>
#   <meta content="IE=edge,chrome=1" http-equiv="X-UA-Compatible"/>
#   <meta content="Applicaster" name="author"/>
#   <meta content="We’re hiring. Tech jobs. Developer jobs. Sales jobs. We want to talk to excellent techies and highly successful salespeople." name="description"/>
#   <meta content="HubSpot" name="generator"/>
#   <title>
#    Careers | Applicaster
#   </title>
#   <link href="https://www.applicaster.com/hubfs/Applicaster_Nov_2016/Image/favicon.png" rel="shortcut icon"/>
#   <script src="/hs/hsstatic/jquery-libs/static-1.1/jquery/jquery-1.7.1.js">
#   </script>
#   <script>
#    hsjQuery = window['jQuery'];
#   </script>
#   <meta content="We’re hiring. Tech jobs. Developer jobs. Sales jobs. We want to talk to excellent techies and highly successful salespeople." property="og:description"/>
#   <meta content="Careers | Applicaster" property="og:title"/>
#   <meta content="We’re hiring. Tech jobs. Developer jobs. Sales jobs. We want to talk to excellent techies and highly successful salespeople." name="twitter:description"/>
#   <meta content="Careers | Applicaster" name="twitter:title"/>
#   <style>
#    a.cta_button{-moz-box-sizing:content-box !important;-webkit-box-sizing:content-box !important;box-sizing:content-box !important;vertical-align:middle}.hs-breadcrumb-menu{list-style-type:none;margin:0px 0px 0px 0px;padding:0px 0px 0px 0px}.hs-breadcrumb-menu-item{float:left;padding:10px 0px 10px 10px}.hs-breadcrumb-menu-divider:before{content:'›';padding-left:10px}.hs-featured-image-link{border:0}.hs-featured-image{float:right;margin:0 0 20px 20px;max-width:50%}@media (max-width: 568px){.hs-featured-image{float:none;margin:0;width:100%;max-width:100%}}.hs-screen-reader-text{clip:rect(1px, 1px, 1px, 1px);height:1px;overflow:hidden;position:absolute !important;width:1px}
#   </style>
#   <link href="https://www.applicaster.com/hs-fs/hub/1919336/hub_generated/module_assets/34711567328/1600899404625/module_34711567328_Banner_-_v2.min.css" rel="stylesheet"/>
#   <link href="https://www.applicaster.com/hs-fs/hub/1919336/hub_generated/module_assets/35233170497/1600901582584/module_35233170497_Platform_App_Mgmt_Slider_-_v2.min.css" rel="stylesheet"/>
#   <link href="https://www.applicaster.com/hs-fs/hub/1919336/hub_generated/module_assets/12251805651/1600699635315/module_12251805651_2_Col_-_Slider_Copy_and_Image.min.css" rel="stylesheet"/>
#   <link href="https://www.applicaster.com/hs-fs/hub/1919336/hub_generated/module_assets/1570820954480/module_12280678332_Custom_modules_Applicaster_2019_S2_Career_Positions.min.css" rel="stylesheet"/>
#   <link href="https://www.applicaster.com/careers" rel="canonical"/>
#   <meta content="width=device-width, initial-scale=1" name="viewport"/>
#   <!-- Google Tag Manager -->
#   <script>
#    (function(w,d,s,l,i){w[l]=w[l]||[];w[l].push({'gtm.start':
# new Date().getTime(),event:'gtm.js'});var f=d.getElementsByTagName(s)[0],
# j=d.createElement(s),dl=l!='dataLayer'?'&l='+l:'';j.async=true;j.src=
# 'https://www.googletagmanager.com/gtm.js?id='+i+dl;f.parentNode.insertBefore(j,f);
# })(window,document,'script','dataLayer','GTM-MSFHXLL');
#   </script>
#   <!-- End Google Tag Manager -->
#   <script language="javascript" type="text/javascript">
#    ;
#   var sf14gv = 18462;
#   (function() {
#     var sf14g = document.createElement('script'); sf14g.type = 'text/javascript'; sf14g.async = true;
#     sf14g.src = ('https:' == document.location.protocol ? 'https://' : 'http://') + 't.sf14g.com/sf14g.js';
#     var s = document.getElementsByTagName('script')[0]; s.parentNode.insertBefore(sf14g, s);
#   })();
#   </script>
#   <meta content="Rq7kzoNa2rgFVGTFyNDdTs4gk5SazE-Orl7O1-zuILo" name="google-site-verification"/>
#   <meta content="https://www.applicaster.com/careers" property="og:url"/>
#   <meta content="summary" name="twitter:card"/>
#   <link href="//cdn2.hubspot.net/hub/7052064/hub_generated/template_assets/1623444889189/hubspot/hubspot_default/shared/responsive/layout.min.css" rel="stylesheet"/>
#   <link href="https://www.applicaster.com/hs-fs/hub/1919336/hub_generated/template_assets/34705417867/1620334362291/Templates/Custom/Page/Applicaster_2020_-_s2/s2-style-v2.min.css" rel="stylesheet"/>
#   <script src="https://unpkg.com/scrollreveal">
#   </script>
#   <script src="https://cdnjs.cloudflare.com/ajax/libs/slick-carousel/1.9.0/slick.min.js">
#   </script>
#   <link href="https://cdnjs.cloudflare.com/ajax/libs/slick-carousel/1.9.0/slick.min.css" rel="stylesheet" type="text/css"/>
#   <!--[if lte IE 9]>
# <link rel="stylesheet" type="text/css" href="https://cdn2.hubspot.net/hubfs/1919336/Applicaster%20Aug%202019%20Assets/css/animations-ie-fix.css">
# <![endif]-->
#   <link href="https://www.applicaster.com/hubfs/Applicaster%20Aug%202019%20Assets/css/animations.css" rel="stylesheet" type="text/css"/>
#  </head>
#  <body class="general hs-content-id-34961382829 hs-site-page page" style="">
#   <div class="header-container-wrapper">
#    <div class="header-container container-fluid">
#     <div class="row-fluid-wrapper row-depth-1 row-number-1">
#      <div class="row-fluid">
#       <div class="span12 widget-span widget-type-global_group" data-w="12" data-widget-type="global_group" data-x="0" style="">
#        <div class="" data-global-widget-path="generated_global_groups/35293518671.html">
#         <div class="row-fluid-wrapper row-depth-1 row-number-1">
#          <div class="row-fluid">
#           <div class="span12 widget-span widget-type-cell header bg-white" data-w="12" data-widget-type="cell" data-x="0" style="">
#            <div class="row-fluid-wrapper row-depth-1 row-number-2">
#             <div class="row-fluid">
#              <div class="span12 widget-span widget-type-cell header-wrapper" data-w="12" data-widget-type="cell" data-x="0" style="">
#               <div class="row-fluid-wrapper row-depth-1 row-number-3">
#                <div class="row-fluid">
#                 <div class="span4 widget-span widget-type-custom_widget" data-w="4" data-widget-type="custom_widget" data-x="0" style="">
#                  <div class="hs_cos_wrapper hs_cos_wrapper_widget hs_cos_wrapper_type_module widget-type-logo" data-hs-cos-general-type="widget" data-hs-cos-type="module" id="hs_cos_wrapper_module_15646223506968" style="">
#                   <span class="hs_cos_wrapper hs_cos_wrapper_widget hs_cos_wrapper_type_logo" data-hs-cos-general-type="widget" data-hs-cos-type="logo" id="hs_cos_wrapper_module_15646223506968_hs_logo_widget" style="">
#                    <a href="http://applicaster.com" id="hs-link-module_15646223506968_hs_logo_widget" style="border-width:0px;border:0px;">
#                     <img alt="applicaster logo blue" class="hs-image-widget" src="https://www.applicaster.com/hubfs/Applicaster%20Aug%202019%20Assets/applicaster%20logo%20blue.svg" style="width:199px;border-width:0px;border:0px;" title="applicaster logo blue" width="199"/>
#                    </a>
#                   </span>
#                  </div>
#                 </div>
#                 <!--end widget-span -->
#                 <div class="span8 widget-span widget-type-cell header-nav bg-blue" data-w="8" data-widget-type="cell" data-x="4" style="">
#                  <div class="row-fluid-wrapper row-depth-1 row-number-4">
#                   <div class="row-fluid">
#                    <div class="span12 widget-span widget-type-custom_widget header-menu" data-w="12" data-widget-type="custom_widget" data-x="0" style="">
#                     <div class="hs_cos_wrapper hs_cos_wrapper_widget hs_cos_wrapper_type_module widget-type-menu" data-hs-cos-general-type="widget" data-hs-cos-type="module" id="hs_cos_wrapper_module_156462240271810" style="">
#                      <span class="hs_cos_wrapper hs_cos_wrapper_widget hs_cos_wrapper_type_menu" data-hs-cos-general-type="widget" data-hs-cos-type="menu" id="hs_cos_wrapper_module_156462240271810_" style="">
#                       <div aria-label="Navigation Menu" class="hs-menu-wrapper active-branch flyouts hs-menu-flow-horizontal" data-menu-id="45772263050" data-sitemap-name="default" id="hs_menu_wrapper_module_156462240271810_" role="navigation">
#                        <ul role="menu">
#                         <li class="hs-menu-item hs-menu-depth-1" role="none">
#                          <a href="https://www.applicaster.com/platform" role="menuitem">
#                           Platform
#                          </a>
#                         </li>
#                         <li class="hs-menu-item hs-menu-depth-1 hs-item-has-children" role="none">
#                          <a aria-expanded="false" aria-haspopup="true" href="javascript:;" role="menuitem">
#                           Solutions
#                          </a>
#                          <ul class="hs-menu-children-wrapper" role="menu">
#                           <li class="hs-menu-item hs-menu-depth-2" role="none">
#                            <a href="https://www.applicaster.com/broadcasters" role="menuitem">
#                             Broadcasters
#                            </a>
#                           </li>
#                           <li class="hs-menu-item hs-menu-depth-2" role="none">
#                            <a href="https://www.applicaster.com/sports" role="menuitem">
#                             Sports
#                            </a>
#                           </li>
#                           <li class="hs-menu-item hs-menu-depth-2" role="none">
#                            <a href="https://www.applicaster.com/kids" role="menuitem">
#                             Kids
#                            </a>
#                           </li>
#                           <li class="hs-menu-item hs-menu-depth-2" role="none">
#                            <a href="https://www.applicaster.com/fitness" role="menuitem">
#                             Fitness
#                            </a>
#                           </li>
#                          </ul>
#                         </li>
#                         <li class="hs-menu-item hs-menu-depth-1" role="none">
#                          <a href="https://www.applicaster.com/ui" role="menuitem">
#                           UI
#                          </a>
#                         </li>
#                         <li class="hs-menu-item hs-menu-depth-1" role="none">
#                          <a href="https://www.applicaster.com/apis" role="menuitem">
#                           Partner APIs
#                          </a>
#                         </li>
#                         <li class="hs-menu-item hs-menu-depth-1" role="none">
#                          <a href="https://www.applicaster.com/case-studies" role="menuitem">
#                           Case Studies
#                          </a>
#                         </li>
#                         <li class="hs-menu-item hs-menu-depth-1" role="none">
#                          <a href="https://www.applicaster.com/pricing" role="menuitem">
#                           Pricing
#                          </a>
#                         </li>
#                         <li class="hs-menu-item hs-menu-depth-1" role="none">
#                          <a href="https://www.applicaster.com/resources" role="menuitem">
#                           Resources
#                          </a>
#                         </li>
#                         <li class="hs-menu-item hs-menu-depth-1" role="none">
#                          <a href="https://www.applicaster.com/about-us" role="menuitem">
#                           About Us
#                          </a>
#                         </li>
#                         <li class="hs-menu-item hs-menu-depth-1" role="none">
#                          <a href="https://zapp.applicaster.com" role="menuitem">
#                           Sign In
#                          </a>
#                         </li>
#                        </ul>
#                       </div>
#                      </span>
#                     </div>
#                    </div>
#                    <!--end widget-span -->
#                   </div>
#                   <!--end row-->
#                  </div>
#                  <!--end row-wrapper -->
#                  <div class="row-fluid-wrapper row-depth-1 row-number-5">
#                   <div class="row-fluid">
#                    <div class="span12 widget-span widget-type-cell header-mobile-menu bg-darkblue display hide-md" data-w="12" data-widget-type="cell" data-x="0" style="">
#                     <div class="row-fluid-wrapper row-depth-2 row-number-1">
#                      <div class="row-fluid">
#                       <div class="span12 widget-span widget-type-custom_widget header-social" data-w="12" data-widget-type="custom_widget" data-x="0" style="">
#                        <div class="hs_cos_wrapper hs_cos_wrapper_widget hs_cos_wrapper_type_module widget-type-rich_text" data-hs-cos-general-type="widget" data-hs-cos-type="module" id="hs_cos_wrapper_module_1564711284489593" style="">
#                         <span class="hs_cos_wrapper hs_cos_wrapper_widget hs_cos_wrapper_type_rich_text" data-hs-cos-general-type="widget" data-hs-cos-type="rich_text" id="hs_cos_wrapper_module_1564711284489593_" style="">
#                          <ul class="d-flex a-items-center no-list-style">
#                           <li>
#                            <a href="https://twitter.com/Applicaster?ref_src=twsrc%5Egoogle%7Ctwcamp%5Eserp%7Ctwgr%5Eauthor" rel="noopener" target="_blank">
#                             <img src="https://www.applicaster.com/hubfs/Applicaster%20Aug%202019%20Assets/twitter-light.svg"/>
#                            </a>
#                           </li>
#                           <li>
#                            <a href="https://www.facebook.com/applicaster/" rel="noopener" target="_blank">
#                             <img src="https://www.applicaster.com/hubfs/Applicaster%20Aug%202019%20Assets/facebook-light.svg"/>
#                            </a>
#                           </li>
#                           <li>
#                            <a href="https://www.youtube.com/channel/UCcUVcIIxenqWdnW0bplNEmw" rel="noopener" target="_blank">
#                             <img src="https://www.applicaster.com/hubfs/Applicaster%20Aug%202019%20Assets/youtube-light.svg"/>
#                            </a>
#                           </li>
#                           <li>
#                            <a href="https://www.linkedin.com/company/applicaster-ltd/" rel="noopener" target="_blank">
#                             <img src="https://www.applicaster.com/hubfs/Applicaster%20Aug%202019%20Assets/LI-In-Bug-light.png"/>
#                            </a>
#                           </li>
#                          </ul>
#                         </span>
#                        </div>
#                       </div>
#                       <!--end widget-span -->
#                      </div>
#                      <!--end row-->
#                     </div>
#                     <!--end row-wrapper -->
#                     <div class="row-fluid-wrapper row-depth-2 row-number-2">
#                      <div class="row-fluid">
#                       <div class="span12 widget-span widget-type-custom_widget" data-w="12" data-widget-type="custom_widget" data-x="0" style="">
#                        <div class="hs_cos_wrapper hs_cos_wrapper_widget hs_cos_wrapper_type_module widget-type-menu" data-hs-cos-general-type="widget" data-hs-cos-type="module" id="hs_cos_wrapper_module_1564711371002625" style="">
#                         <span class="hs_cos_wrapper hs_cos_wrapper_widget hs_cos_wrapper_type_menu" data-hs-cos-general-type="widget" data-hs-cos-type="menu" id="hs_cos_wrapper_module_1564711371002625_" style="">
#                          <div aria-label="Navigation Menu" class="hs-menu-wrapper active-branch flyouts hs-menu-flow-vertical" data-menu-id="34735700898" data-sitemap-name="default" id="hs_menu_wrapper_module_1564711371002625_" role="navigation">
#                           <ul role="menu">
#                            <li class="hs-menu-item hs-menu-depth-1" role="none">
#                             <a href="https://www.applicaster.com/platform" role="menuitem">
#                              Platform
#                             </a>
#                            </li>
#                            <li class="hs-menu-item hs-menu-depth-1" role="none">
#                             <a href="https://www.applicaster.com/ui" role="menuitem">
#                              UI
#                             </a>
#                            </li>
#                            <li class="hs-menu-item hs-menu-depth-1 hs-item-has-children" role="none">
#                             <a aria-expanded="false" aria-haspopup="true" href="javascript:;" role="menuitem">
#                              Solutions
#                             </a>
#                             <ul class="hs-menu-children-wrapper" role="menu">
#                              <li class="hs-menu-item hs-menu-depth-2" role="none">
#                               <a href="https://www.applicaster.com/broadcasters" role="menuitem">
#                                Broadcasters
#                               </a>
#                              </li>
#                              <li class="hs-menu-item hs-menu-depth-2" role="none">
#                               <a href="https://www.applicaster.com/kids" role="menuitem">
#                                Kids
#                               </a>
#                              </li>
#                              <li class="hs-menu-item hs-menu-depth-2" role="none">
#                               <a href="https://www.applicaster.com/sports" role="menuitem">
#                                Sports
#                               </a>
#                              </li>
#                              <li class="hs-menu-item hs-menu-depth-2" role="none">
#                               <a href="https://www.applicaster.com/fitness" role="menuitem">
#                                Fitness
#                               </a>
#                              </li>
#                             </ul>
#                            </li>
#                            <li class="hs-menu-item hs-menu-depth-1" role="none">
#                             <a href="https://www.applicaster.com/apis" role="menuitem">
#                              Partner APIs
#                             </a>
#                            </li>
#                            <li class="hs-menu-item hs-menu-depth-1" role="none">
#                             <a href="https://www.applicaster.com/case-studies" role="menuitem">
#                              Case Studies
#                             </a>
#                            </li>
#                            <li class="hs-menu-item hs-menu-depth-1" role="none">
#                             <a href="https://www.applicaster.com/pricing" role="menuitem">
#                              Pricing
#                             </a>
#                            </li>
#                            <li class="hs-menu-item hs-menu-depth-1" role="none">
#                             <a href="https://www.applicaster.com/resources" role="menuitem">
#                              Resources
#                             </a>
#                            </li>
#                            <li class="hs-menu-item hs-menu-depth-1" role="none">
#                             <a href="https://www.applicaster.com/about-us" role="menuitem">
#                              About Us
#                             </a>
#                            </li>
#                            <li class="hs-menu-item hs-menu-depth-1" role="none">
#                             <a href="https://zapp.applicaster.com" role="menuitem">
#                              Sign In
#                             </a>
#                            </li>
#                           </ul>
#                          </div>
#                         </span>
#                        </div>
#                       </div>
#                       <!--end widget-span -->
#                      </div>
#                      <!--end row-->
#                     </div>
#                     <!--end row-wrapper -->
#                    </div>
#                    <!--end widget-span -->
#                   </div>
#                   <!--end row-->
#                  </div>
#                  <!--end row-wrapper -->
#                 </div>
#                 <!--end widget-span -->
#                </div>
#                <!--end row-->
#               </div>
#               <!--end row-wrapper -->
#              </div>
#              <!--end widget-span -->
#              <span class="nav-bar display hide-lg">
#               <span>
#               </span>
#              </span>
#             </div>
#             <!--end row-->
#            </div>
#            <!--end row-wrapper -->
#           </div>
#           <!--end widget-span -->
#          </div>
#          <!--end row-->
#         </div>
#         <!--end row-wrapper -->
#        </div>
#       </div>
#       <!--end widget-span -->
#      </div>
#      <!--end row-->
#     </div>
#     <!--end row-wrapper -->
#    </div>
#    <!--end header -->
#   </div>
#   <!--end header wrapper -->
#   <div class="body-container-wrapper">
#    <div class="body-container container-fluid">
#     <div class="row-fluid-wrapper row-depth-1 row-number-1">
#      <div class="row-fluid">
#       <div class="span12 widget-span widget-type-widget_container" data-w="12" data-widget-type="widget_container" data-x="0" style="">
#        <span class="hs_cos_wrapper hs_cos_wrapper_widget_container hs_cos_wrapper_type_widget_container" data-hs-cos-general-type="widget_container" data-hs-cos-type="widget_container" id="hs_cos_wrapper_module_15646222868736" style="">
#         <div class="hs_cos_wrapper hs_cos_wrapper_widget hs_cos_wrapper_type_module" data-hs-cos-general-type="widget" data-hs-cos-type="module" id="hs_cos_wrapper_widget_1600955110978" style="">
#          <div class="home-banner banner animatedParent animateOnce top-spacing-lg bottom-spacing-md">
#           <img class="accent-right accent hide display-lg animated fadeInRight" src="https://www.applicaster.com/hubfs/Applicaster%20Aug%202019%20Assets/banner_group2.svg"/>
#           <div class="container">
#            <div class="banner__inner animated fadeIn">
#             <div class="banner__title">
#              <h1>
#               <strong>
#                Build the
#                <span>
#                 future
#                </span>
#                of media OTT distribution
#               </strong>
#               <div class="banner__title-rotation">
#                <div>
#                </div>
#               </div>
#              </h1>
#             </div>
#             <div class="custom-row j-content-between">
#              <div class="column-lg-5 banner-text custom-column">
#               <div class="banner__copy">
#                <p class="p1">
#                 <span class="s1">
#                  Positive. Curious. Creative. Dedicated. Humble. Fun.
#                  <br/>
#                  If this sounds like you, we’d love to have you on our team.
#                 </span>
#                </p>
#               </div>
#               <div class="banner__cta">
#                <span class="hs_cos_wrapper hs_cos_wrapper_widget hs_cos_wrapper_type_cta" data-hs-cos-general-type="widget" data-hs-cos-type="cta" id="hs_cos_wrapper_widget_1600955110978_" style="">
#                 <!--HubSpot Call-to-Action Code -->
#                 <span class="hs-cta-wrapper" id="hs-cta-wrapper-b0baecfc-45a9-407e-bce5-51f4c3da6d78">
#                  <span class="hs-cta-node hs-cta-b0baecfc-45a9-407e-bce5-51f4c3da6d78" id="hs-cta-b0baecfc-45a9-407e-bce5-51f4c3da6d78">
#                   <!--[if lte IE 8]><div id="hs-cta-ie-element"></div><![endif]-->
#                   <a href="https://cta-redirect.hubspot.com/cta/redirect/1919336/b0baecfc-45a9-407e-bce5-51f4c3da6d78">
#                    <img alt="Request a Demo" class="hs-cta-img" id="hs-cta-img-b0baecfc-45a9-407e-bce5-51f4c3da6d78" src="https://no-cache.hubspot.com/cta/default/1919336/b0baecfc-45a9-407e-bce5-51f4c3da6d78.png" style="border-width:0px;"/>
#                   </a>
#                  </span>
#                  <script charset="utf-8" src="/hs/cta/cta/current.js">
#                  </script>
#                  <script type="text/javascript">
#                   hbspt.cta._relativeUrls=true;hbspt.cta.load(1919336, 'b0baecfc-45a9-407e-bce5-51f4c3da6d78', {"region":"na1"});
#                  </script>
#                 </span>
#                 <!-- end HubSpot Call-to-Action Code -->
#                </span>
#               </div>
#               <img class="accent-right accent hide-lg display animated fadeInRight" src="https://www.applicaster.com/hubfs/Applicaster%20Aug%202019%20Assets/banner_accent_mobile.svg"/>
#              </div>
#              <div class="banner__img-wrapper banner__img-desktop column-lg-7 custom-column">
#               <div class="banner__img imgoverlap">
#                <img class="grey-rhombus grey-rhombus__right-top animated fadeIn slower hide display-md" src="https://www.applicaster.com/hubfs/Applicaster%20Aug%202019%20Assets/Rectangle.png"/>
#                <img alt="carrers" src="https://www.applicaster.com/hubfs/carrers.png"/>
#               </div>
#              </div>
#             </div>
#            </div>
#           </div>
#           <img class="banner__img-bottomLine pos-relative animated fadeInLeft hide display-md" src="https://www.applicaster.com/hubfs/Applicaster%20Aug%202019%20Assets/banner_group1@2x.png"/>
#          </div>
#         </div>
#         <div class="hs_cos_wrapper hs_cos_wrapper_widget hs_cos_wrapper_type_module" data-hs-cos-general-type="widget" data-hs-cos-type="module" id="hs_cos_wrapper_widget_1600955414679" style="">
#          <div class="appMgmt-platform pos-relative bg-white animatedParent animateOnce bottom-spacing">
#           <div class="container animatedParent animateOnce">
#            <h2 class="">
#             Great benefits for great people
#            </h2>
#            <p style="font-size: 18px;">
#             <span class="s1">
#              At Applicaster, we believe that if you’re working hard for us then we should be working just as hard for you. We offer market-leading benefits at all of our global locations. As with any global company, benefits vary depending on your region. Benefits may include:
#             </span>
#            </p>
#            <div class="custom-row appMgmt-platform__slider">
#             <div class="custom-column column-md-6 appMgmt-platform-item">
#              <div class="image">
#               <div class="appMgmt-platform__slider-icon ta-center" data-src="" id="appMgmt-platform__lottie1">
#                <img alt="vacation-icon@2x" height="79" sizes="(max-width: 80px) 100vw, 80px" src="https://www.applicaster.com/hs-fs/hubfs/vacation-icon@2x.png?width=80&amp;height=79&amp;name=vacation-icon@2x.png" srcset="https://www.applicaster.com/hs-fs/hubfs/vacation-icon@2x.png?width=40&amp;height=40&amp;name=vacation-icon@2x.png 40w, https://www.applicaster.com/hs-fs/hubfs/vacation-icon@2x.png?width=80&amp;height=79&amp;name=vacation-icon@2x.png 80w, https://www.applicaster.com/hs-fs/hubfs/vacation-icon@2x.png?width=120&amp;height=119&amp;name=vacation-icon@2x.png 120w, https://www.applicaster.com/hs-fs/hubfs/vacation-icon@2x.png?width=160&amp;height=158&amp;name=vacation-icon@2x.png 160w, https://www.applicaster.com/hs-fs/hubfs/vacation-icon@2x.png?width=200&amp;height=198&amp;name=vacation-icon@2x.png 200w, https://www.applicaster.com/hs-fs/hubfs/vacation-icon@2x.png?width=240&amp;height=237&amp;name=vacation-icon@2x.png 240w" width="80"/>
#               </div>
#              </div>
#              <div class="text">
#               <h4 class="fw-bold">
#               </h4>
#               <h3>
#                Take what you need vacation policy
#               </h3>
#              </div>
#             </div>
#             <div class="custom-column column-md-6 appMgmt-platform-item">
#              <div class="image">
#               <div class="appMgmt-platform__slider-icon ta-center" data-src="" id="appMgmt-platform__lottie2">
#                <img alt="medical-icon@2x" height="79" sizes="(max-width: 80px) 100vw, 80px" src="https://www.applicaster.com/hs-fs/hubfs/medical-icon@2x.png?width=80&amp;height=79&amp;name=medical-icon@2x.png" srcset="https://www.applicaster.com/hs-fs/hubfs/medical-icon@2x.png?width=40&amp;height=40&amp;name=medical-icon@2x.png 40w, https://www.applicaster.com/hs-fs/hubfs/medical-icon@2x.png?width=80&amp;height=79&amp;name=medical-icon@2x.png 80w, https://www.applicaster.com/hs-fs/hubfs/medical-icon@2x.png?width=120&amp;height=119&amp;name=medical-icon@2x.png 120w, https://www.applicaster.com/hs-fs/hubfs/medical-icon@2x.png?width=160&amp;height=158&amp;name=medical-icon@2x.png 160w, https://www.applicaster.com/hs-fs/hubfs/medical-icon@2x.png?width=200&amp;height=198&amp;name=medical-icon@2x.png 200w, https://www.applicaster.com/hs-fs/hubfs/medical-icon@2x.png?width=240&amp;height=237&amp;name=medical-icon@2x.png 240w" width="80"/>
#               </div>
#              </div>
#              <div class="text">
#               <h4 class="fw-bold">
#               </h4>
#               <h3>
#                Private medical insurance
#               </h3>
#              </div>
#             </div>
#             <div class="custom-column column-md-6 appMgmt-platform-item">
#              <div class="image">
#               <div class="appMgmt-platform__slider-icon ta-center" data-src="" id="appMgmt-platform__lottie3">
#                <img alt="401-plans-icon@2x" height="79" sizes="(max-width: 80px) 100vw, 80px" src="https://www.applicaster.com/hs-fs/hubfs/401-plans-icon@2x.png?width=80&amp;height=79&amp;name=401-plans-icon@2x.png" srcset="https://www.applicaster.com/hs-fs/hubfs/401-plans-icon@2x.png?width=40&amp;height=40&amp;name=401-plans-icon@2x.png 40w, https://www.applicaster.com/hs-fs/hubfs/401-plans-icon@2x.png?width=80&amp;height=79&amp;name=401-plans-icon@2x.png 80w, https://www.applicaster.com/hs-fs/hubfs/401-plans-icon@2x.png?width=120&amp;height=119&amp;name=401-plans-icon@2x.png 120w, https://www.applicaster.com/hs-fs/hubfs/401-plans-icon@2x.png?width=160&amp;height=158&amp;name=401-plans-icon@2x.png 160w, https://www.applicaster.com/hs-fs/hubfs/401-plans-icon@2x.png?width=200&amp;height=198&amp;name=401-plans-icon@2x.png 200w, https://www.applicaster.com/hs-fs/hubfs/401-plans-icon@2x.png?width=240&amp;height=237&amp;name=401-plans-icon@2x.png 240w" width="80"/>
#               </div>
#              </div>
#              <div class="text">
#               <h4 class="fw-bold">
#               </h4>
#               <h3>
#                401k (retirement) plans
#               </h3>
#              </div>
#             </div>
#             <div class="custom-column column-md-6 appMgmt-platform-item">
#              <div class="image">
#               <div class="appMgmt-platform__slider-icon ta-center" data-src="" id="appMgmt-platform__lottie4">
#                <img alt="fsa-icon@2x" height="79" sizes="(max-width: 80px) 100vw, 80px" src="https://www.applicaster.com/hs-fs/hubfs/fsa-icon@2x.png?width=80&amp;height=79&amp;name=fsa-icon@2x.png" srcset="https://www.applicaster.com/hs-fs/hubfs/fsa-icon@2x.png?width=40&amp;height=40&amp;name=fsa-icon@2x.png 40w, https://www.applicaster.com/hs-fs/hubfs/fsa-icon@2x.png?width=80&amp;height=79&amp;name=fsa-icon@2x.png 80w, https://www.applicaster.com/hs-fs/hubfs/fsa-icon@2x.png?width=120&amp;height=119&amp;name=fsa-icon@2x.png 120w, https://www.applicaster.com/hs-fs/hubfs/fsa-icon@2x.png?width=160&amp;height=158&amp;name=fsa-icon@2x.png 160w, https://www.applicaster.com/hs-fs/hubfs/fsa-icon@2x.png?width=200&amp;height=198&amp;name=fsa-icon@2x.png 200w, https://www.applicaster.com/hs-fs/hubfs/fsa-icon@2x.png?width=240&amp;height=237&amp;name=fsa-icon@2x.png 240w" width="80"/>
#               </div>
#              </div>
#              <div class="text">
#               <h4 class="fw-bold">
#               </h4>
#               <h3>
#                FSA card
#               </h3>
#              </div>
#             </div>
#             <div class="custom-column column-md-6 appMgmt-platform-item">
#              <div class="image">
#               <div class="appMgmt-platform__slider-icon ta-center" data-src="" id="appMgmt-platform__lottie5">
#                <img alt="life-icon@2x" height="79" sizes="(max-width: 80px) 100vw, 80px" src="https://www.applicaster.com/hs-fs/hubfs/life-icon@2x.png?width=80&amp;height=79&amp;name=life-icon@2x.png" srcset="https://www.applicaster.com/hs-fs/hubfs/life-icon@2x.png?width=40&amp;height=40&amp;name=life-icon@2x.png 40w, https://www.applicaster.com/hs-fs/hubfs/life-icon@2x.png?width=80&amp;height=79&amp;name=life-icon@2x.png 80w, https://www.applicaster.com/hs-fs/hubfs/life-icon@2x.png?width=120&amp;height=119&amp;name=life-icon@2x.png 120w, https://www.applicaster.com/hs-fs/hubfs/life-icon@2x.png?width=160&amp;height=158&amp;name=life-icon@2x.png 160w, https://www.applicaster.com/hs-fs/hubfs/life-icon@2x.png?width=200&amp;height=198&amp;name=life-icon@2x.png 200w, https://www.applicaster.com/hs-fs/hubfs/life-icon@2x.png?width=240&amp;height=237&amp;name=life-icon@2x.png 240w" width="80"/>
#               </div>
#              </div>
#              <div class="text">
#               <h4 class="fw-bold">
#               </h4>
#               <h3>
#                Life and disability insurance
#               </h3>
#              </div>
#             </div>
#             <div class="custom-column column-md-6 appMgmt-platform-item">
#              <div class="image">
#               <div class="appMgmt-platform__slider-icon ta-center" data-src="" id="appMgmt-platform__lottie6">
#                <img alt="parental-icon@2x" height="79" sizes="(max-width: 80px) 100vw, 80px" src="https://www.applicaster.com/hs-fs/hubfs/parental-icon@2x.png?width=80&amp;height=79&amp;name=parental-icon@2x.png" srcset="https://www.applicaster.com/hs-fs/hubfs/parental-icon@2x.png?width=40&amp;height=40&amp;name=parental-icon@2x.png 40w, https://www.applicaster.com/hs-fs/hubfs/parental-icon@2x.png?width=80&amp;height=79&amp;name=parental-icon@2x.png 80w, https://www.applicaster.com/hs-fs/hubfs/parental-icon@2x.png?width=120&amp;height=119&amp;name=parental-icon@2x.png 120w, https://www.applicaster.com/hs-fs/hubfs/parental-icon@2x.png?width=160&amp;height=158&amp;name=parental-icon@2x.png 160w, https://www.applicaster.com/hs-fs/hubfs/parental-icon@2x.png?width=200&amp;height=198&amp;name=parental-icon@2x.png 200w, https://www.applicaster.com/hs-fs/hubfs/parental-icon@2x.png?width=240&amp;height=237&amp;name=parental-icon@2x.png 240w" width="80"/>
#               </div>
#              </div>
#              <div class="text">
#               <h4 class="fw-bold">
#               </h4>
#               <h3>
#                Parental leave
#               </h3>
#              </div>
#             </div>
#            </div>
#           </div>
#          </div>
#         </div>
#         <div class="hs_cos_wrapper hs_cos_wrapper_widget hs_cos_wrapper_type_module" data-hs-cos-general-type="widget" data-hs-cos-type="module" id="hs_cos_wrapper_widget_1566354100804" style="">
#          <div class="col2-copySlider-img animatedParent animateOnce padding-top padding-bottom">
#           <div class="container">
#            <div class="col2-copySlider-img__inner">
#             <div class="col2-copySlider-img__header ta-md-center ta-left animated fadeIn">
#              <h2>
#               People make the difference
#              </h2>
#             </div>
#             <div class="custom-row a-items-center j-content-between animated fadeIn slow">
#              <div class="custom-column column-md-6 order-2">
#               <div class="col2-copySlider-img__imgslider mx-neg-15">
#                <div class="col2-copySlider-img__image">
#                 <img alt="curious" src="https://www.applicaster.com/hubfs/curious.png"/>
#                </div>
#                <div class="col2-copySlider-img__image">
#                 <img alt="humble" src="https://www.applicaster.com/hubfs/humble.png"/>
#                </div>
#                <div class="col2-copySlider-img__image">
#                 <img alt="team" src="https://www.applicaster.com/hubfs/team.png"/>
#                </div>
#                <div class="col2-copySlider-img__image">
#                 <img alt="destiny" src="https://www.applicaster.com/hubfs/destiny.png"/>
#                </div>
#                <div class="col2-copySlider-img__image">
#                 <img alt="human" src="https://www.applicaster.com/hubfs/human.png"/>
#                </div>
#               </div>
#              </div>
#              <div class="custom-column column-md-5 order-1">
#               <div class="col2-copySlider-img__slider">
#                <div class="col2-copySlider-img__slider-item">
#                 <h3 class="p1">
#                  <span class="s1">
#                   We’re curious.
#                  </span>
#                 </h3>
#                 <p class="p1">
#                  <span class="s1">
#                   “Why?” and “what if?” are questions you’ll hear a lot at Applicaster. We recognize that to question is to explore, and we believe that exploration drives us forward as individuals and as a company.
#                  </span>
#                 </p>
#                </div>
#                <div class="col2-copySlider-img__slider-item">
#                 <h3 class="p1">
#                  <span class="s1">
#                   We’re humble.
#                  </span>
#                 </h3>
#                 <p class="p1">
#                  <span class="s1">
#                   Despite our successes, we keep our feet firmly planted on the ground, because that’s the only way to keep moving forward.
#                  </span>
#                 </p>
#                </div>
#                <div class="col2-copySlider-img__slider-item">
#                 <h3 class="p1">
#                  <span class="s1">
#                   We’re a Team.
#                  </span>
#                 </h3>
#                 <p class="p1">
#                  <span class="s1">
#                   We win and (rarely) lose as a team. Collective responsibility and collaboration are not just words at Applicaster, they’re part of our DNA.
#                  </span>
#                 </p>
#                </div>
#                <div class="col2-copySlider-img__slider-item">
#                 <h3 class="p1">
#                  <span class="s1">
#                   We own our destiny.
#                  </span>
#                 </h3>
#                 <p class="p1">
#                  <span class="s1">
#                   Our destiny lies in our own hands and we accept full responsibility for it. We strive to raise the bar for our products, our teams, and ourselves to one end:
#                   <i>
#                    customer satisfaction
#                   </i>
#                   .
#                  </span>
#                 </p>
#                </div>
#                <div class="col2-copySlider-img__slider-item">
#                 <h3 class="p1">
#                  <span class="s1">
#                   We are human.
#                  </span>
#                 </h3>
#                 <p class="p1">
#                  <span class="s1">
#                   We take an interest in, and embrace each other’s individuality. We stay true to who we are, stand up for what we believe in, and are always respectful of others.
#                  </span>
#                 </p>
#                </div>
#               </div>
#              </div>
#             </div>
#            </div>
#           </div>
#          </div>
#         </div>
#         <div class="hs_cos_wrapper hs_cos_wrapper_widget hs_cos_wrapper_type_module" data-hs-cos-general-type="widget" data-hs-cos-type="module" id="hs_cos_wrapper_widget_1566354229060" style="">
#          <div class="career-positions animatedParent animateOnce bg-solitude padding-top pos-relative of-hidden padding-bottom">
#           <img alt="accent" class="accent-bottom-left accent animated fadeIn display-md hide" src="https://www.applicaster.com/hubfs/Applicaster%20Aug%202019%20Assets/accent-4.svg"/>
#           <img alt="accent" class="accent-top-right accent animated fadeIn slow display-md hide" src="https://www.applicaster.com/hubfs/Applicaster%20Aug%202019%20Assets/accent-5.svg"/>
#           <img alt="accent" class="accent-left accent animated fadeIn display hide-md" src="https://www.applicaster.com/hubfs/Applicaster%20Aug%202019%20Assets/accent-6.svg"/>
#           <img alt="accent" class="accent-right accent animated fadeIn slow display hide-md" src="https://www.applicaster.com/hubfs/Applicaster%20Aug%202019%20Assets/accent-7.svg"/>
#           <div class="container">
#            <div class="career-positions__header ta-center ta-md-left animated fadeIn">
#             <h2>
#              Open positions
#             </h2>
#            </div>
#            <div class="career-positions__listWrapper animated fadeIn green-rectangle-md green-rectangle pos-relative">
#             <div class="career-positions__list pos-relative">
#             </div>
#            </div>
#           </div>
#          </div>
#          <script id="careers-template" type="text/x-handlebars-template">
#           {{#each this}}
#   <div class="career-positions__item bg-white">
#           <div class="custom-row a-items-center">
#             <div class="custom-column column-md-9 career-positions__item-header">
#               <div class="career-positions__details">
#                 <div class="career-positions__title d-flex a-items-center ff-prospectus fw-semibold">
#                   {{ name }} {{#if location.city }}<span class="ff-circular fw-bold pos-relative">{{ location.city }}, {{ location.state }}</span>{{/if}}
#                 </div>
#                 {{#if details }}
#                 <div class="career-positions__desc hide display-md">
#                   {{#if details.[2].value }}
#                   {{{ details.[2].value }}}
#                   {{else}}
#                   {{{ details.[0].value }}}
#                   {{/if }}
#                 </div>
#                 {{/if }}
#               </div>
#             </div>
#             <div class="custom-column column-md-3 career-positions__collapse">
#               {{#if details }}
#               <div class="career-positions__desc display hide-md">
#                 {{#if details.[3].value }}
#                 {{{ details.[3].value }}}
#                 {{else}}
#                 {{{ details.[0].value }}}
#                 {{/if }}
#               </div>
#               {{/if }}
#               <div class="career-positions__cta ta-center">
#                 <a class="btn" href="{{ url_active_page }}" target="_blank">
#                   Apply Now
#                 </a>
#               </div>
#             </div>
#           </div>
#         </div>
#         {{/each}}
#          </script>
#         </div>
#        </span>
#       </div>
#       <!--end widget-span -->
#      </div>
#      <!--end row-->
#     </div>
#     <!--end row-wrapper -->
#    </div>
#    <!--end body -->
#   </div>
#   <!--end body wrapper -->
#   <div class="footer-container-wrapper">
#    <div class="footer-container container-fluid">
#     <div class="row-fluid-wrapper row-depth-1 row-number-1">
#      <div class="row-fluid">
#       <div class="span12 widget-span widget-type-global_group" data-w="12" data-widget-type="global_group" data-x="0" style="">
#        <div class="" data-global-widget-path="generated_global_groups/35301337850.html">
#         <div class="row-fluid-wrapper row-depth-1 row-number-1">
#          <div class="row-fluid">
#           <div class="span12 widget-span widget-type-cell footer bg-blue" data-w="12" data-widget-type="cell" data-x="0" style="">
#            <div class="row-fluid-wrapper row-depth-1 row-number-2">
#             <div class="row-fluid">
#              <div class="span12 widget-span widget-type-cell container" data-w="12" data-widget-type="cell" data-x="0" style="">
#               <div class="row-fluid-wrapper row-depth-1 row-number-3">
#                <div class="row-fluid">
#                 <div class="span12 widget-span widget-type-cell footer-menu-wrapper" data-w="12" data-widget-type="cell" data-x="0" style="">
#                  <div class="row-fluid-wrapper row-depth-1 row-number-4">
#                   <div class="row-fluid">
#                    <div class="span6 widget-span widget-type-custom_widget" data-w="6" data-widget-type="custom_widget" data-x="0" style="">
#                     <div class="hs_cos_wrapper hs_cos_wrapper_widget hs_cos_wrapper_type_module widget-type-logo" data-hs-cos-general-type="widget" data-hs-cos-type="module" id="hs_cos_wrapper_module_1564623273204108" style="">
#                      <span class="hs_cos_wrapper hs_cos_wrapper_widget hs_cos_wrapper_type_logo" data-hs-cos-general-type="widget" data-hs-cos-type="logo" id="hs_cos_wrapper_module_1564623273204108_hs_logo_widget" style="">
#                       <a href="http://applicaster.com" id="hs-link-module_1564623273204108_hs_logo_widget" style="border-width:0px;border:0px;">
#                        <img alt="applicaster logo white.svg" class="hs-image-widget" src="https://www.applicaster.com/hubfs/2017_Website/applicaster%20logo%20white.svg" style="width:400px;border-width:0px;border:0px;" title="applicaster logo white.svg" width="400"/>
#                       </a>
#                      </span>
#                     </div>
#                    </div>
#                    <!--end widget-span -->
#                    <div class="span6 widget-span widget-type-custom_widget footer-socials" data-w="6" data-widget-type="custom_widget" data-x="6" style="">
#                     <div class="hs_cos_wrapper hs_cos_wrapper_widget hs_cos_wrapper_type_module widget-type-rich_text" data-hs-cos-general-type="widget" data-hs-cos-type="module" id="hs_cos_wrapper_module_1564623350392111" style="">
#                      <span class="hs_cos_wrapper hs_cos_wrapper_widget hs_cos_wrapper_type_rich_text" data-hs-cos-general-type="widget" data-hs-cos-type="rich_text" id="hs_cos_wrapper_module_1564623350392111_" style="">
#                       <ul class="d-flex a-items-center j-content-center j-content-md-end">
#                        <li>
#                         <a href="https://twitter.com/Applicaster?ref_src=twsrc%5Egoogle%7Ctwcamp%5Eserp%7Ctwgr%5Eauthor" rel="noopener" target="_blank">
#                          <img src="https://www.applicaster.com/hubfs/Applicaster%20Aug%202019%20Assets/twitter-light.svg"/>
#                         </a>
#                        </li>
#                        <li>
#                         <a href="https://www.facebook.com/applicaster/" rel="noopener" target="_blank">
#                          <img src="https://www.applicaster.com/hubfs/Applicaster%20Aug%202019%20Assets/facebook-light.svg"/>
#                         </a>
#                        </li>
#                        <li>
#                         <a href="https://www.youtube.com/channel/UCcUVcIIxenqWdnW0bplNEmw" rel="noopener" target="_blank">
#                          <img src="https://www.applicaster.com/hubfs/Applicaster%20Aug%202019%20Assets/youtube-light.svg"/>
#                         </a>
#                        </li>
#                        <li>
#                         <a href="https://www.linkedin.com/company/applicaster-ltd/" rel="noopener" target="_blank">
#                          <img src="https://www.applicaster.com/hubfs/Applicaster%20Aug%202019%20Assets/LinkedIn.svg"/>
#                         </a>
#                        </li>
#                       </ul>
#                      </span>
#                     </div>
#                    </div>
#                    <!--end widget-span -->
#                   </div>
#                   <!--end row-->
#                  </div>
#                  <!--end row-wrapper -->
#                  <div class="row-fluid-wrapper row-depth-1 row-number-5">
#                   <div class="row-fluid">
#                    <div class="span12 widget-span widget-type-custom_widget footer-menu hide display-md" data-w="12" data-widget-type="custom_widget" data-x="0" style="">
# ...
#                          </a>
#                         </li>
#                         <li class="hs-menu-item hs-menu-depth-1" role="none">
#                          <a href="https://www.applicaster.com/fast-forward-solutions" role="menuitem">
#                           Fast Forward solutions
#                          </a>
#                         </li>
#                         <li class="hs-menu-item hs-menu-depth-1" role="none">
#                          <a href="https://www.applicaster.com/apple-certified" role="menuitem">
#                           Apple approved
#                          </a>
#                         </li>
#                         <li class="hs-menu-item hs-menu-depth-1" role="none">
#                          <a href="https://www.applicaster.com/launch-on-roku" role="menuitem">
#                           Roku channels
#                          </a>
#                         </li>
#                        </ul>
#                       </div>
#                      </span>
#                     </div>
#                    </div>
#                    <!--end widget-span -->
#                   </div>
#                   <!--end row-->
#                  </div>
#                  <!--end row-wrapper -->
#                 </div>
#                 <!--end widget-span -->
#                </div>
#                <!--end row-->
#               </div>
#               <!--end row-wrapper -->
#               <div class="row-fluid-wrapper row-depth-1 row-number-6">
#                <div class="row-fluid">
#                 <div class="span12 widget-span widget-type-custom_widget hide display-md" data-w="12" data-widget-type="custom_widget" data-x="0" style="">
#                  <div class="hs_cos_wrapper hs_cos_wrapper_widget hs_cos_wrapper_type_module" data-hs-cos-general-type="widget" data-hs-cos-type="module" id="hs_cos_wrapper_module_1564624529401232" style="">
#                   <div class="footer-locations">
#                    <div class="custom-row">
#                     <div class="custom-column column-md-3">
#                      <div class="footer-locations__heading c-white footer-title">
#                       SALES INQUIRIES
#                      </div>
#                      <div class="footer-phone c-white">
#                       <p>
#                        Fill out
#                        <strong>
#                         <a href="https://www.applicaster.com/request-demo" rel="noopener" target="_blank">
#                          this
#                         </a>
#                        </strong>
#                        form
#                       </p>
#                      </div>
#                     </div>
#                     <div class="custom-column column-md-9">
#                      <div class="footer-locations__heading c-white footer-title">
#                       OUR OFFICES
#                      </div>
#                      <div class="custom-row footer-location__wrap">
#                       <div class="custom-column column-lg-4 column-md-6">
#                        <div class="footer-location__item c-white">
#                         <div class="footer-location__title uppercase">
#                          NEW YORK
#                         </div>
#                         <div class="footer-location__address">
#                          1410 Broadway
#                          <br/>
#                          New York, NY 10018 USA
#                         </div>
#                        </div>
#                       </div>
#                       <div class="custom-column column-lg-4 column-md-6">
#                        <div class="footer-location__item c-white">
#                         <div class="footer-location__title uppercase">
#                          MIAMI
#                         </div>
#                         <div class="footer-location__address">
#                          1101 Brickell Ave
#                          <br/>
#                          Miami, FL 33131 USA
#                         </div>
#                        </div>
#                       </div>
#                       <div class="custom-column column-lg-4 column-md-6">
#                        <div class="footer-location__item c-white">
#                         <div class="footer-location__title uppercase">
#                          LOS ANGELES
#                         </div>
#                         <div class="footer-location__address">
#                          10100 Santa Monica Blvd
#                          <br/>
#                          Los Angeles, CA 90067 USA
#                         </div>
#                        </div>
#                       </div>
#                       <div class="custom-column column-lg-4 column-md-6">
#                        <div class="footer-location__item c-white">
#                         <div class="footer-location__title uppercase">
#                          SAN JOSE
#                         </div>
#                         <div class="footer-location__address">
#                          333 W. San Carlos St., #6140
#                          <br/>
#                          San Jose, CA 95110 USA
#                         </div>
#                        </div>
#                       </div>
#                       <div class="custom-column column-lg-4 column-md-6">
#                        <div class="footer-location__item c-white">
#                         <div class="footer-location__title uppercase">
#                          LONDON
#                         </div>
#                         <div class="footer-location__address">
#                          37 Broadhurst Gardens
#                          <br/>
#                          London, NW6 3QT
#                         </div>
#                        </div>
#                       </div>
#                       <div class="custom-column column-lg-4 column-md-6">
#                        <div class="footer-location__item c-white">
#                         <div class="footer-location__title uppercase">
#                          TEL AVIV
#                         </div>
#                         <div class="footer-location__address">
#                          124 Ibn Gabirol St, 9th Fl
#                          <br/>
#                          Tel Aviv, 6203854 Israel
#                         </div>
#                        </div>
#                       </div>
#                      </div>
#                     </div>
#                    </div>
#                   </div>
#                  </div>
#                 </div>
#                 <!--end widget-span -->
#                </div>
#                <!--end row-->
#               </div>
#               <!--end row-wrapper -->
#               <div class="row-fluid-wrapper row-depth-1 row-number-7">
#                <div class="row-fluid">
#                 <div class="span12 widget-span widget-type-cell footer-copyright" data-w="12" data-widget-type="cell" data-x="0" style="">
#                  <div class="row-fluid-wrapper row-depth-1 row-number-8">
#                   <div class="row-fluid">
#                    <div class="span6 widget-span widget-type-custom_widget c-white ta-center ta-md-left" data-w="6" data-widget-type="custom_widget" data-x="0" style="">
#                     <div class="hs_cos_wrapper hs_cos_wrapper_widget hs_cos_wrapper_type_module widget-type-text" data-hs-cos-general-type="widget" data-hs-cos-type="module" id="hs_cos_wrapper_module_1564624634164234" style="">
#                      <span class="hs_cos_wrapper hs_cos_wrapper_widget hs_cos_wrapper_type_text" data-hs-cos-general-type="widget" data-hs-cos-type="text" id="hs_cos_wrapper_module_1564624634164234_" style="">
#                       © 2021 Applicaster, All rights reserved.
#                      </span>
#                     </div>
#                    </div>
#                    <!--end widget-span -->
#                    <div class="span6 widget-span widget-type-custom_widget ta-right hide display-md" data-w="6" data-widget-type="custom_widget" data-x="6" style="">
#                     <div class="hs_cos_wrapper hs_cos_wrapper_widget hs_cos_wrapper_type_module widget-type-rich_text" data-hs-cos-general-type="widget" data-hs-cos-type="module" id="hs_cos_wrapper_module_1564701978245336" style="">
#                      <span class="hs_cos_wrapper hs_cos_wrapper_widget hs_cos_wrapper_type_rich_text" data-hs-cos-general-type="widget" data-hs-cos-type="rich_text" id="hs_cos_wrapper_module_1564701978245336_" style="">
#                       <a class="c-green" href="/privacy-security" rel="noopener">
#                        <span class="s1">
#                         Privacy and Security
#                        </span>
#                       </a>
#                      </span>
#                     </div>
#                    </div>
#                    <!--end widget-span -->
#                   </div>
#                   <!--end row-->
#                  </div>
#                  <!--end row-wrapper -->
#                 </div>
#                 <!--end widget-span -->
#                </div>
#                <!--end row-->
#               </div>
#               <!--end row-wrapper -->
#              </div>
#              <!--end widget-span -->
#             </div>
#             <!--end row-->
#            </div>
#            <!--end row-wrapper -->
#           </div>
#           <!--end widget-span -->
#          </div>
#          <!--end row-->
#         </div>
#         <!--end row-wrapper -->
#        </div>
#       </div>
#       <!--end widget-span -->
#      </div>
#      <!--end row-->
#     </div>
#     <!--end row-wrapper -->
#    </div>
#    <!--end footer -->
#   </div>
#   <!--end footer wrapper -->
#   <script>
#    (function () {
#     window.addEventListener('load', function () {
#         setTimeout(function () {
#             var xhr = new XMLHttpRequest();
#             xhr.open('POST', '/_hcms/perf', true /*async*/);
#             xhr.setRequestHeader("Content-type", "application/json");
#             xhr.onreadystatechange = function () {
#                 // do nothing.
#             };
#             var connection = navigator.connection || navigator.mozConnection || navigator.webkitConnection;
#             function populateNetworkInfo(name, connection, info) {
#                 if (name in connection) {
#                     info[name] = connection[name];
#                 }
#             }
#             var networkInfo = {};
#             if (connection) {
#                 ['type', 'effectiveType', 'downlink', 'rtt'].forEach(function(name) {
#                     populateNetworkInfo(name, connection, networkInfo);
#                 });
#             }
#             var perfData = {
#                 url: location.href,
#                 portal: 1919336,
#                 content: 34961382829,
#                 group: -1,
#                 connection: networkInfo,
#                 timing: performance.timing
#             };
#             xhr.send(JSON.stringify(perfData));
#         }, 3000);  // Execute this 3 seconds after onload.
#     });
# })();
#   </script>
#   <script src="https://www.applicaster.com/hs-fs/hub/1919336/hub_generated/template_assets/11781559782/1620319843135/Coded_files/Custom/page/Applicaster_2019_S2/s2-script.js">
#   </script>
#   <script>
#    if (typeof hsVars !== 'undefined') { hsVars['language'] = 'en'; }
#   </script>
#   <script src="/hs/hsstatic/cos-i18n/static-1.27/bundles/project.js">
#   </script>
#   <script src="/hs/hsstatic/keyboard-accessible-menu-flyouts/static-1.17/bundles/project.js">
#   </script>
#   <script src="https://www.applicaster.com/hs-fs/hub/1919336/hub_generated/module_assets/34711567328/1600899404482/module_34711567328_Banner_-_v2.min.js">
#   </script>
#   <script src="https://www.applicaster.com/hs-fs/hub/1919336/hub_generated/module_assets/35233170497/1600901582512/module_35233170497_Platform_App_Mgmt_Slider_-_v2.min.js">
#   </script>
#   <script src="https://www.applicaster.com/hs-fs/hub/1919336/hub_generated/module_assets/1600699635243/module_12251805651_2_Col_-_Slider_Copy_and_Image.js">
#   </script>
#   <script src="https://www.applicaster.com/hubfs/handlebars.min.js">
#   </script>
#   <script src="https://www.applicaster.com/hs-fs/hub/1919336/hub_generated/module_assets/1570820954396/module_12280678332_Custom_modules_Applicaster_2019_S2_Career_Positions.js">
#   </script>
#   <!-- Start of HubSpot Analytics Code -->
#   <script type="text/javascript">
#    var _hsq = _hsq || [];
# _hsq.push(["setContentType", "standard-page"]);
# _hsq.push(["setCanonicalUrl", "https:\/\/www.applicaster.com\/careers"]);
# _hsq.push(["setPageId", "34961382829"]);
# _hsq.push(["setContentMetadata", {
#     "contentPageId": 34961382829,
#     "legacyPageId": "34961382829",
#     "contentFolderId": null,
#     "contentGroupId": null,
#     "abTestId": null,
#     "languageVariantId": 34961382829,
#     "languageCode": null,
#
# }]);
#   </script>
#   <script async="" defer="" id="hs-script-loader" src="/hs/scriptloader/1919336.js" type="text/javascript">
#   </script>
#   <!-- End of HubSpot Analytics Code -->
#   <script type="text/javascript">
#    var hsVars = {
#     ticks: 1623683093133,
#     page_id: 34961382829,
#
#     content_group_id: 0,
#     portal_id: 1919336,
#     app_hs_base_url: "https://app.hubspot.com",
#     cp_hs_base_url: "https://cp.hubspot.com",
#     language: "en",
#     analytics_page_type: "standard-page",
#     analytics_page_id: "34961382829",
#     category_id: 1,
#     folder_id: 0,
#     is_hubspot_user: false
# }
#   </script>
#   <script defer="" src="/hs/hsstatic/HubspotToolsMenu/static-1.103/js/index.js">
#   </script>
#   <!-- Google Tag Manager (noscript) -->
#   <noscript>
#    <iframe height="0" src="https://www.googletagmanager.com/ns.html?id=GTM-MSFHXLL" style="display:none;visibility:hidden" width="0">
#    </iframe>
#   </noscript>
#   <!-- End Google Tag Manager (noscript) -->
#   <!-- Facebook Pixel Code -->
#   <script>
#    !function(f,b,e,v,n,t,s){if(f.fbq)return;n=f.fbq=function(){n.callMethod?
# n.callMethod.apply(n,arguments):n.queue.push(arguments)};if(!f._fbq)f._fbq=n;
# n.push=n;n.loaded=!0;n.version='2.0';n.queue=[];t=b.createElement(e);t.async=!0;
# t.src=v;s=b.getElementsByTagName(e)[0];s.parentNode.insertBefore(t,s)}(window,
# document,'script','https://connect.facebook.net/en_US/fbevents.js');
# fbq('init', '1998947433673474'); // Insert your pixel ID here.
# fbq('track', 'PageView');
#   </script>
#   <noscript>
#    <img height="1" src="https://www.facebook.com/tr?id=1998947433673474&amp;ev=PageView&amp;noscript=1" style="display:none" width="1"/>
#   </noscript>
#   <!-- DO NOT MODIFY -->
#   <!-- End Facebook Pixel Code -->
#   <script type="text/javascript">
#    _linkedin_partner_id = "958689"; window._linkedin_data_partner_ids = window._linkedin_data_partner_ids || []; window._linkedin_data_partner_ids.push(_linkedin_partner_id);
#   </script>
#   <script type="text/javascript">
#    (function(){var s = document.getElementsByTagName("script")[0]; var b = document.createElement("script"); b.type = "text/javascript";b.async = true; b.src = "https://snap.licdn.com/li.lms-analytics/insight.min.js"; s.parentNode.insertBefore(b, s);})();
#   </script>
#   <noscript>
#    <img alt="" height="1" src="https://dc.ads.linkedin.com/collect/?pid=958689&amp;fmt=gif" style="display:none;" width="1"/>
#   </noscript>
#   <script type="text/javascript">
#    _linkedin_data_partner_id = "68246";
#   </script>
#   <script type="text/javascript">
#    (function(){var s = document.getElementsByTagName("script")[0]; var b = document.createElement("script"); b.type = "text/javascript";b.async = true; b.src = "https://snap.licdn.com/li.lms-analytics/insight.min.js"; s.parentNode.insertBefore(b, s);})();
#   </script>
#   <noscript>
#    <img alt="" height="1" src="https://dc.ads.linkedin.com/collect/?pid=68246&amp;fmt=gif" style="display:none;" width="1"/>
#   </noscript>
#   <link href="/_hcms/raw-resource?path=Coded%20files/Custom/page/css/domain_fonts.css&amp;portalId=1919336&amp;t=1568132048655" rel="stylesheet" type="text/css"/>
#   <script src="https://www.applicaster.com/hubfs/Applicaster%20Aug%202019%20Assets/js/lottie.min.js">
#   </script>
#   <script src="https://www.applicaster.com/hubfs/Applicaster%20Aug%202019%20Assets/js/css3-animate-it.js">
#   </script>
#   <!-- Generated by the HubSpot Template Builder - template version 1.03 -->
#  </body>
# </html>

# %%
database = [['job_name', 'country', 'city', 'offer_link']]

offers = soup.find('div', class_ = 'list-container list')
#print(offers)
positions = offers.find_all('div', class_ = 'job')

for position in positions:
    #print("______________")
    #print(position)
    
    #JOB_NAME
    job_name = position.find("a").text.strip(' \n\t')
    #print(job_name)        
    
    # COUNTRY / CITY
    citycountry = position.find("li").text.strip(' \n\t')
    #print(citycountry)

    citycountry_list = citycountry.split(",")
 
    # Best case: the 2 fields are provided:
    if len(citycountry_list) == 2:
        country = get_country(citycountry_list[1]).strip(' \n\t')
        city = citycountry_list[0].strip(' \n\t')
    
    # But sometimes only the city or the country is provided: in that case, the length of citycountry is 1
    elif len(citycountry_list) == 1: 
        country = get_country(citycountry_list[0]).strip(' \n\t')
        city = ' '
        
    else:
        country = ' '
        city = ' '
        
    #REMOTE CASE
    if citycountry == 'Remote job':
        country = 'Remote'
        city = ' '
        
    #print(country)
    #print('the city is: '+ city)
    
    # OFFER_LINK
    link = position.a.get('href')    
    offer_link = "https://everli.recruitee.com" + link
    print(offer_link)

# #    print(position.prettify())

    database.append([job_name, country, city, offer_link])
# Out:
# https://everli.recruitee.com/o/key-account-support-intern
# https://everli.recruitee.com/o/corporate-development-and-ma-associate
# https://everli.recruitee.com/o/consolidation-reporting-specialist
# https://everli.recruitee.com/o/international-talent-acquisition-specialist
# https://everli.recruitee.com/o/marketing-manager-italy-1
# https://everli.recruitee.com/o/head-of-corporate-development-and-ma
# https://everli.recruitee.com/o/illustration-and-motion-designer
# https://everli.recruitee.com/o/campaign-content-designer
# https://everli.recruitee.com/o/finance-business-partner-product-hr-and-central-functions
# https://everli.recruitee.com/o/internal-communication-and-employer-branding-manager
# https://everli.recruitee.com/o/crm-manager-everli-plus-subscription-programme
# https://everli.recruitee.com/o/crm-associate
# https://everli.recruitee.com/o/product-marketing-manager-retail
# https://everli.recruitee.com/o/operations-area-manager-emilia-romagna
# https://everli.recruitee.com/o/city-manager-poznan
# https://everli.recruitee.com/o/city-manager-odz
# https://everli.recruitee.com/o/city-manager-wrocaw
# https://everli.recruitee.com/o/international-expansion-associate-3
# https://everli.recruitee.com/o/back-end-engineer-demand
# https://everli.recruitee.com/o/senior-product-designer
# https://everli.recruitee.com/o/operations-area-manager-toscana-firenze
# https://everli.recruitee.com/o/tech-lead
# https://everli.recruitee.com/o/brand-and-customer-insights-manager-milano
# https://everli.recruitee.com/o/head-of-crm
# https://everli.recruitee.com/o/back-end-engineer-retail-milano
# https://everli.recruitee.com/o/back-end-engineer-l-6899
# https://everli.recruitee.com/o/data-scientist-core
# https://everli.recruitee.com/o/back-end-engineer-operations
# https://everli.recruitee.com/o/data-engineer-1
# https://everli.recruitee.com/o/product-manager-2
# https://everli.recruitee.com/o/specjalisty-ds-ksiegowosci-i-podatkow
# https://everli.recruitee.com/o/junior-marketing-intern-lyon
# https://everli.recruitee.com/o/retail-sales-manager-france
# https://everli.recruitee.com/o/country-manager-czech-republic

# %%
print(database)
print(len(database)-1)
# Out:
# [['job_name', 'country', 'city', 'offer_link'], ['Key Account Support Intern', 'Italy', 'Milano', 'https://everli.recruitee.com/o/key-account-support-intern'], ['Corporate Development and M&A Associate', 'Italy', 'Milano', 'https://everli.recruitee.com/o/corporate-development-and-ma-associate'], ['Consolidation & Reporting Specialist', 'Italy', 'Milano', 'https://everli.recruitee.com/o/consolidation-reporting-specialist'], ['International Talent Acquisition Specialist', 'Italy', 'Milano', 'https://everli.recruitee.com/o/international-talent-acquisition-specialist'], ['Marketing Manager Italy', 'Italy', 'Milano', 'https://everli.recruitee.com/o/marketing-manager-italy-1'], ['Head of Corporate Development and M&A', 'Italy', 'Milano', 'https://everli.recruitee.com/o/head-of-corporate-development-and-ma'], ['Illustration and Motion Designer', 'Italy', 'Milano', 'https://everli.recruitee.com/o/illustration-and-motion-designer'], ['Campaign & Content Designer', 'Italy', 'Milano', 'https://everli.recruitee.com/o/campaign-content-designer'], ['Finance Business Partner - Product, HR and Central Functions', 'Italy', 'Milano', 'https://everli.recruitee.com/o/finance-business-partner-product-hr-and-central-functions'], ['Internal Communication and Employer Branding Manager', 'Italy', 'Milano', 'https://everli.recruitee.com/o/internal-communication-and-employer-branding-manager'], ['CRM Manager - Everli Plus subscription programme', 'Italy', 'Milano', 'https://everli.recruitee.com/o/crm-manager-everli-plus-subscription-programme'], ['CRM Associate', 'Italy', 'Milano', 'https://everli.recruitee.com/o/crm-associate'], ['Product Marketing Manager - Retail', 'Italy', 'Milano', 'https://everli.recruitee.com/o/product-marketing-manager-retail'], ['Operations Area Manager Emilia Romagna', 'Remote', ' ', 'https://everli.recruitee.com/o/operations-area-manager-emilia-romagna'], ['City Manager Poznań', 'Remote', ' ', 'https://everli.recruitee.com/o/city-manager-poznan'], ['City Manager Łódź', 'Remote', ' ', 'https://everli.recruitee.com/o/city-manager-odz'], ['City Manager Wrocław', 'Remote', ' ', 'https://everli.recruitee.com/o/city-manager-wrocaw'], ['International Expansion Associate', 'Remote', ' ', 'https://everli.recruitee.com/o/international-expansion-associate-3'], ['Back End Engineer - Demand', 'Remote', ' ', 'https://everli.recruitee.com/o/back-end-engineer-demand'], ['Senior Product Designer', 'Remote', ' ', 'https://everli.recruitee.com/o/senior-product-designer'], ['Operations Area Manager Toscana', 'Remote', ' ', 'https://everli.recruitee.com/o/operations-area-manager-toscana-firenze'], ['Tech Lead', 'Remote', ' ', 'https://everli.recruitee.com/o/tech-lead'], ['Brand and Customer Insights Manager', 'Remote', ' ', 'https://everli.recruitee.com/o/brand-and-customer-insights-manager-milano'], ['Head of CRM', 'Remote', ' ', 'https://everli.recruitee.com/o/head-of-crm'], ['Back End Engineer - Retail', 'Remote', ' ', 'https://everli.recruitee.com/o/back-end-engineer-retail-milano'], ['Back End Engineer - L. 68/99', 'Remote', ' ', 'https://everli.recruitee.com/o/back-end-engineer-l-6899'], ['Data Scientist - Core', 'Remote', ' ', 'https://everli.recruitee.com/o/data-scientist-core'], ['Back End Engineer - Operations', 'Remote', ' ', 'https://everli.recruitee.com/o/back-end-engineer-operations'], ['Data Engineer', 'Remote', ' ', 'https://everli.recruitee.com/o/data-engineer-1'], ['Product Manager', 'Remote', ' ', 'https://everli.recruitee.com/o/product-manager-2'], ['Specjalisty ds. Księgowości i Podatków', 'Poland', 'Warsaw', 'https://everli.recruitee.com/o/specjalisty-ds-ksiegowosci-i-podatkow'], ['Junior Marketing Intern', 'France', 'Lyon', 'https://everli.recruitee.com/o/junior-marketing-intern-lyon'], ['Retail Sales Manager - France', 'France', 'Lyon', 'https://everli.recruitee.com/o/retail-sales-manager-france'], ['Country Manager - Czech Republic', 'Czechia', 'Praha', 'https://everli.recruitee.com/o/country-manager-czech-republic']]
# 34
