# %% [markdown]
# LYST

# %% [markdown]
# # SCRAPING

# %%
import requests


from requests import get

# Lien de la page à scraper
#url = "https://apply.workable.com/lyst/"
url = "https://www.lyst.fr/emplois/"

response = get(url)
source = None # Le code source de la page 

if response.status_code == 200 :
    # Si la requete s'est bien passee
    source = response.text
    
print(source)
# Out:
# <!DOCTYPE html>
# <html lang="fr" class="no-js">
# <head>
# <meta charset="utf-8">
# <meta http-equiv="X-UA-Compatible" content="IE=edge,chrome=1" />
# <meta http-equiv="x-dns-prefetch-control" content="on">
# <link rel="preconnect" href="//static.lystit.com">
# <link rel="dns-prefetch" href="//static.lystit.com">
# <link rel="preconnect" href="//cdna.lystit.com">
# <link rel="dns-prefetch" href="//cdna.lystit.com">
# <link rel="preconnect" href="//googleads.g.doubleclick.net">
# <link rel="dns-prefetch" href="//googleads.g.doubleclick.net">
# <link rel="preconnect" href="//www.googleadservices.com">
# <link rel="dns-prefetch" href="//www.googleadservices.com">
# <link rel="preconnect" href="//js-agent.newrelic.com">
# <link rel="dns-prefetch" href="//js-agent.newrelic.com">
# <link rel="preconnect" href="//www.google-analytics.com">
# <link rel="dns-prefetch" href="//www.google-analytics.com">
# <link rel="preconnect" href="//sc-static.net">
# <link rel="dns-prefetch" href="//sc-static.net">
# <meta name="viewport" content="width=device-width, initial-scale=1.0, maximum-scale=1.0, user-scalable=no">
# <link rel="preload" href="https://static.lystit.com/static/n/fonts/SuisseIntl-Regular-WebS.5ff578be98a31a99629e8169b3c904de.woff2" as="font" type="font/woff2" crossorigin>
# <link rel="preload" href="https://static.lystit.com/static/n/fonts/SuisseIntl-Bold-WebS.14b102a6d21cfc5d3b9634c173ff2b13.woff2" as="font" type="font/woff2" crossorigin>
# <script>var dc=document.documentElement.classList;dc.remove("no-js");dc.add("js")</script>
# <link rel="alternate" hreflang="x-default" href="https://www.lyst.com/careers/" />
# <link rel="alternate" hreflang="en-gb" href="https://www.lyst.co.uk/careers/" />
# <link rel="alternate" hreflang="en-au" href="https://www.lyst.com/en-au/careers/" />
# <link rel="alternate" hreflang="en-ca" href="https://www.lyst.com/en-ca/careers/" />
# <link rel="alternate" hreflang="fr-fr" href="https://www.lyst.fr/emplois/" />
# <link rel="alternate" hreflang="it-it" href="https://www.lyst.it/opportunit%C3%A0-di-lavoro/" />
# <link rel="alternate" hreflang="de-de" href="https://www.lyst.de/karriere/" />
# <link rel="alternate" hreflang="es-es" href="https://www.lyst.com/es-es/empleo/" />
# <link rel="alternate" hreflang="ja-jp" href="https://www.lyst.com/ja-jp/%E6%B1%82%E4%BA%BA/" />
# <link rel="alternate" hreflang="ru-ru" href="https://www.lyst.com/ru-ru/%D0%BA%D0%B0%D1%80%D1%8C%D0%B5%D1%80%D0%B0/" />
# <link rel="alternate" hreflang="nl-nl" href="https://www.lyst.com/nl-nl/vacatures/" />
# <link rel="alternate" hreflang="de-at" href="https://www.lyst.com/de-at/karriere/" />
# <link rel="alternate" hreflang="de-ch" href="https://www.lyst.com/de-ch/karriere/" />
# <link rel="alternate" hreflang="nl-be" href="https://www.lyst.com/nl-be/vacatures/" />
# <title>Lyst - Travailler chez Lyst</title>
# <link type="text/css" href="https://static.lystit.com/static/n/web/css/feeds~homepage~main~track-email-interstitial~track-redirect~webviews.ed775523a1654a4a6793.css" rel="stylesheet" media="all" />
# <link type="text/css" href="https://static.lystit.com/static/n/web/css/feeds~homepage~main~track-email-interstitial~webviews.8bceb889818c10470de6.css" rel="stylesheet" media="all" />
# <link type="text/css" href="https://static.lystit.com/static/n/web/css/feeds~homepage~main.1526cc3e739f99242ed0.css" rel="stylesheet" media="all" />
# <link type="text/css" href="https://static.lystit.com/static/n/web/css/feeds~main.08db07e243116beac2db.css" rel="stylesheet" media="all" />
# <link type="text/css" href="https://static.lystit.com/static/n/web/css/main.370030c6e8a87e78eb73.css" rel="stylesheet" media="all" />
# <meta name="theme-color" content="#000000">
# <link href='https://api.mapbox.com/mapbox-gl-js/v1.11.0/mapbox-gl.css' rel='stylesheet' />
# <meta name="description" content="Si vous voulez nous aider à changer le futur de la mode et de l’e-commerce, cliquez ici pour parcourir la liste des postes à pourvoir.">
# <meta property="fb:app_id" content="152784791451625">
# <meta property="al:web:should_fallback" content="false">
# <link rel="icon" href="/favicon.ico">
# <link rel="apple-touch-icon-precomposed" sizes="152x152" href="/apple-touch-icon-152x152.png">
# <link rel="apple-touch-icon-precomposed" sizes="120x120" href="/apple-touch-icon-120x120.png">
# <link rel="search" type="application/opensearchdescription+xml" href="//static.lystit.com/static/n/misc/opensearch.378670c460bd.xml" title="Lyst">
# <link rel="canonical" href="https://www.lyst.fr/emplois/">
# <script type="text/javascript">(window.NREUM||(NREUM={})).init={privacy:{cookies_enabled:false},distributed_tracing:{enabled:true}};(window.NREUM||(NREUM={})).loader_config={agentID:"3502639",accountID:"228560",trustKey:"228560",xpid:"VgQPVFBTGwAFVFNUBAI=",licenseKey:"7db5f3f67d",applicationID:"3502633"};window.NREUM||(NREUM={}),__nr_require=function(t,e,n){function r(n){if(!e[n]){var o=e[n]={exports:{}};t[n][0].call(o.exports,function(e){var o=t[n][1][e];return r(o||e)},o,o.exports)}return e[n].exports}if("function"==typeof __nr_require)return __nr_require;for(var o=0;o<n.length;o++)r(n[o]);return r}({1:[function(t,e,n){function r(t){try{c.console&&console.log(t)}catch(e){}}var o,i=t("ee"),a=t(29),c={};try{o=localStorage.getItem("__nr_flags").split(","),console&&"function"==typeof console.log&&(c.console=!0,o.indexOf("dev")!==-1&&(c.dev=!0),o.indexOf("nr_dev")!==-1&&(c.nrDev=!0))}catch(s){}c.nrDev&&i.on("internal-error",function(t){r(t.stack)}),c.dev&&i.on("fn-err",function(t,e,n){r(n.stack)}),c.dev&&(r("NR AGENT IN DEVELOPMENT MODE"),r("flags: "+a(c,function(t,e){return t}).join(", ")))},{}],2:[function(t,e,n){function r(t,e,n,r,c){try{p?p-=1:o(c||new UncaughtException(t,e,n),!0)}catch(f){try{i("ierr",[f,s.now(),!0])}catch(d){}}return"function"==typeof u&&u.apply(this,a(arguments))}function UncaughtException(t,e,n){this.message=t||"Uncaught error with no additional information",this.sourceURL=e,this.line=n}function o(t,e){var n=e?null:s.now();i("err",[t,n])}var i=t("handle"),a=t(30),c=t("ee"),s=t("loader"),f=t("gos"),u=window.onerror,d=!1,l="nr@seenError";if(!s.disabled){var p=0;s.features.err=!0,t(1),window.onerror=r;try{throw new Error}catch(h){"stack"in h&&(t(13),t(12),"addEventListener"in window&&t(6),s.xhrWrappable&&t(14),d=!0)}c.on("fn-start",function(t,e,n){d&&(p+=1)}),c.on("fn-err",function(t,e,n){d&&!n[l]&&(f(n,l,function(){return!0}),this.thrown=!0,o(n))}),c.on("fn-end",function(){d&&!this.thrown&&p>0&&(p-=1)}),c.on("internal-error",function(t){i("ierr",[t,s.now(),!0])})}},{}],3:[function(t,e,n){var r=t("loader");r.disabled||(r.features.ins=!0)},{}],4:[function(t,e,n){function r(){L++,T=g.hash,this[u]=y.now()}function o(){L--,g.hash!==T&&i(0,!0);var t=y.now();this[h]=~~this[h]+t-this[u],this[d]=t}function i(t,e){E.emit("newURL",[""+g,e])}function a(t,e){t.on(e,function(){this[e]=y.now()})}var c="-start",s="-end",f="-body",u="fn"+c,d="fn"+s,l="cb"+c,p="cb"+s,h="jsTime",m="fetch",v="addEventListener",w=window,g=w.location,y=t("loader");if(w[v]&&y.xhrWrappable&&!y.disabled){var x=t(10),b=t(11),E=t(8),R=t(6),O=t(13),N=t(7),M=t(14),P=t(9),C=t("ee"),S=C.get("tracer");t(16),y.features.spa=!0;var T,L=0;C.on(u,r),b.on(l,r),P.on(l,r),C.on(d,o),b.on(p,o),P.on(p,o),C.buffer([u,d,"xhr-done","xhr-resolved"]),R.buffer([u]),O.buffer(["setTimeout"+s,"clearTimeout"+c,u]),M.buffer([u,"new-xhr","send-xhr"+c]),N.buffer([m+c,m+"-done",m+f+c,m+f+s]),E.buffer(["newURL"]),x.buffer([u]),b.buffer(["propagate",l,p,"executor-err","resolve"+c]),S.buffer([u,"no-"+u]),P.buffer(["new-jsonp","cb-start","jsonp-error","jsonp-end"]),a(M,"send-xhr"+c),a(C,"xhr-resolved"),a(C,"xhr-done"),a(N,m+c),a(N,m+"-done"),a(P,"new-jsonp"),a(P,"jsonp-end"),a(P,"cb-start"),E.on("pushState-end",i),E.on("replaceState-end",i),w[v]("hashchange",i,!0),w[v]("load",i,!0),w[v]("popstate",function(){i(0,L>1)},!0)}},{}],5:[function(t,e,n){function r(t){}if(window.performance&&window.performance.timing&&window.performance.getEntriesByType){var o=t("ee"),i=t("handle"),a=t(13),c=t(12),s="learResourceTimings",f="addEventListener",u="resourcetimingbufferfull",d="bstResource",l="resource",p="-start",h="-end",m="fn"+p,v="fn"+h,w="bstTimer",g="pushState",y=t("loader");if(!y.disabled){y.features.stn=!0,t(8),"addEventListener"in window&&t(6);var x=NREUM.o.EV;o.on(m,function(t,e){var n=t[0];n instanceof x&&(this.bstStart=y.now())}),o.on(v,function(t,e){var n=t[0];n instanceof x&&i("bst",[n,e,this.bstStart,y.now()])}),a.on(m,function(t,e,n){this.bstStart=y.now(),this.bstType=n}),a.on(v,f ...
# <script>
#
#     var Lyst = {
#         data: {"pageType":"about","pageSubType":"careers","features":{"mg_cookie_consent_settings":false,"mg_cookie_consent_larger_cta":false,"uf_upper_funnel_journey":false,"uf_load_previous":false,"uf_feed_filters_redesign":false,"mg_app_download_email_combo":false,"mg_getfeedback":false,"checkout_klarna_messaging":false,"seo_lazy_load_navigation":true,"mg_financial_incentives_homepage":"","mg_android_email_signup_banner":false,"mg_android_email_signup_banner_desc":"","mg_financial_incentives_homepage_value":"","mg_financial_incentives_feed":"","mg_financial_incentives_feed_value":"","mg_financial_incentives_is_pdp":"","mg_financial_incentives_is_pdp_value":"","mg_product_card_alt_image":false,"mg_product_hover_event":false},"hotjar":null},
#         environment: {"country":"FR","csrftoken":"MrkWgdZj2r3UsTWyLtaqXtJNXv5eEuDXDPVHiRgT0S3uCGpnl4AI1JfxlFkxPKYb","eu_geoip_country":true,"language":"fr-fr","domainDefaultLanguageIsEnglish":false,"forceShowEnglishOnlyFeatures":false,"urlPatterns":{"productPageRegex":"^/?(accessoires|chaussures|vetements|maison|bijoux|sacs)/([%-\\w]+)/$","searchPage":"recherche","signupPageRegex":"^/?(account)/(register|login)/$","rothkoEndpoint":"/api/rothko/","helpContactUs":"/aide/nous-contacter/","about":"/%C3%A0-propos/","careers":"/emplois/","exploreFeed":"/explore/","helpCentreHomepage":"https://help.lyst.com/hc/change_language/fr-fr?return_to=/hc/fr-fr","helpTermsAndConditions":"/aide/conditions-generales/","helpPrivacyPolicy":"/aide/politique-de-confidentialite/","helpIntellectualProperty":"/aide/propriete-intellectuelle/","helpCookiePolicy":"/aide/politique-de-cookies/","partnerContact":"/partenaires/","sitemapsAllCategories":"/sitemap/categories/","articleIndex":"/articles/"},"productNamesToTypes":{"Clothing":"A","Shoes":"S","Accessories":"R","Bags":"B","Jewelry":"J","Home":"H"},"currentTranslationsFilesPaths":{"django":{"path":"../locale/fr/LC_MESSAGES/django.json","versionName":"fr_django_a9efd5ba4b713fe66983253c3a08109843795be1b5f092bd4c317838aac0f2c1.zip"},"djangojs":{"path":"../locale/fr/LC_MESSAGES/djangojs.json","versionName":"fr_djangojs_8d97e3b360fd48c775710707ab2698c5bec15c9bfde9f56b3d12d4b6d4e1dd31.zip"}},"isProduction":true,"gaUaAccount":"UA-5946484-12","agifAnalyticsUrl":"//api.ldnlyap.com/lyst.gif","analyticsCookieVersion":1,"currencyProps":{"currencyCode":"EUR","currencySymbol":"\u20ac","currencyIndicator":"\u20ac","currencyDecimalPlaces":2,"priceWithCurrencySymbolFormat":"{price}\u00a0{currency_symbol}","priceWithCurrencySymbolFormatInItempropSpans":"&lt;span {price_span_props}&gt;{price}&lt;/span&gt;&lt;span {currency_symbol_span_props}&gt;&amp;nbsp;{currency_symbol}&lt;/span&gt;"},"gaVariables":{"dimension12":"about","dimension19":"careers","contentGroup1":"about","dimension2":"Visitor"},"userName":null,"userLoggedIn":false,"userSignedInStatus":"no","userSlug":null,"userAvatar":null,"lystId":null,"userId":null,"userGender":null,"facebookAppId":"152784791451625","channelUrl":"https://www.lyst.com/facebook-channel.html","ipAddress":"86.242.54.146","pageViewId":"8a3c6606-ae82-446b-8fe2-b717e16ff836","timestamp_ms":1623681172377,"messages":[],"disable_third_party_js":false,"showPromoCode":false,"s4lFeedTooltip":true,"enable_branch_io":false,"paidNoRetarget":"nope","lifeCycleStage":"prospecting","trafficSource":"","firstTimeLogin":false,"boomLeadSignupPrompt":false,"branchIoKey":"key_live_glC2sUCTNt2zrOAWq49iTjnhsFblPHmX","heimdallFlags":["null_test_enabled","hotjar_on_feeds_journeys_disabled","mg_cookie_consent_settings_disabled"],"release":"v3083","release_sha":"677eb10c0748782e967eea8d4eb8fbeab7a501f3","cookieVersions":{"customization":1,"advertisement":1,"analytics":1},"snapchatHash":null,"webToAppCpi":{"Email to App - Footer":0.0,"Web to App - CSS Lead Return - General":0.05,"Web to App - Feed - General":0.5,"Web to App - Feed - Product card click":0.54,"Web to App - Feed - Show More Button":0.54,"Web to App - Footer":0.0,"Web to App - Homepage - General":0.42,"Web to App - In Stock PDP - General":1.28,"Web to App - In Stock PDP - Shop Now button":0.03,"Web to App - In Stock PDP - Show More Button":0.53,"Web to App - Out of Stock PDP - General":0.59,"Web to App - Out of Stock PDP - Show More Button":0.09,"Web to App - Show More Button":0.47},"isPlaUtmCampaign":false,"activeWebToAppBanners":["mg_app_banner_feed","mg_app_banner_homepage","mg_app_banner_is_pdp","mg_app_banner_oos_pdp","mg_app_banner_css_lead_return"],"activeWebToAppBlocks":["mg_block_shop_now_is_pdp","mg_block_related_show_more_is_pdp","mg_block_related_show_more_oos_pdp"]}
#     };
#
#     (function (data) {
#         try {
#             var name = data.pageType + (data.pageSubType ? '/' + data.pageSubType : '');
#             var testBucket = data.testBucket;
#
#             if (name) {
#                 if (testBucket) {
#                     var viewName = name + '/' + testBucket;
#                     NREUM.setPageViewName(viewName);
#                 }
#                 else {
#                     NREUM.setPageViewName(name);
#                 }
#             }
#         }
#         catch (e) {}
#     })(Lyst.data);
# </script>
# <script>
#     function loadCatalog(data) {
#         var django = this.django || (this.django = {});
#         django.translationsCatalog = data;
#     }
#
#     function translationsError(event, error) {
#         // TODO: do something with event/error
#         NREUM && NREUM.noticeError('Translations Failed!')
#     }
# </script>
# <script type="text/javascript" src="https://static.lystit.com/static/n/web/script/runtime.e9b98cf518cb11896524.js" defer crossorigin></script>
# <script type="text/javascript" src="https://static.lystit.com/static/n/web/script/vendors~feeds~homepage~main~track-email-interstitial~webviews.91c898473b949b20e948.js" defer crossorigin></script>
# <script type="text/javascript" src="https://static.lystit.com/static/n/web/script/vendors~main.dd8b035c392a7c1285cf.js" defer crossorigin></script>
# <script type="text/javascript" defer crossorigin>(window.webpackJsonp=window.webpackJsonp||[]).push([[1],{288:function(n,w,o){}}]);
# //# sourceMappingURL=https://static.lystit.com/static/n/web/script/feeds~homepage~main~track-email-interstitial~track-redirect~webviews.78d4b26bd0ef98c69162.js.map</script>
# <script type="text/javascript" src="https://static.lystit.com/static/n/web/script/feeds~homepage~main~track-email-interstitial~webviews.8fc6f78ee76123ae179b.js" defer crossorigin></script>
# <script type="text/javascript" src="https://static.lystit.com/static/n/web/script/feeds~homepage~main.cb0acd2a2cefdb8b068e.js" defer crossorigin></script>
# <script type="text/javascript" src="https://static.lystit.com/static/n/web/script/feeds~main.3b06ff0a62a1d0628cab.js" defer crossorigin></script>
# <script type="text/javascript" src="https://static.lystit.com/static/n/web/script/main.64f37f5f15356538a17c.js" defer crossorigin></script>
# <script type="text/javascript" onerror="translationsError(event, error)" src="/i18n/jsoni18n.js/?bundle_ids=feeds~homepage~main.js,feeds~homepage~main~track-email-interstitial~webviews.js,feeds~main.js,feeds~homepage~main~track-email-interstitial~track-redirect~webviews.js,vendors~main.js,main.js,vendors~feeds~homepage~main~track-email-interstitial~webviews.js,runtime.js"></script>
# <div data-hypernova-key="JSONLDOrganization" data-hypernova-id="707185ea-edc7-482c-8b53-59ff385214bc"><script type="application/ld+json" data-reactroot="">{"@context":"http://schema.org","@type":"Organization","name":"Lyst","url":"https://www.lyst.fr","sameAs":["https://twitter.com/lyst","https://www.facebook.com/Lyst","https://instagram.com/lyst/","https://plus.google.com/+LYST","https://www.pinterest.com/Lyst/","http://lyst.tumblr.com/"]}</script></div>
# <script type="application/json" data-hypernova-key="JSONLDOrganization" data-hypernova-id="707185ea-edc7-482c-8b53-59ff385214bc"><!--{"url":"https://www.lyst.fr"}--></script>
# </head>
# <body is="lyst-app" class="lyst-app
#
#
#
#
#
#                  header-bg-careers
#                  ">
# <div class="icon-sprite-map">
# <svg xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink">
# <defs>
# <symbol viewBox="0 0 28 28" id="account-icon"><g stroke="none" stroke-width="1" fill="none" fill-rule="evenodd"><path d="M10,7 C10,4.79442411 11.7944241,3 14,3 C16.2055759,3 18,4.79442411 18,7 C18,9.20557589 16.2055759,11 14,11 C11.7944241,11 10,9.20557589 10,7 M21.3524505,7.65907592 C21.3524505,3.43577608 18.0531804,0 14,0 C9.94577685,0 6.64754953,3.43577608 6.64754953,7.65907592 C6.64754953,9.59041006 7.34306569,11.353377 8.48070907,12.7014005 C3.49843587,14.9368817 0,20.0986926 0,26.0990806 C0,27.1483881 0.816475495,28 1.82481752,28 C2.83315954,28 3.64963504,27.1483881 3.64963504,26.0990806 C3.64963504,20.1540909 8.29301356,15.3181518 14,15.3181518 C19.7059437,15.3181518 24.350365,20.1540909 24.350365,26.0990806 C24.350365,27.1483881 25.1668405,28 26.1751825,28 C27.1824818,28 28,27.1483881 28,26.0990806 C28,20.0986926 24.5015641,14.9368817 19.5192909,12.7014005 C20.6558916,11.353377 21.3524505,9.59041006 21.3524505,7.65907592 Z" id="Fill-1" fill="#FFFFFF"></path></g></symbol>
# <symbol viewBox="0 0 28 28" id="basket-icon"><g stroke="none" stroke-width="1" fill="none" fill-rule="evenodd"><g fill="currentColor" fill-rule="nonzero"><path d="M21,8.62573242 L21,7.5 C21,3.38559685 17.8965362,-8.8817842e-16 14,-8.8817842e-16 C10.1034638,-8.8817842e-16 7,3.38559685 7,7.5 L7,8.62573242 L10,8.62573242 L10,7.5 C10,4.98698616 11.821404,3 14,3 C16.178596,3 18,4.98698616 18,7
# <symbol viewBox="0 0 28 28" id="cart"><path d="M13.1124119 3l-3.61313533 7h9.00144683l-3.6131353-7h-1.7751762zm8.5370491 7H28l-2 18H2L0 10h6.35053902L11.2219007 0h5.5561986l4.8713617 10z" fill="currentColor" fill-rule="evenodd" /></symbol>
# <symbol viewBox="0 0 28 28" id="chevron"><path d="M20.19238816 17.67695526L11 26.86934342l-3.67695526-3.67695526L16.51543289 14l-6.50644604-6.50644605-2.68594211-2.6859421L11 1.13065657 23.86934342 14l-3.67695526 3.67695526z" fill="currentColor" fill-rule="evenodd" /></symbol>
# <symbol viewBox="0 0 20 12" id="chevron-thin"><path fill-rule="evenodd" clip-rule="evenodd" d="M1.25226 0.888787L0 2.12354L8.76811 10.7657L8.76411 10.7697L10.013 12L10.0167 11.9964L10.0203 11.9999L11.2726 10.7652L11.2692 10.7618L20 2.15578L18.7516 0.925464L10.0206 9.53121L1.25226 0.888787Z" fill="black" /></symbol>
# <symbol viewBox="0 0 20 20" id="clear"><circle cx="10" cy="10" r="10" fill="#e0e1e7" /><path d="M10 11l-3.4 3.4-1-1L9 10 5.6 6.6l1-1L10 9l3.4-3.4 1 1L11 10l3.4 3.4-1 1L10 11z" fill="#707070" /></symbol>
# <symbol viewBox="0 0 28 28" id="cross"><path d="M11.172 14l-3.53-3.53-3.54-3.54L6.928 4.1 14 11.173l7.07-7.07L23.9 6.93 16.827 14l7.07 7.07-2.827 2.83L14 16.827l-7.07 7.07L4.1 21.07 11.173 14z" fill="currentColor" fill-rule="evenodd" /></symbol>
# <symbol viewBox="0 0 24 24" id="cross-thin"><path fill-rule="evenodd" clip-rule="evenodd" d="M12 10.9394L3.06067 2L2.00001 3.06066L10.9394 12L2 20.9394L3.06066 22L12 13.0607L20.9393 22L22 20.9394L13.0607 12.0001L22.0001 3.06072L20.9394 2.00006L12 10.9394Z" fill="currentColor" /></symbol>
# <symbol viewBox="0 0 28 28" id="discount"><path fill="none" stroke-linecap="round" stroke="white" stroke-width="2" d="M3.865 9.072L8.902 15.25l7.178-4.842 6.455 9.57M18.252 20.079l5.008.973.974-5.008" /></symbol>
# <symbol viewBox="0 0 28 28" id="external-link"><path d="M21.068 4.068L17 0h11v11l-4.457-4.457-9.068 9.07L12 13.136l9.068-9.07zM14 4V0h14v14h-4v10H4V4h10zM0 28h28V0H0v28z" fill="currentColor" fill-rule="evenodd" /></symbol>
# <symbol viewBox="0 0 48 48" id="fat-arrow"><path fill="currentColor" d="m24 0-24 24h12.25l-.17 24.5 23.25.08.34-24.58h12.33z" /></symbol>
# <symbol viewBox="0 0 24 24" id="filters"><path d="M7 9.5c.82843 0 1.5-.67157 1.5-1.5S7.82843 6.5 7 6.5 5.5 7.17157 5.5 8 6.17157 9.5 7 9.5zM7 11c1.39788 0 2.57245-.9561 2.90549-2.25H22v-1.5H9.90549C9.57245 5.95608 8.39788 5 7 5s-2.57245.95608-2.90549 2.25H2v1.5h2.09451C4.42755 10.0439 5.60212 11 7 11zm10 6.5c.8284 0 1.5-.6716 1.5-1.5s-.6716-1.5-1.5-1.5-1.5.6716-1.5 1.5.6716 1.5 1.5 1.5zm0 1.5c1.3979 0 2.5725-.9561 2.9055-2.25H22v-1.5h-2.0945C19.5725 13.9561 18.3979 13 17 13s-2.5725.9561-2.9055 2.25H2v1.5h12.0945C14.4275 18.0439 15.6021 19 17 19z" fill="currentColor" fill-rule="evenodd" /></symbol>
7334523,4.01464636 C12.9085595,4.1819825 14.072194,3.80157913 14.9253775,2.97144375 L17.6011116,0.367786407 C18.1050593,-0.122595469 18.8947142,-0.122595469 19.3988331,0.367786407 L22.0744816,2.97144375 C22.9276651,3.80166526 24.0911283,4.1819825 25.2664068,4.01464636 L28.9525191,3.49015995 C29.6466243,3.39137736 30.2857628,3.85824778 30.4069123,4.55308462 L31.0500748,8.24162789 C31.2552156,9.41771762 31.9742357,10.4132083 33.0227995,10.9727466 L36.3113874,12.7279245 C36.9309193,13.058549 37.1749307,13.81393 36.8669627,14.4477059 L35.2320011,17.8119978 C34.7107586,18.8846543 34.7107586,20.1151735 35.2320011,21.18783 L36.8669627,24.5521218 C37.1750163,25.18607 36.9310049,25.9415371 36.311473,26.2721617 Z" id="Shape" fill="#F5B9A1"></path></g></g></g></g></symbol>
# <symbol viewBox="0 0 28 28" id="heart-unpressed"><path d="M14.01 26.63c-.26 0-.51-.11-.7-.29L2.35 15.21c-3.14-3.18-3.14-8.38 0-11.59a7.956 7.956 0 015.72-2.41c2.17 0 4.21.85 5.74 2.4l.19.2.19-.19a8.02 8.02 0 015.73-2.4c2.17 0 4.21.85 5.73 2.4 3.13 3.21 3.13 8.41 0 11.6L14.71 26.34a.95.95 0 01-.7.29zM8.07 3.17c-1.64 0-3.17.65-4.32 1.82-2.39 2.45-2.4 6.42 0 8.85l10.27 10.43 10.24-10.41c2.39-2.44 2.39-6.41 0-8.86a6.035 6.035 0 00-4.33-1.82c-1.63 0-3.17.65-4.34 1.82l-.88.9c-.37.37-1.02.37-1.39 0l-.89-.9a6.066 6.066 0 00-4.36-1.83z" fill="currentColor" /></symbol>
# <symbol viewBox="0 0 28 28" id="heart-pressed"><path d="M25.76 3.67a7.53 7.53 0 00-5.41-2.27c-1.95 0-3.91.76-5.41 2.27l-.94.96-.95-.97A7.61 7.61 0 007.63 1.4c-1.96 0-3.91.76-5.39 2.27-2.98 3.05-2.98 7.95 0 10.98L14.01 26.6l10.8-10.98.95-.97c2.99-3.03 2.99-7.93 0-10.98z" fill="currentColor" /></symbol>
# ...
# <div class="lyst-app__layout-container lyst-app__layout-container--no-top-white-space">
# <div class="lyst-app__matte"></div>
# <div is="default-layout" class="default-layout">
# <div class="default-layout__content page-block p40 mb5">
# <div class="careers">
# <div class="careers__page-header mb40">
# <h1 class="heading-1 ">Emplois chez Lyst</h1>
# <p class="hero-paragraph">Si vous êtes passionné par ce que nous faisons et que vous avez un talent unique à apporter à l’équipe, contactez-nous à <a href="/cdn-cgi/l/email-protection" class="__cf_email__" data-cfemail="81ebeee3f2c1edf8f2f5afe2eeecaf">[email&#160;protected]</a></p>
# </div>
# <div class="careers__life-at-lyst-video mb60">
# <iframe width="560" height="315" src="https://www.youtube.com/embed/JE2zqi3ZzTg?amp=&feature=youtu.be&controls=0&modestbranding=1&rel=0&showinfo=0">
#                     </iframe>
# </div>
# <div class="careers__column">
# <div class="mb40">
# <h3 class="heading-3 mb20">Postes à Londres, Royaume-Uni</h3>
# <ul class="job-listing mb80">
# <li>
#  <a href="https://apply.workable.com/j/CF9C2E9D74" class="job-listing__job">
# Android Engineer
# <svg class="svg-icon svg-icon-chevron">
# <use xlink:href="#chevron"></use>
# </svg>
# <span class="job-listing__job-details">Full-time</span>
# </a>
# </li>
# <li>
# <a href="https://apply.workable.com/j/196FAF8A52" class="job-listing__job">
# Backend Engineer - Contract Opportunity
# <svg class="svg-icon svg-icon-chevron">
# <use xlink:href="#chevron"></use>
# </svg>
# <span class="job-listing__job-details">Contract</span>
# </a>
# </li>
# <li>
# <a href="https://apply.workable.com/j/ED7D5CC37C" class="job-listing__job">
# Full Stack Engineer - Contract Opportunity
# <svg class="svg-icon svg-icon-chevron">
# <use xlink:href="#chevron"></use>
# </svg>
# <span class="job-listing__job-details">Contract</span>
# </a>
# </li>
# <li>
# <a href="https://apply.workable.com/j/403E021C11" class="job-listing__job">
# Full-Stack Engineer | Checkout Product
# <svg class="svg-icon svg-icon-chevron">
# <use xlink:href="#chevron"></use>
# </svg>
# <span class="job-listing__job-details">Full-time</span>
# </a>
# </li>
# <li>
# <a href="https://apply.workable.com/j/F88CA95C5D" class="job-listing__job">
# Fullstack Engineer | Upper Funnel
# <svg class="svg-icon svg-icon-chevron">
# <use xlink:href="#chevron"></use>
# </svg>
# <span class="job-listing__job-details">Full-time</span>
# </a>
# </li>
# <li>
# <a href="https://apply.workable.com/j/5ED5BD8FD6" class="job-listing__job">
# Lead Analytics Engineer
# <svg class="svg-icon svg-icon-chevron">
# <use xlink:href="#chevron"></use>
# </svg>
# <span class="job-listing__job-details">Full-time</span>
# </a>
# </li>
# <li>
# <a href="https://apply.workable.com/j/F7CD09B5DE" class="job-listing__job">
# Lead Backend Engineer | Checkout Integration
# <svg class="svg-icon svg-icon-chevron">
# <use xlink:href="#chevron"></use>
# </svg>
# <span class="job-listing__job-details">Full-time</span>
# </a>
# </li>
# <li>
# <a href="https://apply.workable.com/j/D9B2AE5A34" class="job-listing__job">
# Lead Data Engineer | Infrastructure
# <svg class="svg-icon svg-icon-chevron">
# <use xlink:href="#chevron"></use>
# </svg>
# <span class="job-listing__job-details">Full-time</span>
# </a>
# </li>
# <li>
# <a href="https://apply.workable.com/j/21D9B0C939" class="job-listing__job">
# Lead Platform Engineer | Infrastructure
# <svg class="svg-icon svg-icon-chevron">
# <use xlink:href="#chevron"></use>
# </svg>
# <span class="job-listing__job-details">Full-time</span>
# </a>
# </li>
# <li>
# <a href="https://apply.workable.com/j/E7ADFA1E65" class="job-listing__job">
# Lead Software Engineer | Core Data
# <svg class="svg-icon svg-icon-chevron">
# <use xlink:href="#chevron"></use>
# </svg>
# <span class="job-listing__job-details">Full-time</span>
# </a>
# </li>
# <li>
# <a href="https://apply.workable.com/j/861210FC4D" class="job-listing__job">
# Partner Acquisition Executive
# <svg class="svg-icon svg-icon-chevron">
# <use xlink:href="#chevron"></use>
# </svg>
# <span class="job-listing__job-details">Full-time</span>
# </a>
# </li>
# <li>
# <a href="https://apply.workable.com/j/A346702A44" class="job-listing__job">
# People &amp; Operations Assistant
# <svg class="svg-icon svg-icon-chevron">
# <use xlink:href="#chevron"></use>
# </svg>
# <span class="job-listing__job-details">Full-time</span>
# </a>
# </li>
# <li>
# <a href="https://apply.workable.com/j/9FAE4CEBDB" class="job-listing__job">
# Performance Marketing Lead
# <svg class="svg-icon svg-icon-chevron">
# <use xlink:href="#chevron"></use>
# </svg>
# <span class="job-listing__job-details">Full-time</span>
# </a>
# </li>
# <li>
# <a href="https://apply.workable.com/j/A92E3A8774" class="job-listing__job">
# Principal Product Designer
# <svg class="svg-icon svg-icon-chevron">
# <use xlink:href="#chevron"></use>
# </svg>
# <span class="job-listing__job-details">Full-time</span>
# </a>
# </li>
# <li>
# <a href="https://apply.workable.com/j/F64789C369" class="job-listing__job">
# Programmatic Display Account Manager / Display Ad Operations Manager
# <svg class="svg-icon svg-icon-chevron">
# <use xlink:href="#chevron"></use>
# </svg>
# <span class="job-listing__job-details">Full-time</span>
# </a>
# </li>
# <li>
# <a href="https://apply.workable.com/j/FFE2BFF3A2" class="job-listing__job">
# Senior Backend Engineer | App
# <svg class="svg-icon svg-icon-chevron">
# <use xlink:href="#chevron"></use>
# </svg>
# <span class="job-listing__job-details">Full-time</span>
# </a>
# </li>
# <li>
# <a href="https://apply.workable.com/j/9F894D86B2" class="job-listing__job">
# Senior Data Engineer | Commercial Data
# <svg class="svg-icon svg-icon-chevron">
# <use xlink:href="#chevron"></use>
# </svg>
# <span class="job-listing__job-details">Full-time</span>
# </a>
# </li>
# <li>
# <a href="https://apply.workable.com/j/6743B5E50C" class="job-listing__job">
# Senior Data Scientist - Data Enrichment
# <svg class="svg-icon svg-icon-chevron">
# <use xlink:href="#chevron"></use>
# </svg>
# <span class="job-listing__job-details">Full-time</span>
# </a>
# </li>
# <li>
# <a href="https://apply.workable.com/j/75B06C1840" class="job-listing__job">
# Senior Full Stack Engineer | Member Growth
# <svg class="svg-icon svg-icon-chevron">
# <use xlink:href="#chevron"></use>
# </svg>
# <span class="job-listing__job-details">Full-time</span>
# </a>
# </li>
# <li>
# <a href="https://apply.workable.com/j/8FA77F0366" class="job-listing__job">
# Senior Partner Acquisition Manager
# <svg class="svg-icon svg-icon-chevron">
# <use xlink:href="#chevron"></use>
# </svg>
# <span class="job-listing__job-details">Full-time</span>
# </a>
# </li>
# <li>
# <a href="https://apply.workable.com/j/4AD50049A6" class="job-listing__job">
# Senior Performance Marketing Analyst | Paid Search
# <svg class="svg-icon svg-icon-chevron">
# <use xlink:href="#chevron"></use>
# </svg>
# <span class="job-listing__job-details">Full-time</span>
# </a>
# </li>
# <li>
# <a href="https://apply.workable.com/j/ABE9D774EC" class="job-listing__job">
# Senior Performance Marketing Analyst | Shopping
# <svg class="svg-icon svg-icon-chevron">
# <use xlink:href="#chevron"></use>
# </svg>
# <span class="job-listing__job-details">Full-time</span>
# </a>
# </li>
# <li>
# <a href="https://apply.workable.com/j/74A714D716" class="job-listing__job">
# Senior Python Engineer | Commercial Data
# <svg class="svg-icon svg-icon-chevron">
# <use xlink:href="#chevron"></use>
# </svg>
# <span class="job-listing__job-details">Full-time</span>
# </a>
# </li>
# <li>
# <a href="https://apply.workable.com/j/D12788AE51" class="job-listing__job">
# Senior Software Engineer | Checkout Core
# <svg class="svg-icon svg-icon-chevron">
# <use xlink:href="#chevron"></use>
# </svg>
# <span class="job-listing__job-details">Full-time</span>
# </a>
# </li>
# <li>
# <a href="https://apply.workable.com/j/8DE8D2E8F5" class="job-listing__job">
# Senior Software Engineer | Commercial Data
# <svg class="svg-icon svg-icon-chevron">
# <use xlink:href="#chevron"></use>
# </svg>
# <span class="job-listing__job-details">Full-time</span>
# </a>
# </li>
# <li>
# <a href="https://apply.workable.com/j/D51FFF67A2" class="job-listing__job">
# Senior Software Engineer | Search &amp; Rank
# <svg class="svg-icon svg-icon-chevron">
# <use xlink:href="#chevron"></use>
# </svg>
# <span class="job-listing__job-details">Full-time</span>
# </a>
# </li>
# <li>
# <a href="https://apply.workable.com/j/886DDC1E78" class="job-listing__job">
# Senior iOS Engineer | Core
# <svg class="svg-icon svg-icon-chevron">
# <use xlink:href="#chevron"></use>
# </svg>
# <span class="job-listing__job-details">Full-time</span>
# </a>
# </li>
# <li>
# <a href="https://apply.workable.com/j/B299AA9CBC" class="job-listing__job">
# Senior iOS Engineer | Core squad
# <svg class="svg-icon svg-icon-chevron">
# <use xlink:href="#chevron"></use>
# </svg>
# <span class="job-listing__job-details">Full-time</span>
# </a>
# </li>
# <li>
# <a href="https://apply.workable.com/j/F775EF4774" class="job-listing__job">
# Software Engineer | App
# <svg class="svg-icon svg-icon-chevron">
# <use xlink:href="#chevron"></use>
# </svg>
# <span class="job-listing__job-details">Full-time</span>
# </a>
# </li>
# <li>
# <a href="https://apply.workable.com/j/B1D4450503" class="job-listing__job">
# Software Engineer | Core Data
# <svg class="svg-icon svg-icon-chevron">
# <use xlink:href="#chevron"></use>
# </svg>
# <span class="job-listing__job-details"></span>
# </a>
# </li>
# <li>
# <a href="https://apply.workable.com/j/F8F6410580" class="job-listing__job">
# Software Engineer | Integrations (PHP, Magento)
# <svg class="svg-icon svg-icon-chevron">
# <use xlink:href="#chevron"></use>
# </svg>
# <span class="job-listing__job-details">Full-time</span>
# </a>
# </li>
# <li>
# <a href="https://apply.workable.com/j/AB4A2168B4" class="job-listing__job">
# Software Engineer | Product Data
# <svg class="svg-icon svg-icon-chevron">
# <use xlink:href="#chevron"></use>
# </svg>
# <span class="job-listing__job-details">Full-time</span>
# </a>
# </li>
# <li>
# <a href="https://apply.workable.com/j/F067B3828A" class="job-listing__job">
# Technical Product Manager | Checkout Integrations
# <svg class="svg-icon svg-icon-chevron">
# <use xlink:href="#chevron"></use>
# </svg>
# <span class="job-listing__job-details">Full-time</span>
# </a>
# </li>
# <li>
# <a href="https://apply.workable.com/j/E6446B70D8" class="job-listing__job">
# Technical Product Manager | Commercial Data
# <svg class="svg-icon svg-icon-chevron">
# <use xlink:href="#chevron"></use>
# </svg>
# <span class="job-listing__job-details">Full-time</span>
# </a>
# </li>
# <li>
# <a href="https://apply.workable.com/j/9524E9A9F8" class="job-listing__job">
# VP - Technical Product Management | Data and Shared Services
# <svg class="svg-icon svg-icon-chevron">
# <use xlink:href="#chevron"></use>
# </svg>
# <span class="job-listing__job-details">Full-time</span>
# </a>
# </li>
# <li>
# <a href="https://apply.workable.com/j/BFB4E4ED51" class="job-listing__job">
# iOS Engineer
# <svg class="svg-icon svg-icon-chevron">
# <use xlink:href="#chevron"></use>
# </svg>
# <span class="job-listing__job-details">Full-time</span>
# </a>
# </li>
# </ul>
# </div>
# </div>
# <div class="careers__column">
# <div class="mb50">
# <h3 class="heading-3 mb20">À propos de Lyst</h3>
# <p>Lyst se donne pour mission de créer la plateforme leader pour les recherches de mode, aiguillant les choix des consommateurs. Nous développons l'application de référence en matière d'achats de mode. Sur l'appli, des millions de consommateurs internationaux découvrent d'une nouvelle façon la plus grande sélection de marques et boutiques de mode au monde.</p>
# <p>Chez Lyst, nous travaillons en petites équipes autonomes et auto-gérées. Chaque équipe est responsable d’un projet particulier centré sur le client, du début à la fin. Cette structure rassemble des Lysters de toutes les disciplines requises pour accomplir les objectifs du groupe. Nous récompensons ces équipes pour leur impact et nous accordons de l’importance aux approches novatrices qui sont le fruit de l’autonomie et de l’alignement. Nous embauchons des professionnels chevronnés qui vont toujours plus loin.</p>
# </div>
# <div class="mb50">
# <h3 class="heading-3 mb20">Retrouvez-nous sur</h3>
# <p>
# <a href="https://www.glassdoor.co.uk/Overview/Working-at-Lyst-EI_IE796501.11,15.htm">
# <img src="https://www.glassdoor.co.uk/pc-app/static/img/partnerCenter/badges/eng_BASIC_170x60.png">
# </a>
# </p>
# </div>
# <div class="studios-location">
# <h3 class="heading-3 mb20">Où nous trouver</h3>
# <p>7th Floor, The Minster Building<br>21 Mincing Lane, Londres, EC3R 7AG</p>
# <ul class="studios-location__list">
# <li class="studios-location__transport-details">
# <div class="studios-location__tube-lines">
# <div class="studios-location__tube-line studios-location__tube-line--northern"></div>
# <div class="studios-location__tube-line studios-location__tube-line--circle"></div>
# <div class="studios-location__tube-line studios-location__tube-line--district"></div>
# <div class="studios-location__tube-line studios-location__tube-line--dlr"></div>
# </div>
# <span>À 4 minutes à pied de l’arrêt de métro Monument</span></li>
# <li class="studios-location__transport-details">
# <div class="studios-location__tube-lines">
# <div class="studios-location__tube-line studios-location__tube-line--circle"></div>
# <div class="studios-location__tube-line studios-location__tube-line--district"></div>
# <div class="studios-location__tube-line studios-location__tube-line--dlr"></div>
# </div>
# <span>À 5 minutes à pied de l’arrêt de métro Tower Hill</span>
# </li>
# <li class="studios-location__transport-details">
# <div class="studios-location__tube-lines">
# <div class="studios-location__tube-line studios-location__tube-line--central"></div>
# <div class="studios-location__tube-line studios-location__tube-line--waterloo-and-city"></div>
# </div>
# <span>À 8 minutes à pied de l’arrêt de métro Bank</span>
# </li>
# </ul>
# </div>
# </div>
# </div>
# <div>
# <div id="map" style="height:400px; height: 300px;"></div>
# <script data-cfasync="false" src="/cdn-cgi/scripts/5c5dd728/cloudflare-static/email-decode.min.js"></script><script src='https://api.mapbox.com/mapbox-gl-js/v1.11.0/mapbox-gl.js'></script>
# <script>
#                     mapboxgl.accessToken = 'pk.eyJ1IjoibHlzdCIsImEiOiJja2JrbXE1eXcxMDlqMzFwamNmMXViZXZpIn0.zzp4EvUaF3vZmIHg2L1H1w';
#                     var map = new mapboxgl.Map({
#                         container: 'map',
#                         style: 'mapbox://styles/mapbox/streets-v11',
#                         center: [-0.081407, 51.510229],
#                         zoom: 17
#                     });
#                     var marker = new mapboxgl.Marker()
#                         .setLngLat([-0.081407, 51.510229])
#                         .addTo(map);
#                     var nav = new mapboxgl.NavigationControl();
#                     map.addControl(nav, 'top-left')
#                 </script>
# </div>
# </div>
# </div>
# </div>
# <script type="text/javascript">window.NREUM||(NREUM={});NREUM.info={"beacon":"bam-cell.nr-data.net","errorBeacon":"bam-cell.nr-data.net","licenseKey":"7db5f3f67d","applicationID":"3502633","transactionName":"b1JXYUoADUFWAEIMV1YYc0BWAhdbWA0ZFktZQBtFVxMXU1tNQAxdT0QbVlkTBldFEAwmWUpSUEdLTwRXQw==","queueTime":2,"applicationTime":67,"agent":""}</script>
# </div>
# <script>
# if ('serviceWorker' in navigator) {
#     navigator.serviceWorker.getRegistrations().then(
#         function(registrations) {
#             var len = registrations.length;
#             for(var i = 0; i < len; i++) {
#                 registrations[i].unregister();
#             }
#         }
#     );
# }
# </script>
# </body>
# </html>

# %% [markdown]
# # PARSING

# %%
import bs4

from bs4 import BeautifulSoup

# %% [markdown]
# ADDITIONAL FUNCTIONS

# %% [markdown]
# # get_country
# get_country returns the country of a city or the country itself if it is a country
# Whatever the input language, answer is returned in english

# %%
from geopy.geocoders import Nominatim
 
geolocator = Nominatim(user_agent = "geoapiExercises")

def get_country(place):
    res = str(geolocator.geocode(place, language = "en"))
    country = res.split(',')[-1]
    return country

# %%
soup = BeautifulSoup(source, 'html.parser')

print(soup.prettify())
# Out:
# <!DOCTYPE html>
# <html class="no-js" lang="fr">
#  <head>
#   <meta charset="utf-8"/>
#   <meta content="IE=edge,chrome=1" http-equiv="X-UA-Compatible">
#    <meta content="on" http-equiv="x-dns-prefetch-control"/>
#    <link href="//static.lystit.com" rel="preconnect"/>
#    <link href="//static.lystit.com" rel="dns-prefetch"/>
#    <link href="//cdna.lystit.com" rel="preconnect"/>
#    <link href="//cdna.lystit.com" rel="dns-prefetch"/>
#    <link href="//googleads.g.doubleclick.net" rel="preconnect"/>
#    <link href="//googleads.g.doubleclick.net" rel="dns-prefetch"/>
#    <link href="//www.googleadservices.com" rel="preconnect"/>
#    <link href="//www.googleadservices.com" rel="dns-prefetch"/>
#    <link href="//js-agent.newrelic.com" rel="preconnect"/>
#    <link href="//js-agent.newrelic.com" rel="dns-prefetch"/>
#    <link href="//www.google-analytics.com" rel="preconnect"/>
#    <link href="//www.google-analytics.com" rel="dns-prefetch"/>
#    <link href="//sc-static.net" rel="preconnect"/>
#    <link href="//sc-static.net" rel="dns-prefetch"/>
#    <meta content="width=device-width, initial-scale=1.0, maximum-scale=1.0, user-scalable=no" name="viewport"/>
#    <link as="font" crossorigin="" href="https://static.lystit.com/static/n/fonts/SuisseIntl-Regular-WebS.5ff578be98a31a99629e8169b3c904de.woff2" rel="preload" type="font/woff2"/>
#    <link as="font" crossorigin="" href="https://static.lystit.com/static/n/fonts/SuisseIntl-Bold-WebS.14b102a6d21cfc5d3b9634c173ff2b13.woff2" rel="preload" type="font/woff2"/>
#    <script>
#     var dc=document.documentElement.classList;dc.remove("no-js");dc.add("js")
#    </script>
#    <link href="https://www.lyst.com/careers/" hreflang="x-default" rel="alternate">
#     <link href="https://www.lyst.co.uk/careers/" hreflang="en-gb" rel="alternate">
#      <link href="https://www.lyst.com/en-au/careers/" hreflang="en-au" rel="alternate">
#       <link href="https://www.lyst.com/en-ca/careers/" hreflang="en-ca" rel="alternate">
#        <link href="https://www.lyst.fr/emplois/" hreflang="fr-fr" rel="alternate">
#         <link href="https://www.lyst.it/opportunit%C3%A0-di-lavoro/" hreflang="it-it" rel="alternate">
#          <link href="https://www.lyst.de/karriere/" hreflang="de-de" rel="alternate">
#           <link href="https://www.lyst.com/es-es/empleo/" hreflang="es-es" rel="alternate">
#            <link href="https://www.lyst.com/ja-jp/%E6%B1%82%E4%BA%BA/" hreflang="ja-jp" rel="alternate">
#             <link href="https://www.lyst.com/ru-ru/%D0%BA%D0%B0%D1%80%D1%8C%D0%B5%D1%80%D0%B0/" hreflang="ru-ru" rel="alternate">
#              <link href="https://www.lyst.com/nl-nl/vacatures/" hreflang="nl-nl" rel="alternate">
#               <link href="https://www.lyst.com/de-at/karriere/" hreflang="de-at" rel="alternate">
#                <link href="https://www.lyst.com/de-ch/karriere/" hreflang="de-ch" rel="alternate">
#                 <link href="https://www.lyst.com/nl-be/vacatures/" hreflang="nl-be" rel="alternate">
#                  <title>
#                   Lyst - Travailler chez Lyst
#                  </title>
#                  <link href="https://static.lystit.com/static/n/web/css/feeds~homepage~main~track-email-interstitial~track-redirect~webviews.ed775523a1654a4a6793.css" media="all" rel="stylesheet" type="text/css">
#                   <link href="https://static.lystit.com/static/n/web/css/feeds~homepage~main~track-email-interstitial~webviews.8bceb889818c10470de6.css" media="all" rel="stylesheet" type="text/css">
#                    <link href="https://static.lystit.com/static/n/web/css/feeds~homepage~main.1526cc3e739f99242ed0.css" media="all" rel="stylesheet" type="text/css"/>
#                    <link href="https://static.lystit.com/static/n/web/css/feeds~main.08db07e243116beac2db.css" media="all" rel="stylesheet" type="text/css"/>
#                    <link href="https://static.lystit.com/static/n/web/css/main.370030c6e8a87e78eb73.css" media="all" rel="stylesheet" type="text/css"/>
#                    <meta content="#000000" name="theme-color"/>
#                    <link href="https://api.mapbox.com/mapbox-gl-js/v1.11.0/mapbox-gl.css" rel="stylesheet"/>
#                    <meta content="Si vous voulez nous aider à changer le futur de la mode et de l’e-commerce, cliquez ici pour parcourir la liste des postes à pourvoir." name="description"/>
#                    <meta content="152784791451625" property="fb:app_id"/>
#                    <meta content="false" property="al:web:should_fallback"/>
#                    <link href="/favicon.ico" rel="icon"/>
#                    <link href="/apple-touch-icon-152x152.png" rel="apple-touch-icon-precomposed" sizes="152x152"/>
#                    <link href="/apple-touch-icon-120x120.png" rel="apple-touch-icon-precomposed" sizes="120x120"/>
#                    <link href="//static.lystit.com/static/n/misc/opensearch.378670c460bd.xml" rel="search" title="Lyst" type="application/opensearchdescription+xml"/>
#                    <link href="https://www.lyst.fr/emplois/" rel="canonical"/>
#                    <script type="text/javascript">
#                     (window.NREUM||(NREUM={})).init={privacy:{cookies_enabled:false},distributed_tracing:{enabled:true}};(window.NREUM||(NREUM={})).loader_config={agentID:"3502639",accountID:"228560",trustKey:"228560",xpid:"VgQPVFBTGwAFVFNUBAI=",licenseKey:"7db5f3f67d",applicationID:"3502633"};window.NREUM||(NREUM={}),__nr_require=function(t,e,n){function r(n){if(!e[n]){var o=e[n]={exports:{}};t[n][0].call(o.exports,function(e){var o=t[n][1][e];return r(o||e)},o,o.exports)}return e[n].exports}if("function"==typeof __nr_require)return __nr_require;for(var o=0;o<n.length;o++)r(n[o]);return r}({1:[function(t,e,n){function r(t){try{c.console&&console.log(t)}catch(e){}}var o,i=t("ee"),a=t(29),c={};try{o=localStorage.getItem("__nr_flags").split(","),console&&"function"==typeof console.log&&(c.console=!0,o.indexOf("dev")!==-1&&(c.dev=!0),o.indexOf("nr_dev")!==-1&&(c.nrDev=!0))}catch(s){}c.nrDev&&i.on("internal-error",function(t){r(t.stack)}),c.dev&&i.on("fn-err",function(t,e,n){r(n.stack)}),c.dev&&(r("NR AGENT IN DEVELOPMENT MODE"),r("flags: "+a(c,function(t,e){return t}).join(", ")))},{}],2:[function(t,e,n){function r(t,e,n,r,c){try{p?p-=1:o(c||new UncaughtException(t,e,n),!0)}catch(f){try{i("ierr",[f,s.now(),!0])}catch(d){}}return"function"==typeof u&&u.apply(this,a(arguments))}function UncaughtException(t,e,n){this.message=t||"Uncaught error with no additional information",this.sourceURL=e,this.line=n}function o(t,e){var n=e?null:s.now();i("err",[t,n])}var i=t("handle"),a=t(30),c=t("ee"),s=t("loader"),f=t("gos"),u=window.onerror,d=!1,l="nr@seenError";if(!s.disabled){var p=0;s.features.err=!0,t(1),window.onerror=r;try{throw new Error}catch(h){"stack"in h&&(t(13),t(12),"addEventListener"in window&&t(6),s.xhrWrappable&&t(14),d=!0)}c.on("fn-start",function(t,e,n){d&&(p+=1)}),c.on("fn-err",function(t,e,n){d&&!n[l]&&(f(n,l,function(){return!0}),this.thrown=!0,o(n))}),c.on("fn-end",function(){d&&!this.thrown&&p>0&&(p-=1)}),c.on("internal-error",function(t){i("ierr",[t,s.now(),!0])})}},{}],3:[function(t,e,n){var r=t("loader");r.disabled||(r.features.ins=!0)},{}],4:[function(t,e,n){function r(){L++,T=g.hash,this[u]=y.now()}function o(){L--,g.hash!==T&&i(0,!0);var t=y.now();this[h]=~~this[h]+t-this[u],this[d]=t}function i(t,e){E.emit("newURL",[""+g,e])}function a(t,e){t.on(e,function(){this[e]=y.now()})}var c="-start",s="-end",f="-body",u="fn"+c,d="fn"+s,l="cb"+c,p="cb"+s,h="jsTime",m="fetch",v="addEventListener",w=window,g=w.location,y=t("loader");if(w[v]&&y.xhrWrappable&&!y.disabled){var x=t(10),b=t(11),E=t(8),R=t(6),O=t(13),N=t(7),M=t(14),P=t(9),C=t("ee"),S=C.get("tracer");t(16),y.features.spa=!0;var T,L=0;C.on(u,r),b.on(l,r),P.on(l,r),C.on(d,o),b.on(p,o),P.on(p,o),C.buffer([u,d,"xhr-done","xhr-resolved"]),R.buffer([u]),O.buffer(["setTimeout"+s,"clearTimeout"+c,u]),M.buffer([u,"new-xhr","send-xhr"+c]),N.buffer([m+c,m+"-done",m+f+c,m+f+s]),E.buffer(["newURL"]),x.buffer([u]),b.buffer(["propagate",l,p,"executor-err","resolve"+c]),S.buffer([u,"no-"+u]),P.buffer(["new-jsonp","cb-start","jsonp-error","jsonp-end"]),a(M,"send-xhr"+c),a(C,"xhr-resolved"),a(C,"xhr-done"),a(N,m+c),a(N,m+"-done"),a(P,"new-jsonp"),a(P,"jsonp-end"),a(P,"cb-start"),E.on("pushState-end",i),E.on("replaceState-end",i),w[v]("hashchange",i,!0),w[v]("load",i,!0),w[v]("popstate",function(){i(0,L>1)},!0)}},{}],5:[function(t,e,n){function r(t){}if(window.performance&&window.performance.timing&&window.performance.getEntriesByType){var o=t("ee"),i=t("handle"),a=t(13),c=t(12),s="learResourceTimings",f="addEventListener",u="resourcetimingbufferfull",d="bstResource",l="resource",p="-start",h="-end",m="fn"+p,v="fn"+h,w="bstTimer",g="pushState",y=t("loader");if(!y.disabled){y.features.stn=!0,t(8),"addEventListener"in window&&t(6);var x=NREUM.o.EV;o.on(m,function(t,e){var n=t[0];n instanceof x&&(this.bstStart=y.now())}),o.on(v,function(t,e){var n=t[0];n instanceof x&&i("bst",[n,e,this.bstStart,y.now()])}),a.on(m,function(t,e,n){this.bstStart=y.now(),this.bstType=n}),a.on(v,function(t,e ...
#                    </script>
#                    <script>
#                     var Lyst = {
#         data: {"pageType":"about","pageSubType":"careers","features":{"mg_cookie_consent_settings":false,"mg_cookie_consent_larger_cta":false,"uf_upper_funnel_journey":false,"uf_load_previous":false,"uf_feed_filters_redesign":false,"mg_app_download_email_combo":false,"mg_getfeedback":false,"checkout_klarna_messaging":false,"seo_lazy_load_navigation":true,"mg_financial_incentives_homepage":"","mg_android_email_signup_banner":false,"mg_android_email_signup_banner_desc":"","mg_financial_incentives_homepage_value":"","mg_financial_incentives_feed":"","mg_financial_incentives_feed_value":"","mg_financial_incentives_is_pdp":"","mg_financial_incentives_is_pdp_value":"","mg_product_card_alt_image":false,"mg_product_hover_event":false},"hotjar":null},
#         environment: {"country":"FR","csrftoken":"MrkWgdZj2r3UsTWyLtaqXtJNXv5eEuDXDPVHiRgT0S3uCGpnl4AI1JfxlFkxPKYb","eu_geoip_country":true,"language":"fr-fr","domainDefaultLanguageIsEnglish":false,"forceShowEnglishOnlyFeatures":false,"urlPatterns":{"productPageRegex":"^/?(accessoires|chaussures|vetements|maison|bijoux|sacs)/([%-\\w]+)/$","searchPage":"recherche","signupPageRegex":"^/?(account)/(register|login)/$","rothkoEndpoint":"/api/rothko/","helpContactUs":"/aide/nous-contacter/","about":"/%C3%A0-propos/","careers":"/emplois/","exploreFeed":"/explore/","helpCentreHomepage":"https://help.lyst.com/hc/change_language/fr-fr?return_to=/hc/fr-fr","helpTermsAndConditions":"/aide/conditions-generales/","helpPrivacyPolicy":"/aide/politique-de-confidentialite/","helpIntellectualProperty":"/aide/propriete-intellectuelle/","helpCookiePolicy":"/aide/politique-de-cookies/","partnerContact":"/partenaires/","sitemapsAllCategories":"/sitemap/categories/","articleIndex":"/articles/"},"productNamesToTypes":{"Clothing":"A","Shoes":"S","Accessories":"R","Bags":"B","Jewelry":"J","Home":"H"},"currentTranslationsFilesPaths":{"django":{"path":"../locale/fr/LC_MESSAGES/django.json","versionName":"fr_django_a9efd5ba4b713fe66983253c3a08109843795be1b5f092bd4c317838aac0f2c1.zip"},"djangojs":{"path":"../locale/fr/LC_MESSAGES/djangojs.json","versionName":"fr_djangojs_8d97e3b360fd48c775710707ab2698c5bec15c9bfde9f56b3d12d4b6d4e1dd31.zip"}},"isProduction":true,"gaUaAccount":"UA-5946484-12","agifAnalyticsUrl":"//api.ldnlyap.com/lyst.gif","analyticsCookieVersion":1,"currencyProps":{"currencyCode":"EUR","currencySymbol":"\u20ac","currencyIndicator":"\u20ac","currencyDecimalPlaces":2,"priceWithCurrencySymbolFormat":"{price}\u00a0{currency_symbol}","priceWithCurrencySymbolFormatInItempropSpans":"&lt;span {price_span_props}&gt;{price}&lt;/span&gt;&lt;span {currency_symbol_span_props}&gt;&amp;nbsp;{currency_symbol}&lt;/span&gt;"},"gaVariables":{"dimension12":"about","dimension19":"careers","contentGroup1":"about","dimension2":"Visitor"},"userName":null,"userLoggedIn":false,"userSignedInStatus":"no","userSlug":null,"userAvatar":null,"lystId":null,"userId":null,"userGender":null,"facebookAppId":"152784791451625","channelUrl":"https://www.lyst.com/facebook-channel.html","ipAddress":"86.242.54.146","pageViewId":"8a3c6606-ae82-446b-8fe2-b717e16ff836","timestamp_ms":1623681172377,"messages":[],"disable_third_party_js":false,"showPromoCode":false,"s4lFeedTooltip":true,"enable_branch_io":false,"paidNoRetarget":"nope","lifeCycleStage":"prospecting","trafficSource":"","firstTimeLogin":false,"boomLeadSignupPrompt":false,"branchIoKey":"key_live_glC2sUCTNt2zrOAWq49iTjnhsFblPHmX","heimdallFlags":["null_test_enabled","hotjar_on_feeds_journeys_disabled","mg_cookie_consent_settings_disabled"],"release":"v3083","release_sha":"677eb10c0748782e967eea8d4eb8fbeab7a501f3","cookieVersions":{"customization":1,"advertisement":1,"analytics":1},"snapchatHash":null,"webToAppCpi":{"Email to App - Footer":0.0,"Web to App - CSS Lead Return - General":0.05,"Web to App - Feed - General":0.5,"Web to App - Feed - Product card click":0.54,"Web to App - Feed - Show More Button":0.54,"Web to App - Footer":0.0,"Web to App - Homepage - General":0.42,"Web to App - In Stock PDP - General":1.28,"Web to App - In Stock PDP - Shop Now button":0.03,"Web to App - In Stock PDP - Show More Button":0.53,"Web to App - Out of Stock PDP - General":0.59,"Web to App - Out of Stock PDP - Show More Button":0.09,"Web to App - Show More Button":0.47},"isPlaUtmCampaign":false,"activeWebToAppBanners":["mg_app_banner_feed","mg_app_banner_homepage","mg_app_banner_is_pdp","mg_app_banner_oos_pdp","mg_app_banner_css_lead_return"],"activeWebToAppBlocks":["mg_block_shop_now_is_pdp","mg_block_related_show_more_is_pdp","mg_block_related_show_more_oos_pdp"]}
#     };
#
#     (function (data) {
#         try {
#             var name = data.pageType + (data.pageSubType ? '/' + data.pageSubType : '');
#             var testBucket = data.testBucket;
#
#             if (name) {
#                 if (testBucket) {
#                     var viewName = name + '/' + testBucket;
#                     NREUM.setPageViewName(viewName);
#                 }
#                 else {
#                     NREUM.setPageViewName(name);
#                 }
#             }
#         }
#         catch (e) {}
#     })(Lyst.data);
#                    </script>
#                    <script>
#                     function loadCatalog(data) {
#         var django = this.django || (this.django = {});
#         django.translationsCatalog = data;
#     }
#
#     function translationsError(event, error) {
#         // TODO: do something with event/error
#         NREUM && NREUM.noticeError('Translations Failed!')
#     }
#                    </script>
#                    <script crossorigin="" defer="" src="https://static.lystit.com/static/n/web/script/runtime.e9b98cf518cb11896524.js" type="text/javascript">
#                    </script>
#                    <script crossorigin="" defer="" src="https://static.lystit.com/static/n/web/script/vendors~feeds~homepage~main~track-email-interstitial~webviews.91c898473b949b20e948.js" type="text/javascript">
#                    </script>
#                    <script crossorigin="" defer="" src="https://static.lystit.com/static/n/web/script/vendors~main.dd8b035c392a7c1285cf.js" type="text/javascript">
#                    </script>
#                    <script crossorigin="" defer="" type="text/javascript">
#                     (window.webpackJsonp=window.webpackJsonp||[]).push([[1],{288:function(n,w,o){}}]);
# //# sourceMappingURL=https://static.lystit.com/static/n/web/script/feeds~homepage~main~track-email-interstitial~track-redirect~webviews.78d4b26bd0ef98c69162.js.map
#                    </script>
#                    <script crossorigin="" defer="" src="https://static.lystit.com/static/n/web/script/feeds~homepage~main~track-email-interstitial~webviews.8fc6f78ee76123ae179b.js" type="text/javascript">
#                    </script>
#                    <script crossorigin="" defer="" src="https://static.lystit.com/static/n/web/script/feeds~homepage~main.cb0acd2a2cefdb8b068e.js" type="text/javascript">
#                    </script>
#                    <script crossorigin="" defer="" src="https://static.lystit.com/static/n/web/script/feeds~main.3b06ff0a62a1d0628cab.js" type="text/javascript">
#                    </script>
#                    <script crossorigin="" defer="" src="https://static.lystit.com/static/n/web/script/main.64f37f5f15356538a17c.js" type="text/javascript">
#                    </script>
#                    <script onerror="translationsError(event, error)" src="/i18n/jsoni18n.js/?bundle_ids=feeds~homepage~main.js,feeds~homepage~main~track-email-interstitial~webviews.js,feeds~main.js,feeds~homepage~main~track-email-interstitial~track-redirect~webviews.js,vendors~main.js,main.js,vendors~feeds~homepage~main~track-email-interstitial~webviews.js,runtime.js" type="text/javascript">
#                    </script>
#                    <div data-hypernova-id="707185ea-edc7-482c-8b53-59ff385214bc" data-hypernova-key="JSONLDOrganization">
#                     <script data-reactroot="" type="application/ld+json">
#                      {"@context":"http://schema.org","@type":"Organization","name":"Lyst","url":"https://www.lyst.fr","sameAs":["https://twitter.com/lyst","https://www.facebook.com/Lyst","https://instagram.com/lyst/","https://plus.google.com/+LYST","https://www.pinterest.com/Lyst/","http://lyst.tumblr.com/"]}
#                     </script>
#                    </div>
#                    <script data-hypernova-id="707185ea-edc7-482c-8b53-59ff385214bc" data-hypernova-key="JSONLDOrganization" type="application/json">
#                     <!--{"url":"https://www.lyst.fr"}-->
#                    </script>
#                   </link>
#                  </link>
#                 </link>
#                </link>
#               </link>
#              </link>
#             </link>
#            </link>
#           </link>
#          </link>
#         </link>
#        </link>
#       </link>
#      </link>
#     </link>
#    </link>
#   </meta>
#  </head>
#  <body class="lyst-app header-bg-careers" is="lyst-app">
#   <div class="icon-sprite-map">
#    <svg xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink">
#     <defs>
#      <symbol id="account-icon" viewbox="0 0 28 28">
#       <g fill="none" fill-rule="evenodd" stroke="none" stroke-width="1">
#        <path d="M10,7 C10,4.79442411 11.7944241,3 14,3 C16.2055759,3 18,4.79442411 18,7 C18,9.20557589 16.2055759,11 14,11 C11.7944241,11 10,9.20557589 10,7 M21.3524505,7.65907592 C21.3524505,3.43577608 18.0531804,0 14,0 C9.94577685,0 6.64754953,3.43577608 6.64754953,7.65907592 C6.64754953,9.59041006 7.34306569,11.353377 8.48070907,12.7014005 C3.49843587,14.9368817 0,20.0986926 0,26.0990806 C0,27.1483881 0.816475495,28 1.82481752,28 C2.83315954,28 3.64963504,27.1483881 3.64963504,26.0990806 C3.64963504,20.1540909 8.29301356,15.3181518 14,15.3181518 C19.7059437,15.3181518 24.350365,20.1540909 24.350365,26.0990806 C24.350365,27.1483881 25.1668405,28 26.1751825,28 C27.1824818,28 28,27.1483881 28,26.0990806 C28,20.0986926 24.5015641,14.9368817 19.5192909,12.7014005 C20.6558916,11.353377 21.3524505,9.59041006 21.3524505,7.65907592 Z" fill="#FFFFFF" id="Fill-1">
#        </path>
#       </g>
#      </symbol>
#      <symbol id="basket-icon" viewbox="0 0 28 28">
#       <g fill="none" fill-rule="evenodd" stroke="none" stroke-width="1">
#        <g fill="currentColor" fill-rule="nonzero">
#         <path d="M21,8.62573242 L21,7.5 C21,3.38559685 17.8965362,-8.8817842e-16 14,-8.8817842e-16 C10.1034638,-8.8817842e-16 7,3.38559685 7,7.5 L7,8.62573242 L10,8.62573242 L10,7.5 C10,4.98698616 11.821404,3 14,3 C16.178596,3 18,4.98698616 18,7.5 L18,8.62573242 L21,8.62573242 Z" id="Shape">
#         </path>
#         <path d="M5.896,8 L22.3125837,8 C23.2463788,8 24.0558961,8.64617755 24.2628479,9.55675114 L27.8992689,25.5567511 C28.1440685,26.6338523 27.4693548,27.7054646 26.3922536,27.9502642 C26.2468205,27.9833177 26.0981466,28 25.9490047,28 L2,28 C0.8954305,28 1.07691633e-14,27.1045695 1.0658141e-14,26 C1.0658141e-14,25.840576 0.0190617692,25.6817238 0.0567794338,25.5268258 L3.95277943,9.52682579 C4.17098516,8.63070369 4.97369389,8 5.896,8 Z M6.84160974,11 L3.5,25 L24.5,25 L21.3810318,11 L6.84160974,11 Z" id="Rectangle">
#         </path>
#        </g>
#       </g>
#      </symbol>
#      <symbol id="bell" viewbox="0 0 16 21">
#       <path d="M6.213 18.53c-.04.168-.06.316-.06.506C6.154 20.113 6.989 21 8 21s1.846-.887 1.846-1.964c0-.169-.02-.338-.06-.507H6.214zM16 15.93a.872.872 0 0 0-.19-.454c-.022-.022-1.715-1.905-1.715-6.883 0-3.874-2.54-5.498-4.635-5.996V1.472C9.46.67 8.804 0 8.021 0s-1.46.671-1.46 1.472v1.147c-2.095.498-4.635 2.1-4.635 5.996 0 4.978-1.693 6.861-1.714 6.861a.755.755 0 0 0-.212.455v1.363h16v-1.363z" fill="currentColor" fill-rule="evenodd">
#       </path>
#      </symbol>
#      <symbol id="bell-empty" viewbox="0 0 24 24">
#       <path clip-rule="evenodd" d="M18 10c0-3.06-2.29-5.585-5.25-5.954V2h-1.5v2.046A6.001 6.001 0 006 10v7.5H4V19h16v-1.5h-2V10zm-1.5 7.5V10a4.5 4.5 0 10-9 0v7.5h9zM12 22a2 2 0 002-2h-4a2 2 0 002 2z" fill="currentColor" fill-rule="evenodd">
#       </path>
#      </symbol>
#      <symbol id="preview-icon" viewbox="0 0 24 24">
#       <path d="M12 14.25C13.5464 14.25 14.8 13.0188 14.8 11.5C14.8 9.98126 13.5464 8.75004 12 8.75004C10.4536 8.75004 9.2 9.98126 9.2 11.5C9.2 13.0188 10.4536 14.25 12 14.25ZM12 15.4286C14.2091 15.4286 16 13.6697 16 11.5C16 9.33035 14.2091 7.57147 12 7.57147C9.79086 7.57147 8 9.33035 8 11.5C8 13.6697 9.79086 15.4286 12 15.4286Z" fill="currentColor" fill-rule="evenodd">
#       </path>
#       <path d="M3.52058 11.5113C4.13253 12.2289 5.04818 13.1277 6.21285 13.9192C7.78463 14.9875 9.75026 15.8214 12 15.8214C14.2497 15.8214 16.2154 14.9875 17.7871 13.9192C18.9518 13.1277 19.8675 12.2289 20.4794 11.5113C19.8195 10.7611 18.8413 9.841 17.6299 9.04023C16.0231 7.97803 14.0876 7.17857 12 7.17857C9.9124 7.17857 7.97686 7.97803 6.37005 9.04023C5.1587 9.841 4.18051 10.7611 3.52058 11.5113ZM22 11.5C20.8 13.2024 17.12 17 12 17C6.88 17 3.2 13.2024 2 11.5C3.33333 9.66667 7.2 6 12 6C16.8 6 20.6667 9.66667 22 11.5Z" fill="currentColor" fill-rule="evenodd">
#       </path>
#      </symbol>
#      <symbol id="cart" viewbox="0 0 28 28">
#       <path d="M13.1124119 3l-3.61313533 7h9.00144683l-3.6131353-7h-1.7751762zm8.5370491 7H28l-2 18H2L0 10h6.35053902L11.2219007 0h5.5561986l4.8713617 10z" fill="currentColor" fill-rule="evenodd">
#       </path>
#      </symbol>
#      <symbol id="chevron" viewbox="0 0 28 28">
#       <path d="M20.19238816 17.67695526L11 26.86934342l-3.67695526-3.67695526L16.51543289 14l-6.50644604-6.50644605-2.68594211-2.6859421L11 1.13065657 23.86934342 14l-3.67695526 3.67695526z" fill="currentColor" fill-rule="evenodd">
#       </path>
#      </symbol>
#      <symbol id="chevron-thin" viewbox="0 0 20 12">
#       <path clip-rule="evenodd" d="M1.25226 0.888787L0 2.12354L8.76811 10.7657L8.76411 10.7697L10.013 12L10.0167 11.9964L10.0203 11.9999L11.2726 10.7652L11.2692 10.7618L20 2.15578L18.7516 0.925464L10.0206 9.53121L1.25226 0.888787Z" fill="black" fill-rule="evenodd">
#       </path>
#      </symbol>
#      <symbol id="clear" viewbox="0 0 20 20">
#       <circle cx="10" cy="10" fill="#e0e1e7" r="10">
#       </circle>
#       <path d="M10 11l-3.4 3.4-1-1L9 10 5.6 6.6l1-1L10 9l3.4-3.4 1 1L11 10l3.4 3.4-1 1L10 11z" fill="#707070">
#       </path>
#      </symbol>
#      <symbol id="cross" viewbox="0 0 28 28">
#       <path d="M11.172 14l-3.53-3.53-3.54-3.54L6.928 4.1 14 11.173l7.07-7.07L23.9 6.93 16.827 14l7.07 7.07-2.827 2.83L14 16.827l-7.07 7.07L4.1 21.07 11.173 14z" fill="currentColor" fill-rule="evenodd">
#       </path>
#      </symbol>
#      <symbol id="cross-thin" viewbox="0 0 24 24">
#       <path clip-rule="evenodd" d="M12 10.9394L3.06067 2L2.00001 3.06066L10.9394 12L2 20.9394L3.06066 22L12 13.0607L20.9393 22L22 20.9394L13.0607 12.0001L22.0001 3.06072L20.9394 2.00006L12 10.9394Z" fill="currentColor" fill-rule="evenodd">
#       </path>
#      </symbol>
#      <symbol id="discount" viewbox="0 0 28 28">
#       <path d="M3.865 9.072L8.902 15.25l7.178-4.842 6.455 9.57M18.252 20.079l5.008.973.974-5.008" fill="none" stroke="white" stroke-linecap="round" stroke-width="2">
#       </path>
#      </symbol>
#      <symbol id="external-link" viewbox="0 0 28 28">
#       <path d="M21.068 4.068L17 0h11v11l-4.457-4.457-9.068 9.07L12 13.136l9.068-9.07zM14 4V0h14v14h-4v10H4V4h10zM0 28h28V0H0v28z" fill="currentColor" fill-rule="evenodd">
#       </path>
#      </symbol>
#      <symbol id="fat-arrow" viewbox="0 0 48 48">
#       <path d="m24 0-24 24h12.25l-.17 24.5 23.25.08.34-24.58h12.33z" fill="currentColor">
#       </path>
#      </symbol>
#      <symbol id="filters" viewbox="0 0 24 24">
#       <path d="M7 9.5c.82843 0 1.5-.67157 1.5-1.5S7.82843 6.5 7 6.5 5.5 7.17157 5.5 8 6.17157 9.5 7 9.5zM7 11c1.39788 0 2.57245-.9561 2.90549-2.25H22v-1.5H9.90549C9.57245 5.95608 8.39788 5 7 5s-2.57245.95608-2.90549 2.25H2v1.5h2.09451C4.42755 10.0439 5.60212 11 7 11zm10 6.5c.8284 0 1.5-.6716 1.5-1.5s-.6716-1.5-1.5-1.5-1.5.6716-1.5 1.5.6716 1.5 1.5 1.5zm0 1.5c1.3979 0 2.5725-.9561 2.9055-2.25H22v-1.5h-2.0945C19.5725 13.9561 18.3979 13 17 13s-2.5725.9561-2.9055 2.25H2v1.5h12.0945C14.4275 18.0439 15.6021 19 17 19z" fill="currentColor" fill-rule="evenodd">
#       </path>
#      </symbol>
#      <symbol id="heart" viewbox="0 0 28 28">
#       <path d="M13.98 6.534l-1.683-1.682a7.14 7.14 0 0 0-10.098 0 7.146 7.146 0 0 0 0 10.097l11.78 11.78 6.73-6.733 5.047-5.045a7.135 7.135 0 0 0 .003-10.1 7.147 7.147 0 0 0-10.1.002l-1.68 1.68z" fill="currentColor" fill-rule="evenodd">
#       </path>
#      </symbol>
#      <symbol id="heart-broken" viewbox="0 0 28 28">
#       <path d="M14.693242,6.52693713 L12.1643836,10.4227523 L14.6575342,14.7016342 L12.1643836,18.9805161 L14.2655716,26.6344367 L4.10885817,16.3996802 C1.29440342,13.5635995 1.29987889,8.9598866 4.10829812,6.12988779 C6.92244357,3.29411876 11.4767903,3.28577059 14.2997803,6.13045214 L14.693242,6.52693713 Z M17.5803532,6.24661905 L17.6933655,6.13273831 C20.5090733,3.29539499 25.0786973,3.29988898 27.8871165,6.12988779 C30.7012619,8.96565682 30.7082692,13.5562857 27.8842877,16.4019664 L22.7916554,21.5337299 L17.1959682,27.1724138 L14.8493151,18.9805161 L17.5342466,14.9053905 L14.6575342,10.4227523 L17.5803532,6.24661905 Z" fill="currentColor" fill-rule="evenodd">
#       </path>
#      </symbol>
#      <symbol id="hyperlink" viewbox="0 0 28 28">
#       <g fill="none" fill-rule="evenodd">
#        <g fill="currentColor" fill-rule="evenodd">
#         <path d="M10.25 17.915l.084.086c2.756 2.756 7.237 2.764 9.995.005l5.011-5.01c2.75-2.75 2.756-7.234-.005-9.996-2.756-2.756-7.237-2.764-9.996-.005l-3.094 3.094 4.612.388.983-.982a3.537 3.537 0 0 1 4.995.005 3.54 3.54 0 0 1 .005 4.995l-5.01 5.011a3.537 3.537 0 0 1-5.08-.092l-2.5 2.501z">
#         </path>
#         <path d="M17.763 10.743a7.19 7.19 0 0 0-.085-.086c-2.756-2.756-7.236-2.764-9.995-.005l-5.01 5.01c-2.75 2.75-2.757 7.234.004 9.996 2.756 2.756 7.237 2.764 9.996.005l3.094-3.094-4.612-.389-.982.983a3.537 3.537 0 0 1-4.995-.005 3.54 3.54 0 0 1-.006-4.996l5.011-5.01a3.537 3.537 0 0 1 5.079.092l2.5-2.501z">
#         </path>
#        </g>
#       </g>
#      </symbol>
#      <symbol id="minus" viewbox="0 0 24 24">
#       <path clip-rule="evenodd" d="M20 12.75H4V11.25L20 11.25V12.75Z" fill="currentColor" fill-rule="evenodd">
#       </path>
#      </symbol>
#      <symbol id="plus" viewbox="0 0 24 24">
#       <path clip-rule="evenodd" d="M11.25 12.75V22H12.75V12.75H22V11.25H12.75V2H11.25V11.25H2V12.75H11.25Z" fill="currentColor" fill-rule="evenodd">
#       </path>
#      </symbol>
#      <symbol id="plus-thin" viewbox="0 0 24 24">
#       <path clip-rule="evenodd" d="M11.25 12.75V22h1.5v-9.25H22v-1.5h-9.25V2h-1.5v9.25H2v1.5h9.25z" fill="currentColor" fill-rule="evenodd">
#       </path>
#      </symbol>
#      <symbol id="round-minus" viewbox="0 0 10 10">
#       <g fill="none" fill-rule="evenodd" stroke="none" stroke-width="1">
#        <rect fill="#707070" height="2" rx="1" width="10" x="0" y="4">
#        </rect>
#       </g>
#      </symbol>
#      <symbol id="round-plus" viewbox="0 0 10 10">
#       <g fill="none" fill-rule="evenodd" stroke="none" stroke-width="1">
#       <path d="M7.412.342c5.334-1.429 10.816 1.736 12.246 7.07a9.982 9.982 0 01-1.733 8.685l7.732 7.731a2 2 0 11-2.829 2.829l-7.935-7.935c-.711.398-1.482.715-2.305.936-5.334 1.429-10.816-1.736-12.246-7.07C-1.087 7.254 2.078 1.772 7.412.342zM3.56 11.725a6.667 6.667 0 1012.88-3.45 6.667 6.667 0 00-12.88 3.45z" fill="currentColor" fill-rule="evenodd">
#       </path>
#      </symbol>
#      <symbol id="sort" viewbox="0 0 24 24">
#       <path d="M7.91357 2L3 6h4.15066v14h1.52593V6H13L7.91357 2zm9.17283 20L22 18h-4.1507V4h-1.5259v14H12l5.0864 4z" fill="currentColor" fill-rule="evenodd">
#       </path>
#      </symbol>
#      <symbol id="tag" viewbox="0 0 28 28">
#       <path d="M0 14.015L13.982 0l12.015 2.038 1.98 11.04-14.98 14.95L0 14.016zm20.863-3.63a2.25 2.25 0 1 0-3.183-3.18 2.25 2.25 0 0 0 3.183 3.18z" fill="currentColor" fill-rule="evenodd">
#       </path>
#      </symbol>
#      <symbol id="tick" viewbox="0 0 24 24">
#       <path clip-rule="evenodd" d="M21 6.09258L8.51175 19L3 13.3032L4.0571 12.2107L8.51175 16.8148L19.9429 5L21 6.09258Z" fill="currentColor" fill-rule="evenodd">
#       </path>
#      </symbol>
#      <symbol id="tick-new" viewbox="0 0 28 28">
#       <g fill="currentColor" fill-rule="evenodd" stroke="none" stroke-width="1">
#        <g fill="#021135" stroke="#021135" transform="translate(0.000000, -5.000000)">
#         <g>
#          <path d="M17.6007813,26.569392 L17.6007813,3.16916279 C17.6007813,2.56177617 18.0852201,2.06939203 18.6866414,2.06939203 L20.3399211,2.06939203 C20.9396251,2.06939203 21.4257813,2.5640629 21.4257813,3.16916279 L21.4257813,29.4696213 C21.4257813,30.0770079 20.9413424,30.569392 20.3399211,30.569392 L20.2762187,30.569392 L8.2315938,30.569392 C7.59670794,30.569392 7.08203125,30.0464619 7.08203125,29.4124263 L7.08203125,27.7263578 C7.08203125,27.0873832 7.59253291,26.569392 8.2315938,26.569392 L17.6007813,26.569392 Z" id="Rectangle-504" transform="translate(14.253906, 16.319392) rotate(30.000000) translate(-14.253906, -16.319392) ">
#          </path>
#         </g>
#        </g>
#       </g>
#      </symbol>
#      <symbol id="truck" viewbox="0 0 28 28">
#       <path d="M21.75 7H18v2h3.75l3.75 5.994L28 15l-5-8h-1.25zM2.027 22H0v-7h28v7h-2.027a4.5 4.5 0 0 0-8.946 0h-6.054a4.5 4.5 0 0 0-8.946 0zM0 3h18v12H0V3zm21.5 22a2.5 2.5 0 1 0 0-5 2.5 2.5 0 0 0 0 5zm-15 0a2.5 2.5 0 1 0 0-5 2.5 2.5 0 0 0 0 5z" fill="currentColor" fill-rule="evenodd">
#       </path>
#      </symbol>
#      <symbol id="lysts-search" viewbox="0 0 67 65">
#       <g fill="none" fill-rule="evenodd" stroke="none" stroke-width="1">
#        <g stroke-width="2" transform="translate(-129.000000, -184.000000)">
#         <g transform="translate(130.000000, 185.000000)">
#          <ellipse cx="37.3158705" cy="26.7894449" rx="27.0884264" ry="26.7294449" stroke="currentColor">
#          </ellipse>
#          <path d="M38.123675,49.7424674 C50.4944939,49.7424674 60.523024,39.8468375 60.523024,27.6399592" stroke="currentColor">
#          </path>
#          <path d="M19.9378174,47.8802502 L5.42401208,62.1241041 C4.42882167,63.1080116 2.76701524,63.0602751 1.71226352,62.0174815 C0.65751181,60.974688 0.60922783,59.3317222 1.60441824,58.3478147 L16.0288091,44.01556 L19.9378174,47.8802502 Z" stroke="currentColor">
#          </path>
#          <path d="M21.4719952,18.1593483 C29.0272244,18.1593483 32.804839,18.1593483 32.804839,18.1593483 C32.804839,18.1593483 37.308918,20.0267413 46.3170759,23.7615275 C51.2570334,25.7725662 53.7270122,27.9272505 53.7270122,30.2255804 C53.7270122,32.5239104 53.7270122,33.6730753 53.7270122,33.6730753 L21.4719952,33.6730753 L21.4719952,18.1593483 Z" stroke="currentColor">
#          </path>
#          <path d="M21.9078738,29.7946436 L53.303239,29.7946436" stroke="currentColor" stroke-linecap="square">
#          </path>
#          <path d="M35.8559893,19.8830957 L33.8954902,24.0365359" stroke="currentColor" stroke-linecap="square">
#          </path>
#          <path d="M38.9071395,21.6068432 L37.5995037,24.6234012" stroke="currentColor" stroke-linecap="square">
#          </path>
#          <path d="M42.3941684,22.4687169 L41.0865326,25.4852749" stroke="currentColor" stroke-linecap="square">
#          </path>
#         </g>
#        </g>
#       </g>
#      </symbol>
#      <symbol id="lysts-control" viewbox="0 0 62 58">
#       <g fill="none" fill-rule="evenodd" stroke="currentColor" stroke-width="1">
#        <g stroke="currentColor" stroke-width="2" transform="translate(-334.000000, -186.000000)">
#         <g transform="translate(335.000000, 187.000000)">
#          <ellipse cx="31" cy="28.5" rx="25" ry="24.5">
#          </ellipse>
#          <path d="M32,0 C16.536027,0 4,12.536027 4,28 M32,56 C47.463973,56 60,43.463973 60,28">
#          </path>
#          <path d="M43,38 C45.494143,35.436238 47,32.1095713 47,28.4742334 C47,24.8632047 45.5142148,21.5567329 43.0499017,19">
#          </path>
#          <path d="M38.2309834,37.1286199 C47.9916237,37.1863752 55.8573661,29.3206328 55.7996108,19.5599925" transform="translate(47.015455, 28.344464) rotate(-45.000000) translate(-47.015455, -28.344464)">
#          </path>
#          <path d="M29.1785357,27.5704157 C29.3591658,27.8300558 29.6597366,28 30,28 C30.5522847,28 31,27.5522847 31,27 C31,26.6597366 30.8300558,26.3591658 30.5704157,26.1785357 C30.8577745,26.0633635 31.1714876,26 31.5,26 C32.8807119,26 34,27.1192881 34,28.5 C34,29.8807119 32.8807119,31 31.5,31 C30.1192881,31 29,29.8807119 29,28.5 C29,28.1714876 29.0633635,27.8577745 29.1785357,27.5704157 Z">
#          </path>
#          <ellipse cx="31.5" cy="28" rx="7.5" ry="8">
#          </ellipse>
#          <rect height="5" rx="1.5" width="3" x="31" y="41">
#          </rect>
#          <path d="M0,35 L4.43076923,43.4857143 L29.9076923,43.4857143 M34.0615385,43.4857143 L36,43.4857143">
#          </path>
#         </g>
#        </g>
#       </g>
#      </symbol>
#      <symbol id="lysts-recommendations" viewbox="0 0 65 47">
#       <g fill="none" fill-rule="evenodd" stroke="none" stroke-width="1">
#        <g transform="translate(-234.000000, -190.000000)">
#         <g transform="translate(235.535254, 191.000000)">
#          <path d="M22,21.9622642 C22,24.6712731 25,28.017185 31,32 C37,27.8666845 40,24.5207726 40,21.9622642 C40,19.7739661 37.9852814,18 35.5,18 C33.0147186,18 31,19.7739661 31,21.9622642 C31,19.7739661 28.9852814,18 26.5,18 C24.0147186,18 22,19.7739661 22,21.9622642" fill="currentColor">
#          </path>
#          <path d="M31,0 C16.3183544,0 3.92485338,9.75034261 0,23.099778 C4.15732912,36.0701226 16.5895044,45 31,45" stroke="currentColor" stroke-width="2">
#          </path>
#          <path d="M62,0 C47.3183544,0 34.9248534,9.75034261 31,23.099778 C35.1573291,36.0701226 47.5895044,45 62,45" stroke="currentColor" stroke-width="2" transform="translate(46.500000, 22.500000) scale(-1, 1) translate(-46.500000, -22.500000) ">
#          </path>
#          <path d="M62,23 C56.8353412,12.3521912 45.8812482,4 31,4 C16.1187518,4 5.15095529,12.3238557 0,23" stroke="currentColor" stroke-width="2">
#          </path>
#          <ellipse cx="31" cy="24.5" rx="20" ry="20.5" stroke="currentColor" stroke-width="2">
#          </ellipse>
#         </g>
#        </g>
#       </g>
#      </symbol>
#      <symbol id="value-proposition-search" viewbox="0 0 42 45">
#       <g fill="none" fill-rule="evenodd" stroke="#021135" stroke-width="2" transform="translate(0 3)">
#        <circle cx="23.333333" cy="16.666667" r="16.666667">
#        </circle>
#        <path d="m22.5897436 29.7692308c7.6470196 0 13.8461538-6.1991343 13.8461538-13.8461539">
#        </path>
#        <path d="m8.18208694 26.3351966-.04612001 12.5112725c0 .861042-.73978795 1.5590545-1.65236263 1.5590545s-1.65236263-.6980125-1.65236263-1.5590545l-.03124167-12.5112725z" transform="matrix(.70710678 .70710678 -.70710678 .70710678 25.49759 5.184092)">
#        </path>
#       </g>
#      </symbol>
#      <symbol id="value-proposition-shopping-bag" viewbox="0 0 42 45">
#       <g fill="none" fill-rule="evenodd" stroke="none" stroke-width="1">
#        <g id="Group-21" stroke-width="2" transform="translate(1.000000, 1.000000)">
#         <g id="Group-20">
#          <path d="M32.7659574,21.2765957 L34.4680851,37.4468085" id="Line-2" stroke="#021135" stroke-linecap="square">
#          </path>
#          <g id="Group" stroke="#0C2A49">
#           <path d="M3.89476146,12.9148936 L1.09927941,42.4042553 L38.9007206,42.4042553 L36.1052385,12.9148936 L3.89476146,12.9148936 Z" id="Rectangle-14">
#           </path>
#           <path d="M11.9148936,12.7659574 C11.9148936,4.00273731 15.4812563,0 20.1955551,0" id="Path-3-Copy">
#           </path>
#           <path d="M19.5744681,12.7659574 C19.5744681,4.00273731 23.1408308,0 27.8551296,0" id="Path-3-Copy" transform="translate(23.714799, 6.382979) scale(-1, 1) translate(-23.714799, -6.382979) ">
#           </path>
#          </g>
#         </g>
#        </g>
#       </g>
#      </symbol>
#      <symbol id="value-proposition-star" viewbox="0 0 42 45">
#       <g fill="none" fill-rule="evenodd" stroke="none" stroke-width="1">
#          </path>
#         </g>
#        </g>
#       </g>
#      </symbol>
#      <symbol id="saved-search-bookmark" viewbox="0 0 13 17">
#       <g fill="none" fill-rule="evenodd" stroke="none" stroke-width="1">
#        <g fill="currentColor" fill-rule="nonzero" transform="translate(-58.000000, -353.000000)">
#         <path d="M59,353 L69.3305921,353 C69.8828769,353 70.3305921,353.447715 70.3305921,354 L70.3305921,368.097416 C70.3305921,368.6497 69.8828769,369.097416 69.3305921,369.097416 C69.128069,369.097416 68.930319,369.035924 68.7635087,368.921076 L64.7323794,366.145677 C64.3908801,365.910557 63.939712,365.910557 63.5982127,366.145677 L59.5670834,368.921076 C59.1121883,369.234268 58.4895311,369.119394 58.1763396,368.664499 C58.0614921,368.497689 58,368.299939 58,368.097416 L58,354 C58,353.447715 58.4477153,353 59,353 Z">
#         </path>
#        </g>
#       </g>
#      </symbol>
#      <symbol id="stopwatch" viewbox="0 0 28 28">
#       <g fill="none" fill-rule="evenodd" stroke="none" stroke-width="1">
#        <g stroke="#021135" stroke-width="2.5" transform="translate(2.500000, 0.500000)">
#         <g>
#          <circle cx="11.5" cy="15" r="11.5">
#          </circle>
#          <path d="M11.5,3 L11.5,1.5" id="Line-5" stroke-linecap="square">
#          </path>
#          <path d="M8.5,0.5 L14.4759521,0.5" id="Line-7" stroke-linecap="round">
#          </path>
#          <circle cx="11.5" cy="15.5" r="2">
#          </circle>
#          <path d="M13,14 L15.9519043,10" id="Line-8" stroke-linecap="round">
#          </path>
#         </g>
#        </g>
#       </g>
#      </symbol>
#      <symbol id="tap-hand" viewbox="0 0 28 28">
#       <g fill="none" fill-rule="evenodd" stroke="none" stroke-width="1">
#        <path d="M11.063 27.85S2.775 13.963 5.246 11.925c0 0 1.764-1.853 3.35 1.11l1.76 3.519V2.48S10.531.628 12.648.628c1.022.118 1.829.965 1.941 2.039v9.815s.177-2.782 2.112-2.41c1.324.255 1.41 2.41 1.41 2.41s.177-2.224 1.764-2.038c1.789.207 1.764 2.219 1.764 2.219s.657-1.678 2.117-1.296c.702.186 1.233.93 1.233 2.782 0 0 .354 9.258-3.537 13.515l-10.39.186z" fill="#FFF" fill-rule="evenodd" stroke="#021135" stroke-linecap="round" stroke-linejoin="round">
#        </path>
#       </g>
#      </symbol>
#      <symbol id="mail-plane" viewbox="0 0 70 100">
#       <g fill="none" fill-rule="evenodd" stroke="none" stroke-width="1">
#        <g transform="translate(-146.000000, -106.000000)">
#         <path d="M221.982919,108.134455 C222.986766,109.496432 223.111227,112.523621 222.221401,113.962683 L196.768184,155.126625 C195.777207,156.729795 194.055574,157.614235 192.292212,157.614235 C191.372214,157.614235 190.441296,157.374012 189.595787,156.86931 L178.760557,150.39997 L165.571512,160.615086 C165.019279,161.043335 164.269124,161.120757 163.639867,160.81456 C163.01061,160.508363 162.611645,159.872295 162.611645,159.17491 L162.611645,140.757665 L148.549597,132.361688 C146.72988,131.275444 145.746508,129.206187 146.056554,127.117331 C146.36816,125.029058 147.91137,123.331195 149.969374,122.815821 L216.468195,106.158532 C216.893875,106.051615 217.324429,106 217.750109,106 C219.396862,106 220.979072,106.772479 221.982919,108.134455 Z M192.269007,151 L216,113 L154,128.37704 L166.378699,135.695029 L191.864452,125.986653 C192.153141,125.87634 192.479281,125.987422 192.638645,126.248793 C192.797814,126.509971 192.743002,126.845524 192.508345,127.044435 L175.776493,141.250305 L192.269007,151 Z" fill="currentColor">
#         </path>
#        </g>
#       </g>
#      </symbol>
#      <symbol id="magnify" viewbox="0 0 28 28">
#       <g fill="none" fill-rule="evenodd">
#        <path d="M16.171 13.509l5.62 5.619a1.6 1.6 0 1 1-2.263 2.263l-5.704-5.705a7.599 7.599 0 1 1 2.348-2.178zm-2.6-.819a5.067 5.067 0 1 0-2.312 1.352 5.048 5.048 0 0 0 1.91-.98 1.615 1.615 0 0 1 .403-.372z" fill="currentColor">
#        </path>
#        <g stroke="currentColor" stroke-linecap="round" stroke-width="2">
#         <path d="M10 7v4M12 9H8">
#         </path>
#        </g>
#       </g>
#      </symbol>
#      <symbol id="heart-empty" viewbox="0 0 28 28">
#       <path d="M7.98 5.079c-1.238 0-2.412.525-3.302 1.477-1.933 2.068-1.917 5.205.043 7.629 1.683 2.084 7.272 7.41 7.939 7.972 1.19 1.005 1.514 1.006 2.677.029.89-.748 6.234-5.918 7.995-8.022 1.922-2.297 1.934-5.568.026-7.608-.889-.95-2.062-1.474-3.303-1.474h-.001c-1.226 0-2.38.512-3.249 1.441-1.001 1.073-1.34 1.688-1.342 1.695-.28.515-.798.83-1.449.843-.607-.003-1.166-.321-1.44-.838 0 0-.369-.655-1.343-1.7-.872-.931-2.026-1.444-3.25-1.444m2.535 19.382c-.74-.626-6.483-6.08-8.355-8.398-2.92-3.614-2.877-8.365.104-11.555C3.778 2.891 5.806 2 7.98 2c2.16 0 4.17.878 5.663 2.476.133.144.257.281.374.413.118-.13.243-.27.376-.413 1.49-1.595 3.5-2.472 5.66-2.473 2.176 0 4.206.89 5.716 2.505 2.941 3.145 2.978 8.121.089 11.576-1.893 2.262-7.426 7.605-8.384 8.41-1.192 1.003-2.324 1.505-3.455 1.506-1.144 0-2.29-.513-3.503-1.54z" fill="currentColor" fill-rule="evenodd">
#       </path>
#      </symbol>
#      <symbol id="round-chevron" viewbox="0 0 28 28">
#       <path d="M21.377 14.058c.037.426-.105.865-.43 1.19L12.994 23.2a1.498 1.498 0 0 1-2.12-.004l-.865-.864a1.504 1.504 0 0 1-.003-2.12l6.134-6.134-5.035-5.036-1.016-1.016a1.498 1.498 0 0 1-.006-2.119L10.991 5a1.5 1.5 0 0 1 2.122.01l7.828 7.827c.333.333.479.785.436 1.22z" fill="currentColor" fill-rule="evenodd">
#       </path>
#      </symbol>
# ...
#             Partner Acquisition Executive
#             <svg class="svg-icon svg-icon-chevron">
#              <use xlink:href="#chevron">
#              </use>
#             </svg>
#             <span class="job-listing__job-details">
#              Full-time
#             </span>
#            </a>
#           </li>
#           <li>
#            <a class="job-listing__job" href="https://apply.workable.com/j/A346702A44">
#             People &amp; Operations Assistant
#             <svg class="svg-icon svg-icon-chevron">
#              <use xlink:href="#chevron">
#              </use>
#             </svg>
#             <span class="job-listing__job-details">
#              Full-time
#             </span>
#            </a>
#           </li>
#           <li>
#            <a class="job-listing__job" href="https://apply.workable.com/j/9FAE4CEBDB">
#             Performance Marketing Lead
#             <svg class="svg-icon svg-icon-chevron">
#              <use xlink:href="#chevron">
#              </use>
#             </svg>
#             <span class="job-listing__job-details">
#              Full-time
#             </span>
#            </a>
#           </li>
#           <li>
#            <a class="job-listing__job" href="https://apply.workable.com/j/A92E3A8774">
#             Principal Product Designer
#             <svg class="svg-icon svg-icon-chevron">
#              <use xlink:href="#chevron">
#              </use>
#             </svg>
#             <span class="job-listing__job-details">
#              Full-time
#             </span>
#            </a>
#           </li>
#           <li>
#            <a class="job-listing__job" href="https://apply.workable.com/j/F64789C369">
#             Programmatic Display Account Manager / Display Ad Operations Manager
#             <svg class="svg-icon svg-icon-chevron">
#              <use xlink:href="#chevron">
#              </use>
#             </svg>
#             <span class="job-listing__job-details">
#              Full-time
#             </span>
#            </a>
#           </li>
#           <li>
#            <a class="job-listing__job" href="https://apply.workable.com/j/FFE2BFF3A2">
#             Senior Backend Engineer | App
#             <svg class="svg-icon svg-icon-chevron">
#              <use xlink:href="#chevron">
#              </use>
#             </svg>
#             <span class="job-listing__job-details">
#              Full-time
#             </span>
#            </a>
#           </li>
#           <li>
#            <a class="job-listing__job" href="https://apply.workable.com/j/9F894D86B2">
#             Senior Data Engineer | Commercial Data
#             <svg class="svg-icon svg-icon-chevron">
#              <use xlink:href="#chevron">
#              </use>
#             </svg>
#             <span class="job-listing__job-details">
#              Full-time
#             </span>
#            </a>
#           </li>
#           <li>
#            <a class="job-listing__job" href="https://apply.workable.com/j/6743B5E50C">
#             Senior Data Scientist - Data Enrichment
#             <svg class="svg-icon svg-icon-chevron">
#              <use xlink:href="#chevron">
#              </use>
#             </svg>
#             <span class="job-listing__job-details">
#              Full-time
#             </span>
#            </a>
#           </li>
#           <li>
#            <a class="job-listing__job" href="https://apply.workable.com/j/75B06C1840">
#             Senior Full Stack Engineer | Member Growth
#             <svg class="svg-icon svg-icon-chevron">
#              <use xlink:href="#chevron">
#              </use>
#             </svg>
#             <span class="job-listing__job-details">
#              Full-time
#             </span>
#            </a>
#           </li>
#           <li>
#            <a class="job-listing__job" href="https://apply.workable.com/j/8FA77F0366">
#             Senior Partner Acquisition Manager
#             <svg class="svg-icon svg-icon-chevron">
#              <use xlink:href="#chevron">
#              </use>
#             </svg>
#             <span class="job-listing__job-details">
#              Full-time
#             </span>
#            </a>
#           </li>
#           <li>
#            <a class="job-listing__job" href="https://apply.workable.com/j/4AD50049A6">
#             Senior Performance Marketing Analyst | Paid Search
#             <svg class="svg-icon svg-icon-chevron">
#              <use xlink:href="#chevron">
#              </use>
#             </svg>
#             <span class="job-listing__job-details">
#              Full-time
#             </span>
#            </a>
#           </li>
#           <li>
#            <a class="job-listing__job" href="https://apply.workable.com/j/ABE9D774EC">
#             Senior Performance Marketing Analyst | Shopping
#             <svg class="svg-icon svg-icon-chevron">
#              <use xlink:href="#chevron">
#              </use>
#             </svg>
#             <span class="job-listing__job-details">
#              Full-time
#             </span>
#            </a>
#           </li>
#           <li>
#            <a class="job-listing__job" href="https://apply.workable.com/j/74A714D716">
#             Senior Python Engineer | Commercial Data
#             <svg class="svg-icon svg-icon-chevron">
#              <use xlink:href="#chevron">
#              </use>
#             </svg>
#             <span class="job-listing__job-details">
#              Full-time
#             </span>
#            </a>
#           </li>
#           <li>
#            <a class="job-listing__job" href="https://apply.workable.com/j/D12788AE51">
#             Senior Software Engineer | Checkout Core
#             <svg class="svg-icon svg-icon-chevron">
#              <use xlink:href="#chevron">
#              </use>
#             </svg>
#             <span class="job-listing__job-details">
#              Full-time
#             </span>
#            </a>
#           </li>
#           <li>
#            <a class="job-listing__job" href="https://apply.workable.com/j/8DE8D2E8F5">
#             Senior Software Engineer | Commercial Data
#             <svg class="svg-icon svg-icon-chevron">
#              <use xlink:href="#chevron">
#              </use>
#             </svg>
#             <span class="job-listing__job-details">
#              Full-time
#             </span>
#            </a>
#           </li>
#           <li>
#            <a class="job-listing__job" href="https://apply.workable.com/j/D51FFF67A2">
#             Senior Software Engineer | Search &amp; Rank
#             <svg class="svg-icon svg-icon-chevron">
#              <use xlink:href="#chevron">
#              </use>
#             </svg>
#             <span class="job-listing__job-details">
#              Full-time
#             </span>
#            </a>
#           </li>
#           <li>
#            <a class="job-listing__job" href="https://apply.workable.com/j/886DDC1E78">
#             Senior iOS Engineer | Core
#             <svg class="svg-icon svg-icon-chevron">
#              <use xlink:href="#chevron">
#              </use>
#             </svg>
#             <span class="job-listing__job-details">
#              Full-time
#             </span>
#            </a>
#           </li>
#           <li>
#            <a class="job-listing__job" href="https://apply.workable.com/j/B299AA9CBC">
#             Senior iOS Engineer | Core squad
#             <svg class="svg-icon svg-icon-chevron">
#              <use xlink:href="#chevron">
#              </use>
#             </svg>
#             <span class="job-listing__job-details">
#              Full-time
#             </span>
#            </a>
#           </li>
#           <li>
#            <a class="job-listing__job" href="https://apply.workable.com/j/F775EF4774">
#             Software Engineer | App
#             <svg class="svg-icon svg-icon-chevron">
#              <use xlink:href="#chevron">
#              </use>
#             </svg>
#             <span class="job-listing__job-details">
#              Full-time
#             </span>
#            </a>
#           </li>
#           <li>
#            <a class="job-listing__job" href="https://apply.workable.com/j/B1D4450503">
#             Software Engineer | Core Data
#             <svg class="svg-icon svg-icon-chevron">
#              <use xlink:href="#chevron">
#              </use>
#             </svg>
#             <span class="job-listing__job-details">
#             </span>
#            </a>
#           </li>
#           <li>
#            <a class="job-listing__job" href="https://apply.workable.com/j/F8F6410580">
#             Software Engineer | Integrations (PHP, Magento)
#             <svg class="svg-icon svg-icon-chevron">
#              <use xlink:href="#chevron">
#              </use>
#             </svg>
#             <span class="job-listing__job-details">
#              Full-time
#             </span>
#            </a>
#           </li>
#           <li>
#            <a class="job-listing__job" href="https://apply.workable.com/j/AB4A2168B4">
#             Software Engineer | Product Data
#             <svg class="svg-icon svg-icon-chevron">
#              <use xlink:href="#chevron">
#              </use>
#             </svg>
#             <span class="job-listing__job-details">
#              Full-time
#             </span>
#            </a>
#           </li>
#           <li>
#            <a class="job-listing__job" href="https://apply.workable.com/j/F067B3828A">
#             Technical Product Manager | Checkout Integrations
#             <svg class="svg-icon svg-icon-chevron">
#              <use xlink:href="#chevron">
#              </use>
#             </svg>
#             <span class="job-listing__job-details">
#              Full-time
#             </span>
#            </a>
#           </li>
#           <li>
#            <a class="job-listing__job" href="https://apply.workable.com/j/E6446B70D8">
#             Technical Product Manager | Commercial Data
#             <svg class="svg-icon svg-icon-chevron">
#              <use xlink:href="#chevron">
#              </use>
#             </svg>
#             <span class="job-listing__job-details">
#              Full-time
#             </span>
#            </a>
#           </li>
#           <li>
#            <a class="job-listing__job" href="https://apply.workable.com/j/9524E9A9F8">
#             VP - Technical Product Management | Data and Shared Services
#             <svg class="svg-icon svg-icon-chevron">
#              <use xlink:href="#chevron">
#              </use>
#             </svg>
#             <span class="job-listing__job-details">
#              Full-time
#             </span>
#            </a>
#           </li>
#           <li>
#            <a class="job-listing__job" href="https://apply.workable.com/j/BFB4E4ED51">
#             iOS Engineer
#             <svg class="svg-icon svg-icon-chevron">
#              <use xlink:href="#chevron">
#              </use>
#             </svg>
#             <span class="job-listing__job-details">
#              Full-time
#             </span>
#            </a>
#           </li>
#          </ul>
#         </div>
#        </div>
#        <div class="careers__column">
#         <div class="mb50">
#          <h3 class="heading-3 mb20">
#           À propos de Lyst
#          </h3>
#          <p>
#           Lyst se donne pour mission de créer la plateforme leader pour les recherches de mode, aiguillant les choix des consommateurs. Nous développons l'application de référence en matière d'achats de mode. Sur l'appli, des millions de consommateurs internationaux découvrent d'une nouvelle façon la plus grande sélection de marques et boutiques de mode au monde.
#          </p>
#          <p>
#           Chez Lyst, nous travaillons en petites équipes autonomes et auto-gérées. Chaque équipe est responsable d’un projet particulier centré sur le client, du début à la fin. Cette structure rassemble des Lysters de toutes les disciplines requises pour accomplir les objectifs du groupe. Nous récompensons ces équipes pour leur impact et nous accordons de l’importance aux approches novatrices qui sont le fruit de l’autonomie et de l’alignement. Nous embauchons des professionnels chevronnés qui vont toujours plus loin.
#          </p>
#         </div>
#         <div class="mb50">
#          <h3 class="heading-3 mb20">
#           Retrouvez-nous sur
#          </h3>
#          <p>
#           <a href="https://www.glassdoor.co.uk/Overview/Working-at-Lyst-EI_IE796501.11,15.htm">
#            <img src="https://www.glassdoor.co.uk/pc-app/static/img/partnerCenter/badges/eng_BASIC_170x60.png"/>
#           </a>
#          </p>
#         </div>
#         <div class="studios-location">
#          <h3 class="heading-3 mb20">
#           Où nous trouver
#          </h3>
#          <p>
#           7th Floor, The Minster Building
#           <br/>
#           21 Mincing Lane, Londres, EC3R 7AG
#          </p>
#          <ul class="studios-location__list">
#           <li class="studios-location__transport-details">
#            <div class="studios-location__tube-lines">
#             <div class="studios-location__tube-line studios-location__tube-line--northern">
#             </div>
#             <div class="studios-location__tube-line studios-location__tube-line--circle">
#             </div>
#             <div class="studios-location__tube-line studios-location__tube-line--district">
#             </div>
#             <div class="studios-location__tube-line studios-location__tube-line--dlr">
#             </div>
#            </div>
#            <span>
#             À 4 minutes à pied de l’arrêt de métro Monument
#            </span>
#           </li>
#           <li class="studios-location__transport-details">
#            <div class="studios-location__tube-lines">
#             <div class="studios-location__tube-line studios-location__tube-line--circle">
#             </div>
#             <div class="studios-location__tube-line studios-location__tube-line--district">
#             </div>
#             <div class="studios-location__tube-line studios-location__tube-line--dlr">
#             </div>
#            </div>
#            <span>
#             À 5 minutes à pied de l’arrêt de métro Tower Hill
#            </span>
#           </li>
#           <li class="studios-location__transport-details">
#            <div class="studios-location__tube-lines">
#             <div class="studios-location__tube-line studios-location__tube-line--central">
#             </div>
#             <div class="studios-location__tube-line studios-location__tube-line--waterloo-and-city">
#             </div>
#            </div>
#            <span>
#             À 8 minutes à pied de l’arrêt de métro Bank
#            </span>
#           </li>
#          </ul>
#         </div>
#        </div>
#       </div>
#       <div>
#        <div id="map" style="height:400px; height: 300px;">
#        </div>
#        <script data-cfasync="false" src="/cdn-cgi/scripts/5c5dd728/cloudflare-static/email-decode.min.js">
#        </script>
#        <script src="https://api.mapbox.com/mapbox-gl-js/v1.11.0/mapbox-gl.js">
#        </script>
#        <script>
#         mapboxgl.accessToken = 'pk.eyJ1IjoibHlzdCIsImEiOiJja2JrbXE1eXcxMDlqMzFwamNmMXViZXZpIn0.zzp4EvUaF3vZmIHg2L1H1w';
#                     var map = new mapboxgl.Map({
#                         container: 'map',
#                         style: 'mapbox://styles/mapbox/streets-v11',
#                         center: [-0.081407, 51.510229],
#                         zoom: 17
#                     });
#                     var marker = new mapboxgl.Marker()
#                         .setLngLat([-0.081407, 51.510229])
#                         .addTo(map);
#                     var nav = new mapboxgl.NavigationControl();
#                     map.addControl(nav, 'top-left')
#        </script>
#       </div>
#      </div>
#     </div>
#    </div>
#    <script type="text/javascript">
#     window.NREUM||(NREUM={});NREUM.info={"beacon":"bam-cell.nr-data.net","errorBeacon":"bam-cell.nr-data.net","licenseKey":"7db5f3f67d","applicationID":"3502633","transactionName":"b1JXYUoADUFWAEIMV1YYc0BWAhdbWA0ZFktZQBtFVxMXU1tNQAxdT0QbVlkTBldFEAwmWUpSUEdLTwRXQw==","queueTime":2,"applicationTime":67,"agent":""}
#    </script>
#   </div>
#   <script>
#    if ('serviceWorker' in navigator) {
#     navigator.serviceWorker.getRegistrations().then(
#         function(registrations) {
#             var len = registrations.length;
#             for(var i = 0; i < len; i++) {
#                 registrations[i].unregister();
#             }
#         }
#     );
# }
#   </script>
#  </body>
# </html>

# %%
database = [['job_name', 'country', 'city', 'offer_link']]

offers = soup.find('div', class_ = 'list-container list')
#print(offers)
positions = offers.find_all('div', class_ = 'job')

for position in positions:
    #print("______________")
    #print(position)
    
    #JOB_NAME
    job_name = position.find("a").text.strip(' \n\t')
    #print(job_name)        
    
    # COUNTRY / CITY
    citycountry = position.find("li").text.strip(' \n\t')
    #print(citycountry)

    citycountry_list = citycountry.split(",")
 
    # Best case: the 2 fields are provided:
    if len(citycountry_list) == 2:
        country = get_country(citycountry_list[1]).strip(' \n\t')
        city = citycountry_list[0].strip(' \n\t')
    
    # But sometimes only the city or the country is provided: in that case, the length of citycountry is 1
    elif len(citycountry_list) == 1: 
        country = get_country(citycountry_list[0]).strip(' \n\t')
        city = ' '
        
    else:
        country = ' '
        city = ' '
        
    #REMOTE CASE
    if citycountry == 'Remote job':
        country = 'Remote'
        city = ' '
        
    #print(country)
    #print('the city is: '+ city)
    
    # OFFER_LINK
    link = position.a.get('href')    
    offer_link = "https://everli.recruitee.com" + link
    print(offer_link)

# #    print(position.prettify())

    database.append([job_name, country, city, offer_link])
# Out:
# https://everli.recruitee.com/o/key-account-support-intern
# https://everli.recruitee.com/o/corporate-development-and-ma-associate
# https://everli.recruitee.com/o/consolidation-reporting-specialist
# https://everli.recruitee.com/o/international-talent-acquisition-specialist
# https://everli.recruitee.com/o/marketing-manager-italy-1
# https://everli.recruitee.com/o/head-of-corporate-development-and-ma
# https://everli.recruitee.com/o/illustration-and-motion-designer
# https://everli.recruitee.com/o/campaign-content-designer
# https://everli.recruitee.com/o/finance-business-partner-product-hr-and-central-functions
# https://everli.recruitee.com/o/internal-communication-and-employer-branding-manager
# https://everli.recruitee.com/o/crm-manager-everli-plus-subscription-programme
# https://everli.recruitee.com/o/crm-associate
# https://everli.recruitee.com/o/product-marketing-manager-retail
# https://everli.recruitee.com/o/operations-area-manager-emilia-romagna
# https://everli.recruitee.com/o/city-manager-poznan
# https://everli.recruitee.com/o/city-manager-odz
# https://everli.recruitee.com/o/city-manager-wrocaw
# https://everli.recruitee.com/o/international-expansion-associate-3
# https://everli.recruitee.com/o/back-end-engineer-demand
# https://everli.recruitee.com/o/senior-product-designer
# https://everli.recruitee.com/o/operations-area-manager-toscana-firenze
# https://everli.recruitee.com/o/tech-lead
# https://everli.recruitee.com/o/brand-and-customer-insights-manager-milano
# https://everli.recruitee.com/o/head-of-crm
# https://everli.recruitee.com/o/back-end-engineer-retail-milano
# https://everli.recruitee.com/o/back-end-engineer-l-6899
# https://everli.recruitee.com/o/data-scientist-core
# https://everli.recruitee.com/o/back-end-engineer-operations
# https://everli.recruitee.com/o/data-engineer-1
# https://everli.recruitee.com/o/product-manager-2
# https://everli.recruitee.com/o/specjalisty-ds-ksiegowosci-i-podatkow
# https://everli.recruitee.com/o/junior-marketing-intern-lyon
# https://everli.recruitee.com/o/retail-sales-manager-france
# https://everli.recruitee.com/o/country-manager-czech-republic

# %%
print(database)
print(len(database)-1)
# Out:
# [['job_name', 'country', 'city', 'offer_link'], ['Key Account Support Intern', 'Italy', 'Milano', 'https://everli.recruitee.com/o/key-account-support-intern'], ['Corporate Development and M&A Associate', 'Italy', 'Milano', 'https://everli.recruitee.com/o/corporate-development-and-ma-associate'], ['Consolidation & Reporting Specialist', 'Italy', 'Milano', 'https://everli.recruitee.com/o/consolidation-reporting-specialist'], ['International Talent Acquisition Specialist', 'Italy', 'Milano', 'https://everli.recruitee.com/o/international-talent-acquisition-specialist'], ['Marketing Manager Italy', 'Italy', 'Milano', 'https://everli.recruitee.com/o/marketing-manager-italy-1'], ['Head of Corporate Development and M&A', 'Italy',